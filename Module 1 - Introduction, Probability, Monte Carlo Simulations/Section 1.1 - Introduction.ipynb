# %% [markdown]
# ## <font face='helvetica' size=12pt color='blue'>Introduction</font>

# %% [markdown]
# ### <font color='blue'> Machine Learning Textbooks:</font>
#
#
# <table><tr>
# <td> <img src='https://m.media-amazon.com/images/I/411CpImAaAL._SX404_BO1,204,203,200_.jpg 'width='300px'/><figcaption><a href="https://www.amazon.com/Hundred-Page-Machine-Learning-Book-ebook/dp/B09Q15C9CQ/ref=sr_1_2?crid=1M3F100NG6OM9&keywords=andrii+burkov&qid=1693420556&sprefix=andrii+burkov+%2Caps%2C789&sr=8-2" target="_blank">The Hundred-Page Book of Machine Learning</a></figcaption> </td>
# <td> <img src='https://f.media-amazon.com/images/I/812I0mhF0DL._SY522_.jpg'width='280px'/>
# <figcaption><a href="https://www.amazon.com/Data-Science-Scratch-Principles-Python/dp/1492041130/ref=sr_1_1?crid=3VP51AXS2SJUX&dib=eyJ2IjoiMSJ9.8bSg9CnzT6ILYn7fN65f9GJBHeKHkJp0V9v3dHtU7x80gc4_NK5tz6j2eqTRRLl0foBmid2sVrKKB2MwKA7kvYvmdVb1_ZYYbcaaACzHYDTlsDviJQszyPjNQcFhkyvzcUHcf5u8zsgUoOfZsjb2Ope7GP4MAy46fR4zxvc48IEoOwwyS_-sGZspN_d5ooTUkbgiekOzzejffo7EAi-ca8PpwmOHmsrGmByOZTkMSmY.JY0dpqn7LODGcC3oxLa0jtQv4ntpRURSXIPQQujlfOE&dib_tag=se&keywords=joel+grus+python&qid=1724787248&sprefix=joel+grus+python%2Caps%2C94&sr=8-1" target="_blank">Data Science From Scratch - First Principles with Python </a></figcaption> </td>
# <td> <img src='https://m.media-amazon.com/images/I/81VywRgKFbL._SL1500_.jpg'width='280px'/>
# <figcaption><a href="https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-PyTorch/dp/B0F2SG98Q9/ref=sr_1_4?dib=eyJ2IjoiMSJ9.2cE0kQmIL-r-0wPLtevAZvbcbzUlpFyp2WlN331uFuECQUnLJGJRfvoNVfq91dyd8ekuoGL3kXNyDZ4CBu2eV_GPRa3WSBm3nEkVWBZafKod5SoQV0_qwFWJaNAREI4Wgu2Q_QBbgilSm7zMqi25QkYRBdO4vELxGeW72HMAFcbyirJ7ZUvuyU--TZ6o4HR3rmmx0kAQxLqGCdah4dsh3UgHWRfEPdJClzGbvN-i_UE.jRIuaYdGvarsQ5tzPOQrPUZ_hQg-SXDWkKftKZfhAi4&dib_tag=se&qid=1768334614&refinements=p_27%3AAurelien+Geron&s=books&sr=1-4" target="_blank">Hands-On Machine Learning with Scikit-Learn and PyTorch</a></figcaption> </td>
# <td> <img src='https://m.media-amazon.com/images/I/41xowcRDX9L._SX424_BO1,204,203,200_.jpg'width='315px'/>
# <figcaption><a href="https://probml.github.io/pml-book/book1.html" target="_blank">Probabilistic Machine Learning - An Introduction </a></figcaption> </td>
# </tr></table>

# %% [markdown]
# ###  <font color='blue' size=6pt>Data Science Preliminaries</font>
# <style> #margins > p { margin-top: -50px; } </style>
#
# ::: {fragment}
# - Data is information, a perception of our own existence and everything surrounding us.
# ::: {fragment}
# - The amount of data that we can record nowadays exceeds anything accomplished before.
# - 1 bit  = 0 or 1.
# - letter = 1 byte = 8 bits, such as for example $(0,1,1,0,0,1,1,0).$
#
# <font color='red'>Critical Thinking:</font> We need many "letters" to encode information! **How many different "letters" do we have?**
# <font color='red'>Hint:</font> Use the multiplication principle.
#
#
# - 1000 letters = 1kbyte = $10^3$ bytes.
# - 1 mil. letters = 1 mbyte = $10^3$ kbytes.
# - 1 gbyte = 1 bil. letters = $10^3$ mbytes.
# - 1 tbyte = $10^3$ gbytes, (tbyte means terabyte).
# - 1 pbyte = $10^3$ tbytes, (pbyte means petabyte).
# - 1 ebyte = $10^3$ pbytes, (ebyte means exabyte).

# %% [markdown]
# ### <font color='blue'> Who said "machine-learning" first?</font>
#
# The term machine learning was coined in 1959 by Arthur Samuel, an IBM employee and pioneer in the field of computer gaming and artificial intelligence:
# [reference link.](https://people.csail.mit.edu/brooks/idocs/Samuel.pdf)
#
# In a few words, it is the science of automating and improving decisions and inferences based on data.

# %% [markdown]
# ## <font color='blue'> Types of Data </font>
#
# - Data could be classified based on the levels of measurement, such as nominal, ordinal, interval and ratio.
# - Nominal data: unique identifiers but order does not matter for example, peoples' names, names of flowers, colors etc.
# - Ordinal data: unique indentifiers and order matters, such as in letter grades, military or administration ranks, etc.
# - Continuous data: Interval level of measurement: numerical values where differences make sense in the context of using them but ratios or proportions could be meaningless, such as temperatures, heights of people, days in the calendar.
# - Continuous data: Ratio level of measurement: numerical values, that are at the interval level of measurement and also the ratio and proportions make sense in the context of using them, such as salaries, weights, distances, forces, etc.

# %% [markdown]
# ### <font color='blue'> Types of Data - Example </font>
#
# Independent vs Dependent variables:
#
#
#
#
# Country|Age|Salary|Purchased
# :---|---:|---:|---:
#  France|44|72000|No
# Spain|29|51000|Yes
# Germany|32|63000|No
# Japan|53|81000|Yes
# Portugal|48|73000|Yes
# Italy|43|67500|No
#
# In this example, the variables "Country", "Age" and "Salary" are independent whereas "Purchased" is a dependent variable.
#
# Quite often in the Data Science community nominal variables are referred as "discrete".
#
#
# CRITICAL THINKING: the context and the implied usage is very important for determining the level of measurement.
#
#
#
# <figure>
# <center>
# <img src="https://i.imgur.com/afKyWNP.png" width='300px'/>
# <figcaption>Levels of Measurement</figcaption></center>
# </figure>

# %% [markdown]
# ## <font color='blue'> Main Ideas </font>
#
# - Machine learning is the science of programming computers for using data with the goal of automating **predictions** and analyses.
#
# - In all, it consists of input-output algorithms for supervised and/or unsupervised learning.
#
# - We learn how to apply machine learing algorithms implemented in Python in order to analyze and make predictions by using real data sets.
#
# - Pyhton is a very popular and friendly to use interpreted programming language that has currently emerged with prominence in the Data Science commumity.

# %% [markdown]
# ## <font color='blue'> Programming Language: Python </font>
#
# [Reference for Beginners](https://github.com/Akuli/python-tutorial)
#
# For using Python you can access <http://colab.research.google.com> via an internet browser such as Chrome.
#
# It is a scripting language that uses libraries of functions and classes which must to be imported before using the specific methods defined in them.
#
# ### <font color='blue' size=4pt> Functions </font>
#
# Functions are a building block in Machine Learning. Every solution to a data problem is articulated in terms of functions.
#
# A function is a mapping, a rule of correspondence such that an input is assigned exacly one output.
#
# <font color='green'>*Crtical Thinking: Functions and Set Theory represent the building blocks of modern mathematics.*</font>
#
#
#
# <figure>
# <center>
# <img src='https://i.imgur.com/boVL9B5.png'width='300px'/>
# <figcaption>Example of a Function by Arrow Diagram</figcaption></center>
# </figure>
#
#
#
# The important elements of a function are
# > i\. the <font color='magenta'>*domain*</font> of the function\
# > ii\. the <font color='magenta'>*range*</font> of the function\
# > iii\. the <font color='magenta'>*definition*</font> of the function.
#
#  Example:
# ```python
# import numpy as np
#
# def distance(P,Q):
#   return np.sqrt(np.sum((P-Q)**2))
# ```
#
# This means that we defined a function that calculates the Euclidean distance between point $P$ and point $Q.$
#
# **Critical Thinking & Discussion Prompts:**
#   - Why did we use so many parentheses in the syntax of the code?
#   - Why do we have a sum in the calculation?
#   - Where (from what concept) is the square root coming from?
#
# Example:
# ```python
# A = ['red','orange','blue','green','yellow']
# B = ['apple','carrot','peach','mango']
#
# def f(A,B):
#   l = []
#   for x in A:
#     for y in B:
#       l.append(x+' '+y)
#   return l
# ```
#
# What does this code do?

# %% [markdown]
# ### <font color='blue'> Object Oriented Programming </font>
#
# #### Introduction to Classes in Python
#
# In Python, a class is a blueprint for creating objects. Objects are instances of classes, and classes define the properties (attributes) and behaviors (methods) that the objects created from the class can have. Classes are a fundamental concept in object-oriented programming (OOP) and allow for the creation of complex data structures and models.
#
# #### Key Concepts
#
# 1. **Class**: A blueprint for creating objects. It defines a set of attributes and methods that the created objects can have.
#
# 2. **Object**: An instance of a class. Each object can have unique values for the attributes defined in the class.
#
# 3. **Attributes**: Variables that belong to a class or an instance of a class. They represent the properties or state of an object.
#
# 4. **Methods**: Functions defined within a class that describe the behaviors of the objects created from the class.
#
# 5. **Inheritance**: A way to form new classes using classes that have already been defined. It allows for the creation of a class that is a modified version of an existing class.
#
# 6. **Encapsulation**: The practice of keeping the details of the implementation hidden, only exposing the necessary parts of the code.
#
# 7. **Polymorphism**: The ability to present the same interface for different underlying data types.
#
# #### Creating a Class
#
# To create a class in Python, use the `class` keyword followed by the class name and a colon. Inside the class, you can define attributes and methods.
#
# ```python
# class MyClass:
#     # Class attribute
#     class_attribute = "I am a class attribute"
#
#     # Initializer / Instance attributes
#     def __init__(self, instance_attribute):
#         self.instance_attribute = instance_attribute
#
#     # Method
#     def display_attributes(self):
#         print(f"Class Attribute: {MyClass.class_attribute}")
#         print(f"Instance Attribute: {self.instance_attribute}")
#
# # Creating an instance of MyClass
# my_object = MyClass("I am an instance attribute")
#
# # Accessing attributes and methods
# my_object.display_attributes()
# ```
#
# #### Explanation
#
# - **Class Definition**: The `class MyClass:` line defines a new class named `MyClass`.
# - **Class Attribute**: `class_attribute` is a class attribute shared by all instances of the class.
# - **Initializer Method**: The `__init__` method is a special method called a constructor. It is called when an object is created from the class and allows the class to initialize the attributes of the object.
# - **Instance Attribute**: `self.instance_attribute` is an instance attribute, unique to each instance of the class.
# - **Method**: The `display_attributes` method is a function defined within the class that can be called on instances of the class.
# - **Creating an Instance**: `my_object = MyClass("I am an instance attribute")` creates an instance of `MyClass` with a unique instance attribute.
# - **Accessing Methods and Attributes**: `my_object.display_attributes()` calls the `display_attributes` method, which prints the class and instance attributes.
#
# #### **Dunder Methods**
#
# Dunder methods, also known as "magic methods" or "special methods," are methods in Python classes that have names surrounded by double underscores (dunder for "double underscore").
#
# **Definition:**
#
# Dunder methods are special methods in Python that allow you to define or customize how your objects interact with built-in Python operators, functions, and language constructs. They are identified by their distinctive naming convention of having two leading and two trailing underscores, like `__init__`, `__str__`, `__add__`, etc.
#
# In simpler terms:
#
# They are methods that Python automatically calls behind the scenes in response to specific operations or events. They let you hook into Python's internal machinery and define how your custom objects should behave in various situations.
#
# **Characteristics of Dunder Methods:**
#
# Naming Convention: Always start and end with two underscores (__).
# Implicit Calls: You rarely call them directly. Python calls them implicitly based on context. For example:
#
# - `__init__` is called when you create a new object instance.
#
# - `__str__` is called when you use print(your_object) or str(your_object).
#
# - `__add__` is called when you use the + operator with your object (e.g., obj1 + obj2).
#
# **Customization:** They allow you to override default behaviors and tailor how your objects work.
#
# **Operator Overloading:** They enable you to define how operators (+, -, *, /, ==, !=, <, >, etc.) work with your objects.
# Integration with Built-in Functions: They make your objects compatible with built-in functions like len(), str(), repr(), abs(), etc.
# Purpose:
#
# The primary purpose of dunder methods is to give you a great deal of control over the behavior of your objects, making them seamlessly integrate with the Python language and its features. They help you create more expressive, intuitive, and powerful classes.
#
# Example:
#
# ```python
# class MyNumber:
#     def __init__(self, value):
#         self.value = value
#
#     def __add__(self, other):
#         if isinstance(other, MyNumber):
#             return MyNumber(self.value + other.value)
#         else:
#             return MyNumber(self.value + other)
#
#     def __str__(self):
#         return f"MyNumber({self.value})"
#
#
# num1 = MyNumber(5)
# num2 = MyNumber(10)
# num3 = num1 + num2  # __add__ is called here
# print(num3)        # __str__ is called here (Output: MyNumber(15))
# ```
#
# In this example:
#
# `__init__` is the dunder method that initializes the object.
#
# `__add__` is the dunder method that defines what happens when you use the + operator with MyNumber objects.
#
# `__str__` defines how the object is represented as a string.
# By defining these dunder methods, we've customized how MyNumber objects are created, added, and displayed.
#
#
# #### Inheritance
#
# Inheritance allows a class (child class) to inherit attributes and methods from another class (parent class).
#
# ```python
# class ParentClass:
#     def __init__(self, attribute):
#         self.attribute = attribute
#
#     def display(self):
#         print(f"Attribute: {self.attribute}")
#
# class ChildClass(ParentClass):
#     def __init__(self, attribute, child_attribute):
#         super().__init__(attribute)  # Call the parent class constructor
#         self.child_attribute = child_attribute
#
#     def display_child(self):
#         print(f"Child Attribute: {self.child_attribute}")
#
# # Creating an instance of ChildClass
# child_object = ChildClass("Parent attribute", "Child attribute")
#
# # Accessing methods from both ParentClass and ChildClass
# child_object.display()
# child_object.display_child()
# ```
#
# #### Explanation
#
# - **ParentClass**: A base class with an initializer and a display method.
# - **ChildClass**: A derived class that inherits from `ParentClass` and adds an additional attribute and method.
# - **super()**: The `super()` function is used to call the constructor of the parent class.
#
# #### Encapsulation and Access Modifiers
#
# Python does not have strict access modifiers like `private`, `protected`, and `public`. However, there are naming conventions to indicate the intended visibility of attributes and methods:
#
# - **Public**: Attributes and methods that can be accessed from outside the class. (No underscores)
# - **Protected**: Attributes and methods intended for use within the class and its subclasses. (Single underscore `_`)
# - **Private**: Attributes and methods intended for use only within the class. (Double underscore `__`)
#
# ```python
# class MyClass:
#     def __init__(self):
#         self.public = "Public"
#         self._protected = "Protected"
#         self.__private = "Private"
#
#     def display(self):
#         print(f"Public: {self.public}")
#         print(f"Protected: {self._protected}")
#         print(f"Private: {self.__private}")
#
# # Creating an instance of MyClass
# obj = MyClass()
#
# # Accessing attributes
# print(obj.public)  # Public
# print(obj._protected)  # Protected (by convention, should be treated as non-public)
# # print(obj.__private)  # AttributeError: 'MyClass' object has no attribute '__private'
# obj.display()
# ```

# %% [markdown]
# #### More Examples of Dunder Methods
#
# In Python, the iteration protocol is implemented using two special (“dunder”) methods: **\_\_iter\_\_** and **\_\_next\_\_**. They allow objects to be used in contexts that expect an iterator, such as in `for` loops or with the built-in `next()` function.
#
#
# 1. **\_\_iter\_\_()**
#    - Must return an iterator object (usually `self`).
#    - Called when an iteration starts, for example in a `for` loop or by passing an object to the `iter()` function.
#
# 2. **\_\_next\_\_()**
#    - Must return the next item in the sequence.
#    - Called repeatedly to get each subsequent item in the iterator.
#    - Must raise `StopIteration` when there are no more items to return.
#
# In summary:
#
# - A class that has an **\_\_iter\_\_()** method returning an iterator object is **iterable**.
# - An **iterator** is an object that has both an **\_\_iter\_\_()** method (returning itself) and a **\_\_next\_\_()** method.
#
#
#
# **How They Are Used**
#
# When you write code like:
# ```python
# for item in some_object:
#     ...
# ```
# 1. Python calls `some_object.__iter__()` to retrieve an iterator.
# 2. It then repeatedly calls the iterator’s `__next__()` method to get items one by one.
# 3. Once the iterator’s `__next__()` method raises `StopIteration`, the `for` loop exits gracefully.
#
# Similarly, the built-in function `iter(some_object)` internally calls `some_object.__iter__()`, and `next(iterator)` internally calls `iterator.__next__()`.
#
# ---
#
# **Code Example: Building a Simple Iterator**
#
# Below is a straightforward example of a custom iterator that yields numbers from 1 up to a specified limit.
#
# ```python
# class CountUpTo:
#     def __init__(self, max):
#         self.max = max
#         self.current = 0
#
#     def __iter__(self):
#         # Return the iterator object (which is self).
#         # The iteration state is defined by self.current
#         return self
#
#     def __next__(self):
#         # Return the next item or raise StopIteration.
#         if self.current < self.max:
#             self.current += 1
#             return self.current
#         else:
#             raise StopIteration
#
# # Example usage:
# counter = CountUpTo(5)
# for number in counter:
#     print(number)
# ```
#
# **Explanation:**
#
# - **\_\_iter\_\_**: Returns `self`, because this class instance is its own iterator.
# - **\_\_next\_\_**: Increments `self.current` until it reaches `self.max`. Once `self.current == self.max`, it raises `StopIteration` to signal that the iteration is over.
# - In the `for` loop, each iteration calls `__next__()`. The items printed would be 1, 2, 3, 4, and 5.

# %% [markdown]
# #### Polymorphism Example
#
# ```python
# class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         raise NotImplementedError("Subclass must implement this method")
#
#
# class Dog(Animal):
#     def speak(self):
#         return f"{self.name} says Woof!"
#
#
# class Cat(Animal):
#     def speak(self):
#         return f"{self.name} says Meow!"
#
#
# class Cow(Animal):
#     def speak(self):
#         return f"{self.name} says Moo!"
#
#
# # Polymorphism in action
# def make_animal_speak(animal):
#     # This function works with any Animal object!
#     print(animal.speak())
#
#
# # Create instances
# animals = [
#     Dog("Buddy"),
#     Cat("Whiskers"),
#     Cow("Bessie")
# ]
#
# # Same interface, different behaviors
# for animal in animals:
#     make_animal_speak(animal)
# ```
#
# **Output:**
#
# Buddy says Woof!
#
# Whiskers says Meow!
#
# Bessie says Moo!
#
#
# Polymorphism means "many forms" - it allows objects of different classes to be treated through the same interface while maintaining their unique behaviors.
# Key points:
#
# Common interface: All animals have a ```speak()``` method
# Different implementations: Each subclass implements ```speak()``` differently
# Unified treatment: The ```make_animal_speak()``` function works with any Animal object without needing to know the specific type
# Runtime behavior: Python determines which ```speak()``` method to call based on the actual object type at runtime
#
# This is powerful because you can write code that works with the parent class type but automatically uses the correct specialized behavior for each subclass - making your code more flexible and extensible.
#
#
# #### Conclusion
#
# Classes in Python provide a way to encapsulate data and functionality together. Understanding the concepts of attributes, methods, inheritance, encapsulation, and polymorphism allows for the creation of complex and reusable code structures. By using classes, you can model real-world entities and their interactions, leading to cleaner and more maintainable code.

# %% [markdown]
# ## <font color='blue' size=5pt> Vectors and Vector Spaces </font>
#
# ### Vectors - Intuition
#
# * A vector represents a way of embedding information in an organized way that allows useful operations to be carried out. Thus, vectors represent meaningful information in a given context.
#
# * Building intuition: think of position vectors. The addition/subtraction operations can be carried out componentwise. Multiplication by scalars (e.g. real numbers) are also distributed to all of the vector's commponents.
#
#
# <figure>
# <center>
# <img src='https://i.imgur.com/hL5eCrq.png'width='350px'/>
# <figcaption>Vector Addition</figcaption></center>
# </figure>
#
# ### <font color='deepskyblue' size=5pt> Example </font>
#
# On a topographic map, "vectors" refer to the individual lines and points that represent geographical features like contour lines, rivers, roads, and boundaries, all digitally encoded using mathematical coordinates, allowing for high customization and flexibility in displaying and visualizing the map data.
#
# <figure>
# <center>
# <img src='https://i.imgur.com/5EjjqzF.jpg'width='800px'/>
# <figcaption>Topographic Map of the Continental United States </figcaption></center>
# </figure>
#
#
#
# * Example: an array of prescribed dimensionality can be regarded as a vector.
#
# * More abstract objects, such as continuous or integrable functions can be regarded as vectors, as well.
#
# ### <font color='blue' size=5pt> Vector Spaces - Formal Definition </font>
#
# A vector space $V$ is a set whose elements can be multiplied with scalars and combined among themselves by using a $"\cdot"$ and a $"+"$ operation, respectively.  These operations mentioned above, must satisfy the following properties:
#
# | **Axiom**                                                                                                                                | **Meaning**                                                                                                                                                                                                  |
# | ---------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | [Associativity](https://en.wikipedia.org/wiki/Associativity "Associativity") of vector addition                                          | **u** + (**v** + **w**) = (**u** + **v**) + **w**                                                                                                                                                            |
# | [Commutativity](https://en.wikipedia.org/wiki/Commutativity "Commutativity") of vector addition                                          | **u** + **v** = **v** + **u**                                                                                                                                                                                |
# | [Identity element](https://en.wikipedia.org/wiki/Identity_element "Identity element") of vector addition                                 | There exists an element **0**∈ _V_, called the _[zero vector](https://en.wikipedia.org/wiki/Zero_vector "Zero vector")_, such that **v** + **0** = **v** for all **v**∈ _V_.                                 |
# | [Inverse elements](https://en.wikipedia.org/wiki/Inverse_element "Inverse element") of vector addition                                   | For every **v**∈ _V_, there exists an element −**v** ∈ _V_, called the _[additive inverse](https://en.wikipedia.org/wiki/Additive_inverse "Additive inverse")_ of **v**, such that **v** + (−**v**) = **0**. |
# | Compatibility of scalar multiplication with field multiplication                                                                         | _a_(_b_**v**) = (_ab_)**v**                                                                                                    |
# | Identity element of scalar multiplication                                                                                                | 1**v** = **v**, where 1 denotes the [multiplicative identity](https://en.wikipedia.org/wiki/Multiplicative_identity "Multiplicative identity") in _F_.                                                       |
# | [Distributivity](https://en.wikipedia.org/wiki/Distributivity "Distributivity") of scalar multiplication with respect to vector addition | _a_(**u** + **v**) = _a_**u** + _a_**v**                                                                                                                                                                     |
# | Distributivity of scalar multiplication with respect to field addition                                                                   | (_a_ + _b_)**v** = _a_**v** + _b_**v**                                                                                                                                                                       |

# %% [markdown]
# ### <font color='blue' size=5pt> Linear Operators </font>
#
# Formal Definition: A mapping $T$ between two vector spaces is called linear if and only if both statements hold for any scalar $\lambda$ and any two vectors $\vec{u}$ and $\vec{w}$ from the domain of $T.$
#
# > i\. $T\left(\lambda\vec{u}\right) = \lambda T\left(\vec{u}\right)$
#
# > ii\. $T\left(\vec{u}+\vec{v}\right)=T\left(\vec{u}\right)+T\left(\vec{v}\right)$
#
# for any scaler $\lambda$ and any two vectors $\vec{u}$ and $\vec{v}.$
#
#
# An example of a linear model with three features is how you compute the final grade in a class if you know your grades from homework, midterm and the final, and also know (per class syllabus) their weights of importance.
#
#
# If $p$ features in the data and we want to create a linear model, the *input-output* mechanism is
#
# $$
# \underbrace{Y}_\text{Output}  = \underbrace{w_1 X_1+w_2 X_2+...+w_p X_p}_\text{Linear combination of features}
# $$
#
# This could represented as a matrix-vector product:
#
# $$
# \underbrace{Y}_\text{Output}  = \underbrace{X\cdot w}_\text{Linear combination of the columns of matrix X}
# $$
#
# In this model the features are $X_1, X_2, ...X_p$ and $w_1, w_2,...w_p$ are a set of weights (real numbers).

# %% [markdown]
# ## <font color='blue' size=6pt> Code Applications </font>
# ---
#
# Libraries are collections of pre-written functions that are already coded and available to be used as such.
#
# Very frequently we are going to use "numpy" for numerical calculations, "matplotlib" for plotting/graphing, "pandas" for importing/exporting data and "sklearn" for useful machine learning functions.

# %% [markdown]
# Let's create some examples in Python:
#
# <font color='deepskyblue'>**Example 1**</font> Create a function whose graph intersects the line $y=0.5$ exactly three times.
#
# *Solution:* We think of a simple possible design that accomodates the requirement such as the construct of a third degree polynomial:
#
# $$
# p(x) = (x-1)\cdot(x-2)\cdot(x-3)+0.5
# $$

# %% [markdown]
# <font color='deepskyblue'>**Example 2**</font> Create a piecewise defined function with three different cases.
#
# *Solution:* Again, we can think of a simple example such as
#
# $$
# f(x) = \begin{cases}
# x &\text{if}\,\,\,0<x<1\\
# \sqrt{x} & \text{if}\,\,\,1\leq x<2\\
# \sin(x) & \text{if}\,\,\,2\leq x \,\,\text{or}\,\, x\leq0
# \end{cases}
# $$
#
# Hint: for Python programming consider <font color='magenta'>*if*, *elif*</font> and <font color='magenta'>*else*</font> statements.

# %%
# Setup Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from sklearn.impute import SimpleImputer

# %%
# piecewise defined function
def f(x):
    if (x>0) & (x<1):
        return x
    elif (x>=1) & (x<2):
        return np.sqrt(x)
    else:
        return np.sin(x)

# %%
# How to "vectorize" a function that acts upon one scalar input (number) at a time:
g = np.vectorize(f)

# %%
f([2.3,7.1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f([2.3,7.1])
#
# Cell In[8], line 3, in f(x)
#       2 def f(x):
# ----> 3     if (x>0) & (x<1):
#       4         return x
#       5     elif (x>=1) & (x<2):
#       6         return np.sqrt(x)
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
g([2.3,7.1])
# Out:
# array([0.74570521, 0.72896904])

# %%
plt.figure(figsize=(8,5))
t = np.arange(0.0,6.0,0.01)

plt.xlim(-1, 7)
plt.ylim(-1.5, 1.5)
plt.scatter(t,g(t),marker='.',color='blue')
plt.xlabel('Input',fontsize=14)
plt.tick_params(axis='x', colors='navy')
plt.tick_params(axis='y', colors='navy')
plt.ylabel('Output',fontsize=14)
plt.grid(which='major', color ='grey', linestyle='-', alpha=0.8)
plt.grid(which='minor', color ='grey', linestyle='--', alpha=0.2)
plt.minorticks_on()
# plt.savefig("ex_fig.png",dpi=300)

# %% [markdown]
# ### <font color='blue' size=5pt> Working with Classes and Object Oriented Programming </font>
#
# A *class* in Python can be understood a blueprint for creating objects that include variables, functions, methods and good memory management.

# %% [markdown]
# ### <font color='deepskyblue' size=5pt>  Simple Examples </font>

# %%
# a very simple example
class George:
  x = 3

# %%
# what happens here?
p = George()
p.x
# Out:
# 3

# %%
p.x =5

# %%
p.x
# Out:
# 5

# %%
p1 = George()
p1.x
# Out:
# 3

# %% [markdown]
# <font color='deepskyblue'>**Example 3**</font> A simple class.

# %%
# a very simple example
class Honda:
  mileage = 37
  color = 'red'
  year = 2019
  model = 'Civic'
  def __init__(self,color,year,model,mileage):
    self.year = year
    self.model = model
    self.mileage = mileage
    self.color = color

# %%
myHonda = Honda('orange',2021,'CRV',32)

# %%
myHonda.model
# Out:
# 'CRV'

# %% [markdown]
# <font color='deepskyblue'>**Example 4**</font> A Fibonacci sequence.
#
# Iterative approach to generating the Fibonacci sequence, i.e. the sequence $(f_n)$ of integers such that $$f_0=0,\,\, f_1=1\,\,\, \text{and}\,\, f_{n+1}=f_n+f_{n-1}$$ for all $n\geq 1.$

# %%
class Fib:
  def __init__(self,a=0,b=1):
    self.a = a
    self.b = b
  def update(self):
    self.a, self.b = self.b, self.a + self.b
    self.current = self.b

# %%
myfib=Fib(a=0.2,b=1.5)

# %%
myfib.update()

# %%
myfib.current
# Out:
# 1.7

# %%
myfib.update()
myfib.current
# Out:
# 3.2

# %% [markdown]
# #### ➡️ Only in key version 👇

# %%
class Fib2:
  def __init__(self,a=0,b=1):
    self.a = a
    self.b = b
    self.max = 20
  def __iter__(self):
      return self
  def __next__(self):
    # Return the next item or raise StopIteration.
    if self.b < self.max:
        self.a, self.b = self.b, self.a + self.b
        return self.b
    else:
        raise StopIteration

# %%
myfib2 = Fib2(a=0.2,b=1.5)
for item in myfib2:
    print(item)
# Out:
# 1.7
# 3.2
# 4.9
# 8.100000000000001
# 13.000000000000002
# 21.1

# %% [markdown]
# > ➡️ Only in key version 👆

# %% [markdown]
# ### <font color='deepskyblue' size=5pt> More Examples </font>

# %% [markdown]
# #### <font color='blue'> Attributes </font>
#
# The __init__ is a method that is used to initialize attributes for a new instance of a class.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Joe", 19)

p2 = Person("Elaina",20)

# %%
p2.name
# Out:
# 'Elaina'

# %% [markdown]
# Another coding example involving iterators:

# %%
class FibNumbers:
  def __init__(self,a=1,b=2):
    self.a = a
    self.b = b

  def __iter__(self):
    return self

  def __next__(self):
    self.a, self.b = self.b, self.a + self.b
    return self.b

# %%
myclass = FibNumbers(a=2,b=3)

# %%
iter(myclass)

# %%
next(myclass)
# Out:
# 8

# %%
# what are iterators?
a = ['rose','tulip','sunflower']
for i in a:
  print(i)
# Out:
# rose
# tulip
# sunflower

# %%
myclass = FibNumbers()
myiter = iter(myclass)

# %%
next(myiter)
# Out:
# 5

# %% [markdown]
# The *self* parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# It does not have to be named *self* , you can call it whatever you like, but it has to be the first parameter of any function in the class.

# %% [markdown]
# Activity: describe in your own words what is a class in Python.

# %% [markdown]
# #### <font color='deepskyblue' size=5pt> Example: Recursive Calculations </font>

# %%
def fibonacci_of(n):
     if n in {0, 1}:  # Base case
         return n
     return fibonacci_of(n - 1) + fibonacci_of(n - 2)  # Recursive case

# %%
# %time
fibonacci_of(20)
# Out:
# CPU times: user 3 μs, sys: 1 μs, total: 4 μs
# Wall time: 6.2 μs
# 6765

# %% [markdown]
# ####  <font color='deepskyblue' size=5pt>Example: Collatz Conjecture </font>
#
# The Collatz conjecture, also known as the 3n + 1 conjecture, is a mathematical hypothesis that concerns sequences defined as follows:
#
# 1. Start with any positive integer $ n $.
# 2. If $ n $ is even, divide it by 2: $ n \to \frac{n}{2} $.
# 3. If $ n $ is odd, multiply it by 3 and add 1: $ n \to 3n + 1 $.
# 4. Repeat the process indefinitely with the resulting value.
#
# The conjecture states that no matter what initial value of $ n $ is chosen, the sequence will eventually reach the number 1. Once it reaches 1, it will enter the repeating cycle of 1, 4, 2, 1.
#
# Despite its simple definition, the Collatz conjecture remains unproven. It has been tested for very large numbers using computers, and no counterexamples have been found. However, a general proof for all positive integers is still elusive, making it one of the most famous unsolved problems in mathematics.

# %%
# example with classes
class collatz:
    # attributes initialization
    def __init__(self,x=1):
        self.x = x
    # method definition
    def f(self):
        if self.x%2 == 0:
            return self.x/2
        else:
            return 3*self.x+1
    def __iter__(self):
        return self
    def __next__(self):
        self.x = self.f()
        return self.x

# %%
myclass = collatz(x=233471)

# %%
# i is a counter variable
i = 1
while next(myclass)>1:
    i += 1
print('The Collatz conjecture worked in: '+str(i),' iterations.')
# Out:
# The Collatz conjecture worked in: 75  iterations.

# %% [markdown]
# ### <font color='blue' size=5pt> Scikit-learn Functions and Classes</font>
#
# Most of the functions included in the Scikit-learn libary offer classes that have a peculiar syntax in applications:
#
#
#
# <figure>
# <center>
# <img src='https://i.imgur.com/sRCl1yw.png'width='400px'/>
# <figcaption>Using Scikitlearn Functions </figcaption></center>
# </figure>

# %% [markdown]
# ### <font color='blue' size=5pt> Features and Independent Variables </font>
#
# What is a feature?
# 	- A feature is something you are going to use to predict a dependent or response variable.
#
# What is a feature matrix?
# 	- A feature matrix is a matrix of all the features you are going to use to make the prediction.
#
# What is an independent variable?
# 	- A different word for a feature.
#
# What is the goal? We want to combine features in a functional way so we need some form of scaling (standardization) in order to perform operations with *fruit of the same kind* such as euclidean distance calculations, etc.
#
# The idea is that we cannot add directly *meters* and *feet* and therefore we need a scaling in the same metric.

# %% [markdown]
# ### <font color='blue' size=5pt> Vectors in Python: NumPy Arrays </font>
#
# If we keep appending values to an empty array we obtain an array whose length is equal to the number of values we appended.
#
# If we need to add or subtract the corresponding entries of two arrays, or multiply all the entries by a scaler, we actually need to convert the arrays into vectors.

# %%
a = [2,3,4]
b = [-2,3,8]
a+b # comment on whether the output is what you expected
# Out:
# [2, 3, 4, -2, 3, 8]

# %%
# here numpy arrays work like vectors
av = np.array(a)
bv = np.array(b)
av+bv
# Out:
# array([ 5,  6, 13])

# %% [markdown]
# ### <font color='blue' size=6pt>  Scaling Data </font>
#
# <font color='red'> IMPORTANT: If we have to perform calculations with values from different features we must consider scaling the data on the same metric, i.e. we want to add apples to apples.</font>
#
# The are many different techniques for data standardization. We can scale numerical values by using:
#
#   - z-scores: $\frac{x-\mu}{\sigma}$ where $\mu$ is the mean and $\sigma$ is the standard deviation.
#   - quantiles: every data point is replaced by its percentile within the feature column.
#   - division by max: $\frac{x}{\max{(x)}}.$
#   - 0 to 1 scaling: $\frac{x-\min{(x)}}{\max{(x)}-\min{(x)}}.$
#   - "traditional" standardization (e.g. old HDI): $\frac{\max{(x)}-x}{\max{(x)}-\min{(x)}}.$
#   Example: Life Expectancy Index has minimum age as 25 and maximum age as 85.
# Formula of LEI in old method of Human Development Index (HDI) = Life expectancy – 25/ 85 – 25.
#   - division by the range.
#   - division by the standard deviation.
#   - proportion of external indicator (i.e. in terms of a predefined metric).
#
#   ### <font color="green"> Practical exercise: write your own Python functions to implement the different standardization techniques </font>

# %% [markdown]
# ### <font color='blue'> Example: z-Scores </font>
#
# A z-score means a number of standard deviations above or below average. It is meaningful because of the density of the observations, within $k$ standard deviations around the mean we have at least $(1-\frac{1}{k^2})\%$ of the whole data.
#
# That is to say, for example, regardless of the data distribution if we look at the interval of three standard deviations around the mean, we have at least $1-\frac{1}{3^2}\approx 88.88\%$ of the data points.
#
# <font color='red'>For easy applications we can use a SKLearn library function such as *StandardScaler*.</font>
#
# The anatomy of application for SKLearn functions:
#
#
#
# <figure>
# <center>
# <img src='https://i.imgur.com/J0Hr3tr.png'width='300px'/>
# <figcaption></figcaption></center>
# </figure>

# %% [markdown]
# ### <font color='blue' size=6pt> Data from URL </font>

# %%
# the data is accessible via free github
url = 'https://github.com/datasciencedojo/datasets/blob/master/titanic.csv?raw=true'

titanic = pd.read_csv(url)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Load a regression dataset, i.e. https://archive.ics.uci.edu/ml/datasets/Concrete+Compressive+Strength
df = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/concrete/compressive/Concrete_Data.xls')

# %%
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
X = df.drop('Concrete compressive strength(MPa, megapascals) ',axis=1)
X
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
# we get the input and the output as numerical arrays
y = df['Concrete compressive strength(MPa, megapascals) '].values
Xv = df.loc[ : , df.columns != 'Concrete compressive strength(MPa, megapascals) '].values

# %%
url = 'https://github.com/dvasiliu/AML/blob/main/Data%20Sets/PrelimData.csv?raw=true'
data = pd.read_csv(url)

# %% [markdown]
# ### More Complex Datasets
#
# https://archive.ics.uci.edu/ml/datasets/heart+Disease
#
# https://github.com/LucDemortier/HeartDiseaseStudy

# %%
# back to PrelimData.csv example
data
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0    NaN  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore   NaN  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0    NaN  Yes
# 18     Senior  25.0    NaN  Yes
# 19     Senior  41.0    NaN  Yes
# 20  Sophomore   NaN  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No

# %% [markdown]
# A different way to append:

# %%
data.append({'Class':'Sophomore','Age':19,'Funds':560,'Sale':'No'},ignore_index=True)
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0    NaN  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore   NaN  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0    NaN  Yes
# 18     Senior  25.0    NaN  Yes
# 19     Senior  41.0    NaN  Yes
# 20  Sophomore   NaN  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No
# 24     Junior  21.0  510.0   No
# 25  Sophomore  19.0  560.0   No

# %% [markdown]
# ### <font color='blue' size=6pt> Missing Values </font>
#
# The entries "NaN" represent missing values.
# ```python
# mydata.iloc[:15]
# ```
#
# When data has missing values we generally have two choices: drop the rows (observations) that have missing entries or run an imputation for replacing the entries containing NaNs with some reasonable ones (in the context).
#
# Here "the context" refers to the type of variable that had missing entries in the data recorded.
#
# ```{python, size="tiny",echo=TRUE}
# mycleandata = mydata.dropna()
# ```
# The new data frame created "mycleandata" has no NaN entries. Thus appending a data frame name with ".dropna()" has the effect of dropping all rows that containn at least one "NaN" entry.
#
# ```{python, size="tiny",echo=FALSE}
# mycleandata.iloc[:15]
# ```
# The rows containing at least one "NaN" entry have been dropped.

# %%
dat1 = data.dropna().copy()

# %%
data
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0  500.0  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore   NaN  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0    NaN  Yes
# 18     Senior  25.0    NaN  Yes
# 19     Senior  41.0    NaN  Yes
# 20  Sophomore   NaN  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No
# 25  Sophomore  20.0  489.0  Yes
# 24     junior  21.0  510.0   No

# %% [markdown]
# ### <font color='blue' size=5pt> Data Imputations </font>
#
# Imputations can be implemented based on different concepts, such as mean/median values, most frequent values, interpolation, k-nearest neighbours, multivariate imputation by chained equation (MICE), etc.
#
# ### <font color='green'> Example of coding: </font>
#
#
# ```python
# import numpy as np
# import pandas as pd
# from sklearn.impute import SimpleImputer
# data = pd.read_csv("L1Data.csv")
# imputing_configuration = SimpleImputer(missing_values = np.nan, strategy = 'mean')
# imp = imputing_configuration.fit(data[["Funds"]])
# # The following replaces the NaNs in the "Funds" column with the mean value
# data[["Funds"]] = imp.transform(data[["Funds"]]).ravel()
# ```

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# %%
# here we provide a new name to the combination of the function from sklearn and the choice of hyperparameters
imputing_config = SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
data
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0    NaN  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore   NaN  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0    NaN  Yes
# 18     Senior  25.0    NaN  Yes
# 19     Senior  41.0    NaN  Yes
# 20  Sophomore   NaN  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No

# %%
# we are fitting our imputer on the subset of seniors
imp1 = imputing_config.fit(data.loc[data.Class=="Senior",["Funds"]])

# %%
# we can also use the whole data, not just the subset of seniors
imp2 = imputing_config.fit(data.loc[:,["Funds"]])

# %%
#imp = imputing_config.fit(data[["Age"]])

# %%
data[["Funds"]] = imp1.transform(data[["Funds"]])

# %%
data
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0  625.0  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore   NaN  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0  625.0  Yes
# 18     Senior  25.0  625.0  Yes
# 19     Senior  41.0  625.0  Yes
# 20  Sophomore   NaN  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No

# %%
# create an imputer for the 'Age' column
imp3 = SimpleImputer(missing_values=np.nan,strategy="median")

# %%
data.loc[data.Class=='Sophomore',['Age']]=imp2.fit_transform(data.loc[data.Class=='Sophomore',['Age']])

# %%
data.loc[:,['Age']] = imp3.fit_transform(data.loc[:,['Age']])

# %%
data
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0  625.0  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore  21.0  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0  625.0  Yes
# 18     Senior  25.0  625.0  Yes
# 19     Senior  41.0  625.0  Yes
# 20  Sophomore  21.0  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No

# %% [markdown]
# Subsetting a dataframe

# %%
data.loc[data.Class=="Sophomore",:]
# Out:
#         Class   Age  Funds Sale
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 12  Sophomore   NaN  500.0   No
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 20  Sophomore   NaN  500.0   No

# %%
data.loc[data.Class=="Sophomore",["Age"]]=imp.transform(data.loc[data.Class=="Sophomore",["Age"]])

# %%
data.loc[data.Class=="Sophomore",:]
# Out:
#         Class   Age  Funds Sale
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 12  Sophomore  22.0  500.0   No
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 20  Sophomore  22.0  500.0   No

# %% [markdown]
# - There are no more "NaNs" in the "Funds" column.
# - What method of imputation would be appropriate for the "Age" column?

# %% [markdown]
# ### <font color='blue'> Dealing with Discrete (nominal) data </font>
#
# As you saw in this data set we have discrete nominal data, however computers really prefer numbers. In the following example we demonstrate how to transform such discrete data into contextually meaningful, numerical values:
#
# ```python
# from sklearn.preprocessing import LabelEncoder
# discreteCoder = LabelEncoder()
# data[["Sale"]] = discreteCoder.fit_transform(data[["Sale"]]).ravel()
# ```
#
# In the "Sale" column the entries with "No" were replaced with $0$ and the entries with "Yes" were replaced with $1$.
#
# For providing numerical entries to the "Class" column we can use the same ***discreteCoder***
#
# Another option is to change the column of "Class" into $n$ columns that have entries of $0$ or $1$, for example "Sophomore" would be represented as a 4-tuple: $(0,1,0,0).$ In our data we have $n=4$ because the "Class" column had $4$ different categories.

# %% [markdown]
# The code is simple:
# ```python
# data[["Class"]] = discreteCoder.fit_transform(data[["Class"]]).ravel()
# ```

# %% [markdown]
# ```python
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import ColumnTransformer
#
# ct = ColumnTransformer(
#     [('one_hot_encoder', OneHotEncoder(categories='auto'), [0])],
#     remainder='passthrough')
# datamod = np.array(ct.fit_transform(data))
# datamod[0:5,:]
# ```
