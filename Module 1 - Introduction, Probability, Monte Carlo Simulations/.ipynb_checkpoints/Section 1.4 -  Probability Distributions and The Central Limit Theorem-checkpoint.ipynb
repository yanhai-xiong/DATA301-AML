# %% [markdown]
# <div style="text-align: center; padding-top: 12%;">
#
# # Probability Distributions and The Central Limit Theorem
#
# ## DATA 301 @ WM
#
# </div>
#
# A brief overview of key concepts

# %% [markdown]
# ## <font color='blue'>Probability Density Functions</font>
#
# A **probability density function (PDF)** is a function that describes the relative likelihood of a continuous random variable taking on a specific value. It is used to characterize the distribution of probabilities across the possible values of the random variable.

# %% [markdown]
# ### Important Properties:
# - **Non-Negativity**: The value of the PDF is always non-negative for all possible values of the random variable:
#    $$
#    f(x) \geq 0 \quad \forall \, x
#    $$
# - **Normalization**: The total area under the curve of the PDF over all possible values of the random variable is equal to 1, ensuring it represents a valid probability distribution:
#    $$
#    CDF(x)=\int_{-\infty}^{\infty} f(x) \, dx = 1
#    $$
# - **Probability Interpretation**: The probability that the random variable $ X $ falls within a particular range $[a, b]$ is given by the integral of the PDF over that range:
#    $$
#    P(a \leq X \leq b) = \int_{a}^{b} f(x) \, dx
#    $$
#
# That is to say the area under the graph of the density function when $X$ is between $a$ and $b.$ The integral sign means **accumulation** or **sum** of all frequencies over a given interval.

# %% [markdown]
# ## <font color='blue'> Normal Distribution</font>
#
# The probability distribution function of a normal density curve with mean μ and standard deviation σ at a given point x is given by:
# $$\large f(x):=\frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}$$
#
# If the mean is 0 and the standard deviation is 1 then the probability density function is:
# $$\large f(x):=\frac{1}{\sqrt{2\pi}}e^{-\frac{x^2}{2}}$$

# %% [markdown]
# Normal Distribution, also known as Gaussian distribution, is ubiquitous in Data Science. You will encounter it at many places especially in topics of statistical inference. It is one of the assumptions of many data science algorithms too.
#
# A normal distribution has a bell-shaped density curve described by its mean μ and standard deviation σ. The density curve is symmetrical, centered about its mean, with its spread determined by its standard deviation showing that data near the mean are more frequent in occurrence than data far from the mean.

# %% [markdown]
# ## <font color='blue'> $\chi^2$ (Chi-Square) Distribution </font>
# Chi-square distribution actually comes from $Z_1, ..., Z_k \sim N(0,1)$, then
# $$
# \sum Z_i^2 = Z_1^2 + ... Z_n^2 \sim \chi_n^2
# $$
#
# Since $Z_i = \frac{X_i - \mu}{\sigma}$, the chi-square distribution is useful for modeling the distribution of the **sample variance for normally distributed random variables**.
# Sample variance:
# $$S^2=\large \frac{\sum\limits_{i=1}^{n}(X_i-\bar{X})^2}{n-1}$$
#
# Thus $$\sum Z_i^2 = \frac{(X_i-\mu)^2}{\sigma^2} \sim \chi_n^2$$
#
# and by estimating $\mu$ using $\bar{X}$, the degree of freedom $-1$, then $$\frac{(X_i-\bar{X})^2}{\sigma^2}= \frac{S^2(n-1)}{\sigma^2} \sim \chi_{n-1}^2$$

# %% [markdown]
# Each sample is a collection of the values $X_1,X_2,X_3,...X_n$ and  $\bar{X}$ is the mean of the sample.

# %% [markdown]
# ### PDF
# For $n$ degrees of freedom, the $\chi^2$ probability distribution function is:
# $$\large f(x):=\begin{cases} \frac{1}{2^{\frac{n}{2}}\Gamma\left(\frac{n}{2}\right)} x^{\frac{n}{2}-1}e^{-\frac{x}{2}} &\text{if}& x\geq 0 \\
# 0 &\text{if}& x<0. \end{cases}$$
# where $\large \Gamma(x)=\int\limits_{0}^{\infty}x^{n-1}\cdot e^{-x}dx$. For positive integers we have $\large Γ(n)=(n-1)!$

# %% [markdown]
# ### Illustration
# ![](https://assets.insightmediagroup.io/media/wp-content/uploads/2024/06/03IEsJ5bq7qMzVC44-1.png)

# %% [markdown]
# ### Chi-Square test
#
# The chi-square distribution allows us to make statistical inferences about the population variance $\sigma^2$ using the observed sample variance $S^2$.
#
# 1. State the hypotheses
#     - $H0: σ^2=σ_0^2$
#     - $H1: σ^2\neqσ_0^2$
# 1. Choose the significance level, such as $\alpha=0.05$
# 1. Calculate the sample variance $S^2$ from $n$ observations.
# 1. Calculate the chi-square test statistic: $\chi^2_{obs} = \frac{(n-1)S^2}{σ_0^2}$
# 1. Determine the degrees of freedom $df=n-1$.
# 1. Use the $\chi^2_{n-1}$ distribution to determine how unusual the observed statistic is under $H_0$ using the p-value.
# 1. Make decision:
#     - $p<\alpha$ Reject H0
#     - $p\geq \alpha$ Fail to reject H0

# %% [markdown]
# ## <font color='blue'> Poisson Distribution </font>
#
# Poisson random variable is typically used to model **the number of times an event happened in a fixed time interval or space**. For example, *the number of users visited on a website in an interval*.
# - The Poisson distribution is characterized by a single parameter, $\lambda$, representing the **average number of events** expected in the specified interval.
# - If $X\sim Poisson(\lambda)$, $X$ can be 0, 1, 2, … times in an interval.
# - The probability of observing k events in an interval is modeled by the equation:
# $$\large P(k \text{ events in an interval}):=e^{-\lambda}\frac{\lambda^k}{k!}$$
# - The mean and variance are both λ: $E[X]={Var}[X]=\lambda$

# %% [markdown]
# ### Illustration
# ![image](https://media.geeksforgeeks.org/wp-content/uploads/20231129155402/poisson-distribution.webp)

# %% [markdown]
# ## <font color='blue'> Gamma Distribution </font>
#
# The gamma distribution is a **two-parameter** family of continuous probability distributions. **Exponential**, **chi-squared**, **erlang** distributions are *special cases* of the gamma distribution.
# - The gamma distribution can be parameterized in terms of a shape parameter α=k and an inverse scale parameter β=1/θ, called a rate parameter.
#
# The probability distribution function is:
# $$\large f(x,\alpha,\beta):=\frac{\beta^\alpha}{\Gamma(\alpha)} x^{\alpha-1}e^{-\beta x}, x, \alpha , \beta>0$$
# - the notation $Γ(\alpha)$ represents the gamma function and is defined as $\alpha−1$!

# %% [markdown]
# ### Illustration
# ![image](https://www.exceltip.com/wp-content/uploads/2020/06/pasted-image-0-5-25.png)

# %% [markdown]
# ### Rationale and Uses
# > **Gamma distribution**: The mathematical consequence of adding together independent waiting times or multiplying independent random shocks
#
# Common Uses and Examples:
# - Waiting and Service Times (the time it takes for a specific number of events, e.g. the 3rd customer arriving or the 2nd machine failure, to occur in a Poisson process)
# - Climatology (the amount of rainfall or total water volume in a given period)
# - Business and Insurance (the size or frequency of insurance claims and customer wait times)
# - Reliability and Life Testing (the lifespan of electrical or mechanical equipment before failure)
# - Bayesian Statistics (as a conjugate prior distribution to update probabilities efficiently when working with rate or scale parameters)

# %% [markdown]
# ## <font color='blue'> Beta Distribution </font>
#
# The beta distribution is also a two-parameter family of continuous probability distributions with the following probability density function:
# $$\large f(x,\alpha,\beta):= \frac{\Gamma(\alpha+\beta)}{\Gamma(\alpha)\Gamma(\beta)}x^{\alpha-1}\cdot(1-x)^{\beta-1}$$
# - $\Gamma$ is the Gamma function
# - $E[X] = \frac{\alpha}{\alpha+\beta}$
# - useful for modeling probabilities, proportions, and rates
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Beta_distribution_pdf.svg/330px-Beta_distribution_pdf.svg.png?utm_source=en.wikipedia.org&utm_campaign=parser&utm_content=thumbnail)

# %% [markdown]
# ## <font color='blue'> Exponential Distribution </font>
#
# The exponential distribution describes the time between events in a Poisson point process, i.e., a process in which events occur continuously and independently at a constant average rate.
# - The distribution has a parameter λ called rate parameter.
# - Its probability density function is:
# $$\large f(x,\lambda):=\begin{cases} \lambda e^{-\lambda x} &\text{if}& x\geq 0 \\
# 0 &\text{if}& x<0. \end{cases}$$
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Exponential_distribution_cdf_-_public_domain.svg/330px-Exponential_distribution_cdf_-_public_domain.svg.png?utm_source=en.wikipedia.org&utm_campaign=parser&utm_content=thumbnail)

# %% [markdown]
# ## Compare Distributions
# <div style="max-height: 65vh; overflow-y: auto;">
#
# <table>
# <thead>
# <tr>
# <th>Distribution</th>
# <th>Type</th>
# <th>Range</th>
# <th>Parameters</th>
# <th>Mean</th>
# <th>Variance</th>
# <th>What Does It Model?</th>
# <th>Example</th>
# </tr>
# </thead>
#
# <tbody>
# <tr>
# <td><b>Normal</b></td>
# <td>Continuous</td>
# <td>$(-\infty,\infty)$</td>
# <td>$\mu,\sigma$</td>
# <td>$\mu$</td>
# <td>$\sigma^2$</td>
# <td>Continuous measurements centered around a mean</td>
# <td>Heights, measurement errors, noise</td>
# </tr>
#
# <tr>
# <td><b>Chi-square</b></td>
# <td>Continuous</td>
# <td>$[0,\infty)$</td>
# <td>$k$ (df)</td>
# <td>$k$</td>
# <td>$2k$</td>
# <td>Sum of squared standard normal variables; variance-related statistics</td>
# <td>Testing population variance</td>
# </tr>
#
# <tr>
# <td><b>Poisson</b></td>
# <td>Discrete</td>
# <td>$0,1,2,\ldots$</td>
# <td>$\lambda$</td>
# <td>$\lambda$</td>
# <td>$\lambda$</td>
# <td>Number of events in a fixed interval</td>
# <td>Website visits per minute</td>
# </tr>
#
# <tr>
# <td><b>Exponential</b></td>
# <td>Continuous</td>
# <td>$[0,\infty)$</td>
# <td>$\lambda$</td>
# <td>$1/\lambda$</td>
# <td>$1/\lambda^2$</td>
# <td>Waiting time until the next event</td>
# <td>Time until next visitor</td>
# </tr>
#
# <tr>
# <td><b>Gamma</b></td>
# <td>Continuous</td>
# <td>$[0,\infty)$</td>
# <td>$\alpha,\lambda$</td>
# <td>$\alpha/\lambda$</td>
# <td>$\alpha/\lambda^2$</td>
# <td>Waiting time until multiple events</td>
# <td>Time until the 5th visitor</td>
# </tr>
#
# <tr>
# <td><b>Beta</b></td>
# <td>Continuous</td>
# <td>$[0,1]$</td>
# <td>$\alpha,\beta$</td>
# <td>$\alpha/(\alpha+\beta)$</td>
# <td>
# $\frac{\alpha\beta}
# {(\alpha+\beta)^2(\alpha+\beta+1)}$
# </td>
# <td>Probabilities and proportions</td>
# <td>Unknown purchase probability</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# ## <font color='blue' size=5pt> The Central Limit Theorem </font>
#
# In many situations, when independent random variables are added, their properly normalized sum tends toward a normal distribution (informally a bell curve) **even if the original variables themselves are not normally distributed**.
#
# - $n$ refers to the sample size
# - $X_1, X_2, X_3...X_n$ are independently sampled values from the same distribution with mean $\mu$ and standard deviation $\sigma$
# - Then the sample mean $\bar{X}$ is almost following a normal distribution if $n$ is big enough
# - That normal distribution has mean $\mu$ and standard deviation $\frac{\sigma}{\sqrt{n}}$
#
# Why useful:
# - In real-world problems, we often don't know the population distribution
# - But if we have a sufficiently large random sample, the CLT tells us that the sample mean behaves approximately normally
# - Once we have an approximately normal sampling distribution, we can calculate probabilities, construct confidence intervals, and perform hypothesis tests
# - 👆one major reason the normal distribution appears everywhere in statistics

# %% [markdown]
# ## CLT vs. Law of Large Numbers
# - $LLN: \bar{X} → μ$: where the sample mean goes as n increases
# - $CTL: \frac{\bar{X}-\mu}{\sigma/\sqrt{n}} \sim N(0,1) $: how the sample mean fluctuates around μ
#
# **Why is Gaussian noise so common?**
# > A measurement error is often the sum of many small independent sources of error. By the **Central Limit Theorem**, their combined effect tends to be approximately normally distributed.

# %% [markdown]
# ## <font color='blue'> Code Applications </font>
# ---

# %%
# Setup Libraries
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# this is for displaying plots with high resolution
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(color_codes=True)

from scipy import stats # helps with many distribution functions
from scipy.stats import beta, gamma, expon, poisson, uniform, norm, chi2
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# %%
# useful class for the visualization of the frequencies
class distribution_plot:
  def __init__(self,dist,bins=11,hist_color='lightblue',pdf_color='red',fill_region=False,fill_color='lightgreen',fill_bounds=[-1,1],edge_color='k',lw_pdf=2):
    self.dist = dist
    self.bins = bins
    self.hist_color = hist_color
    self.pdf_color = pdf_color
    self.edgecolor = edge_color
    self.lw_pdf = lw_pdf
    self.fill_region = fill_region
    self.fill_color = fill_color
    self.fill_bounds = fill_bounds


  def fit(self,data):
    fig, ax = plt.subplots(figsize=(6, 5))
    # Create the histogram
    sns.histplot(data,
                bins=self.bins,
                kde=False,
                color=self.hist_color,
                alpha=0.5,
                edgecolor=self.edgecolor,
                ax=ax)

    # Calculate the parameters for the normal distribution fit
    params = self.dist.fit(data)

    # Create the x values for the normal distribution curve
    xmin, xmax = ax.get_xlim()
    x = np.linspace(xmin, xmax, 100)

    # Calculate the y values for the normal distribution curve
    p = self.dist.pdf(x, *params)

    # Plot the normal distribution curve, scaling it to the histogram
    # We need to scale it because histplot uses counts, while norm.pdf is a density
    scale_factor = len(data) * (xmax - xmin) / self.bins # Approximate bin width
    ax.plot(x, p * scale_factor, 'r', linewidth=self.lw_pdf)

    ax.set_xlabel('Random Variable', fontsize=16)
    ax.set_ylabel('Frequency', fontsize=16)
    ax.set_title('Data Distribution', fontsize=16)
    if self.fill_region:
      l = ax.lines[0]
      xx = l.get_xydata()[:,0]
      yy = l.get_xydata()[:,1]
      ax.fill_between(xx,yy, where=(self.fill_bounds[0]<=xx) & (xx <= self.fill_bounds[1]), color=self.fill_color,alpha=0.5)

    # plt.savefig('example_distribution.png',dpi=300)
    plt.show()

# %% [markdown]
# ### <font color='blue'>Visualize Distributions of Random Variables</font>

# %%
# how to sample from a known distribution
x = stats.uniform.rvs(size=10000,loc=1,scale=9)

# %%
plt.hist(x)
plt.show()

# %%
# uniform distribution
# Generate random values
n = 20000
a = -3
b = 7
data_uniform = uniform.rvs(size=n, loc = a, scale=b) # this is the actual sampling
show_dist = distribution_plot(uniform,fill_region=True,bins=13,pdf_color='red')
show_dist.fit(data_uniform)

# %%
data_uniform[:10]
# Out:
# array([-2.885215, -0.478687, -0.365932, 3.649197, 2.529673, 3.358090,
#        -1.731386, 1.628888, 0.415970, -2.979513])

# %% [markdown]
# ### Example: suppose we want to evaluate the probability that the random variable is between 0 and 0.25.
#
# $$P(0<X<0.25) = \frac{0.25-0}{3}=\frac{0.25}{3}$$

# %%
n=2500
new_data = uniform.rvs(size=n, loc = -1, scale=3)

# %%
new_data
# Out:
# array([-0.912875, 0.565189, -0.019549, ..., 0.588230, 0.152913, 0.501046])

# %%
idx = ((new_data>=0) & (new_data<0.25))

# %%
idx
# Out:
# array([False, False, False, ..., False,  True, False])

# %%
# here we can count how many hits we got inside of the prescribed interval
count = sum((idx==True))

# %%
# so the probability that the random variable is between 0 and 0.1 is estimated as
count/n
# Out:
# np.float64(0.078)

# %%
# the theoretical value would be
0.25/3
# Out:
# 0.08333333333333333

# %% [markdown]
# **Exercise:** What is the exact value for $P(0<X<0.1)?$

# %% [markdown]
# **Exercise:** What is the function $f$ for a uniform distribution? How can we find the probability that $a<X<b$ given two values $a$ and $b$?
#
# Let's have an example with the **uniform** distribution:

# %%
n = 2000
a = 0
b = 5
data_uniform = stats.uniform.rvs(size=n, loc = a, scale=b)
show_dist = distribution_plot(uniform,bins=11,pdf_color='red')
show_dist.fit(data_uniform)

# %% [markdown]
# Now we compute
#
# $$\large P\left( a<X<b\right)$$
#
# by using a Monte Carlo simulation (experimental probability)

# %%
n = 1000000
rv = uniform.rvs(size=n, loc = -1, scale=4)

# %%
count = ((rv>=0) & (rv<=1.5)) + 0

# %%
sum(count)/n
# Out:
# np.float64(0.375227)

# %%
15/40
# Out:
# 0.375

# %% [markdown]
# ### Example with Normal Distributions

# %%
# generate random numbers from N(mu,sigma)
data_normal = norm.rvs(size=2000,loc=2,scale=1.5) # here for the normal loc means mean and scale means standard deviation
# then we want to display the histogram and the fit of the underlying distribution:
show_dist = distribution_plot(norm,bins=11,pdf_color='red')
show_dist.fit(data_normal)

# %%
n=1000
X = norm.rvs(size=n,loc=-3,scale=10,random_state=1234)

# %%
np.std(X)
# Out:
# np.float64(9.730661993772294)

# %%
# inclass problem: compute the probability for the above distribution that X is between -21 and -13
sum((X>-21)&(X<-13))/n
# Out:
# np.float64(0.106)

# %%
sum((X>-2)&(X<0))/n # experimental probability
# Out:
# np.float64(0.091)

# %%
n = 10
X = norm.rvs(size=n,loc=5,scale=3,random_state=310)

# %%
X
# Out:
# array([6.606036, 8.034690, 5.216903, 5.932330, 2.935562, 8.118571,
#        5.532380, 3.540298, 3.292948, 5.149627])

# %% [markdown]
# ### Example with the $\chi$-squared distribution

# %%
#x-axis ranges from 0 to 20 with .001 steps
x = np.arange(0, 20, 0.001)

#define multiple Chi-square distributions
plt.plot(x, chi2.pdf(x, df=3), label='df: 3')
plt.plot(x, chi2.pdf(x, df=4), label='df: 4')
plt.plot(x, chi2.pdf(x, df=8), label='df: 8')
plt.plot(x, chi2.pdf(x, df=12), label='df: 12')

#add legend to plot
plt.legend()
plt.show()

# %%
# example with gamma distribution
data_gamma = gamma.rvs(a=1.5,loc=5,scale=2, size=10000)
# here "scale" means 1/beta
# then we want to display the histogram and the fit of the underlying distribution:
show_dist = distribution_plot(gamma,bins=13,pdf_color='red')
show_dist.fit(data_gamma)

# %% [markdown]
# ### Example with Beta Distributions

# %%
data_beta = beta.rvs(a=1.2,b=2.45,loc=-5,scale=12, size=5000)
# a and b are the alpha and beta parameters
# then we want to display the histogram and the fit of the underlying distribution:
show_dist = distribution_plot(beta,bins=13,pdf_color='red')
show_dist.fit(data_beta)

# %%
beta.fit(data_beta)
# Out:
# (np.float64(1.1798727458154818),
#  np.float64(2.376618654079806),
#  np.float64(-4.991644631024412),
#  np.float64(11.80778871651695))

# %% [markdown]
# ### Example with Exponential Distributions

# %%
data_expon = expon.rvs(scale=0.2,loc=0,size=1000)
# then we want to display the histogram and the fit of the underlying distribution:
show_dist = distribution_plot(expon,bins=13,pdf_color='red')
show_dist.fit(data_expon)

# %% [markdown]
# ### Numerical confirmation of the Central Limit Theorem

# %%
data_beta = beta.rvs(a=1.7,b=1.2,loc=-3,scale=2, size=10000)
# a is alpha and b is beta
# then we want to display the histogram and the fit of the underlying distribution:
show_dist = distribution_plot(beta,bins=15,pdf_color='red')
show_dist.fit(data_beta)

# %%
population = data_beta

# %%
# we want to simulate many simple random samples
samples = [np.random.choice(population,30,replace=False) for _i in range(200)]

# %%
# here we want to get the sample means
# one way to do that is to make samples a 2-dimensional array
means = np.mean(np.array(samples),axis=1)

# %%
show_dist = distribution_plot(norm,bins=11,pdf_color='red')
show_dist.fit(means)
