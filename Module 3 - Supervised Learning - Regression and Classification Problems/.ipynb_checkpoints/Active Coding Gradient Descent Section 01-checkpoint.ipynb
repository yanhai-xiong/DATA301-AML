# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/1m/2d5xq3d16t31xt6lgcqz8wlm0000gq/T/ipykernel_34704/2080034654.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 22, in <module>
#     from pandas.compat import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/compat/__init__.py", line 29, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/compat/pyarrow.py", line 12, in <module>
#     import pyarrow as pa
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/1m/2d5xq3d16t31xt6lgcqz8wlm0000gq/T/ipykernel_34704/2080034654.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 27, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 65, in <module>
#     from pandas.core import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 9, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 55, in <module>
#     from pandas.core.computation import expressions
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 23, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 158, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/1m/2d5xq3d16t31xt6lgcqz8wlm0000gq/T/ipykernel_34704/2080034654.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 27, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 79, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 56, in <module>
#     from pandas.core import (
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 54, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 158, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/yanhaixiong/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
# get some real data to play with for gradient descent
data = pd.read_csv('https://github.com/yanhai-xiong/DATA301-AML/blob/main/Data%20Sets/Advertising.csv?raw=true')

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ## The Main Goal
#  Determine the weights for TV, Radio and Newspaper advertising to predict the Sales. We want to minimize the sum of squared errors by applying gradient descent.

# %%
y = data['Sales'].values
x = data.loc[:,['TV','Radio','Newspaper']].values

# %% [markdown]
# We want to predict $y$ by using
# $$w_0\cdot 1 + w_1\cdot \text{TV} + w_2\cdot \text{Radio} +w_3\cdot \text{Newspaper}$$

# %%
def zscore(x):
  return (x-np.mean(x))/np.std(x)

# %%
x_scaled = zscore(x)

# %%
# we can use a bias term or we can center y
# to generate a bias term we need to augment x by including a columns of 1s
x_aug = np.column_stack([np.ones(len(x)),x_scaled])

# %%
x_aug
# Out:
# array([[ 1.00000000e+00,  2.12559023e+00, -3.79832818e-01,
#          2.92690218e-02],
#        [ 1.00000000e+00, -2.92540387e-01, -3.60289737e-01,
#         -2.84723155e-01],
#        [ 1.00000000e+00, -6.48224471e-01, -2.74300178e-01,
#          3.05718939e-02],
#        [ 1.00000000e+00,  1.10153276e+00, -3.34232295e-01,
#         -1.10138293e-01],
#        [ 1.00000000e+00,  1.48327429e+00, -7.31608286e-01,
#         -1.11441165e-01],
#        [ 1.00000000e+00, -7.58968600e-01, -2.35214015e-01,
#          1.04835604e-01],
#        [ 1.00000000e+00, -1.23167014e-01, -4.44976423e-01,
#         -5.66143529e-01],
#        [ 1.00000000e+00,  6.93733794e-01, -6.16955541e-01,
#         -7.21185309e-01],
#        [ 1.00000000e+00, -7.60271472e-01, -8.44958158e-01,
#         -8.59289751e-01],
#        [ 1.00000000e+00,  1.73081999e+00, -8.38443798e-01,
#         -5.96109587e-01],
#        [ 1.00000000e+00, -1.11200134e-02, -7.96751891e-01,
#         -5.57023424e-01],
#        [ 1.00000000e+00,  1.92494793e+00, -5.59629168e-01,
#         -8.20203588e-01],
#        [ 1.00000000e+00, -5.62234912e-01, -4.15010365e-01,
#         -1.37257576e-02],
#        [ 1.00000000e+00,  3.97981826e-01, -7.73300193e-01,
#         -7.78511681e-01],
#        [ 1.00000000e+00,  1.78684349e+00, -4.43673551e-01,
#         -2.72997306e-01],
#        [ 1.00000000e+00,  1.67349361e+00, -2.50848480e-01,
#         -1.83099131e-01],
#        [ 1.00000000e+00,  1.10288123e-02, -3.95467283e-01,
#          6.12955723e-01],
#        [ 1.00000000e+00,  2.79396362e+00, -3.56381120e-01,
#         -1.45315840e-01],
#        [ 1.00000000e+00,  2.92690218e-02, -6.05229692e-01,
#         -6.33892878e-01],
#        [ 1.00000000e+00,  1.04681213e+00, -5.60932040e-01,
#         -6.23469901e-01],
#        [ 1.00000000e+00,  1.97315420e+00, -5.11422900e-01,
#         -1.76584770e-01],
#        [ 1.00000000e+00,  2.22069990e+00, -8.05871995e-01,
#         -5.66143529e-01],
#        [ 1.00000000e+00, -7.00339355e-01, -6.65161808e-01,
#         -2.26093910e-01],
#        [ 1.00000000e+00,  2.10213854e+00, -6.52133087e-01,
#         -5.30965982e-01],
#        [ 1.00000000e+00, -6.06291532e-02, -7.08156588e-01,
#         -6.33892878e-01],
#        [ 1.00000000e+00,  2.55293228e+00, -8.26717949e-01,
#         -6.18258413e-01],
#        [ 1.00000000e+00,  9.89485761e-01, -4.90576947e-01,
#         -7.08156588e-01],
#        [ 1.00000000e+00,  2.25587744e+00, -6.54738832e-01,
#         -5.73960761e-01],
#        [ 1.00000000e+00,  2.36922732e+00, -5.19240133e-01,
#         -5.73960761e-01],
#        [ 1.00000000e+00,  4.75092312e-02, -6.63858936e-01,
#         -3.40746655e-01],
#        [ 1.00000000e+00,  2.94379391e+00, -5.03605668e-01,
#         -3.09477725e-01],
#        [ 1.00000000e+00,  5.98624130e-01, -6.45618727e-01,
#         -3.69409841e-01],
#        [ 1.00000000e+00,  3.94073210e-01, -8.52775391e-01,
#         -4.81456842e-01],
#        [ 1.00000000e+00,  2.58810983e+00, -6.11744052e-01,
#         -8.68409856e-01],
#        [ 1.00000000e+00,  3.74530129e-01, -8.54078263e-01,
#         -7.75905937e-01],
#        [ 1.00000000e+00,  2.91513073e+00, -8.18900716e-01,
#         -7.61574344e-01],
#        [ 1.00000000e+00,  2.60504717e+00, -3.01660492e-01,
#         -8.07174867e-01],
#        [ 1.00000000e+00,  1.00926987e-01, -2.28699654e-01,
#         -2.76905922e-01],
#        [ 1.00000000e+00, -3.10780597e-01, -5.24451621e-01,
#         -4.15010365e-01],
#        [ 1.00000000e+00,  2.09822992e+00, -3.81135690e-01,
#         -4.55399400e-01],
#        [ 1.00000000e+00,  1.76599753e+00, -5.81777994e-01,
#         -4.60610888e-01],
#        [ 1.00000000e+00,  1.43376515e+00, -4.37159191e-01,
#         -3.68106969e-01],
#        [ 1.00000000e+00,  2.95291402e+00, -5.11422900e-01,
#         -8.48866775e-01],
#        [ 1.00000000e+00,  1.82332391e+00, -7.62877216e-01,
#         -5.28360238e-01],
#        [ 1.00000000e+00, -5.45297575e-01, -5.37480342e-01,
#         -3.08174853e-01],
#        [ 1.00000000e+00,  1.40901058e+00, -5.79172250e-01,
#         -4.61913761e-01],
#        [ 1.00000000e+00,  2.96357803e-01, -7.43334134e-01,
#         -4.07193132e-01],
#        [ 1.00000000e+00,  2.25327170e+00, -3.31626550e-01,
#         -6.31287134e-01],
#        [ 1.00000000e+00,  2.08780694e+00, -6.66464680e-01,
#         -2.22185294e-01],
#        [ 1.00000000e+00, -6.97036574e-04, -7.19882437e-01,
#         -3.92861539e-01],
#        [ 1.00000000e+00,  1.73081999e+00, -8.31929437e-01,
#         -4.21524725e-01],
#        [ 1.00000000e+00,  4.35765117e-01, -7.47242751e-01,
#         -8.25415077e-01],
#        [ 1.00000000e+00,  1.94709676e+00, -3.29020806e-01,
#         -3.56381120e-01],
#        [ 1.00000000e+00,  1.50672598e+00, -2.70391562e-01,
#         -1.07532549e-01],
#        [ 1.00000000e+00,  2.55032654e+00, -4.97091307e-01,
#         -6.65161808e-01],
#        [ 1.00000000e+00,  1.71909414e+00, -2.28699654e-01,
#         -9.05952116e-02],
#        [ 1.00000000e+00, -7.77208809e-01, -5.06211412e-01,
#         -3.32929422e-01],
#        [ 1.00000000e+00,  9.02193330e-01, -6.22167029e-01,
#         -6.56041704e-01],
#        [ 1.00000000e+00,  1.87413592e+00, -2.26093910e-01,
#         -3.81135690e-01],
#        [ 1.00000000e+00,  1.87283305e+00, -4.87971203e-01,
#         -7.51151367e-01],
#        [ 1.00000000e+00, -1.75281898e-01, -8.46261030e-01,
#         -5.93503843e-01],
#        [ 1.00000000e+00,  2.53208633e+00, -3.15992085e-01,
#         -1.59647433e-01],
#        [ 1.00000000e+00,  2.24545447e+00, -6.70373297e-01,
#         -5.16634389e-01],
#        [ 1.00000000e+00,  4.65731176e-01, -4.86668330e-01,
#         -7.62877216e-01],
#        [ 1.00000000e+00,  8.35746853e-01, -3.14689213e-01,
#         -4.95788435e-01],
#        [ 1.00000000e+00,  2.66632776e-02, -7.51151367e-01,
#         -8.60592624e-01],
#        [ 1.00000000e+00, -4.61913761e-01, -5.51811936e-01,
#         -8.43655286e-01],
#        [ 1.00000000e+00,  9.42582365e-01, -6.83402018e-01,
#         -7.39425518e-01],
#        [ 1.00000000e+00,  2.22069990e+00, -5.14028645e-01,
#         -7.29002541e-01],
#        [ 1.00000000e+00,  1.95230824e+00, -3.00357620e-01,
#         -5.17937261e-01],
#        [ 1.00000000e+00,  1.72169988e+00, -4.73639609e-01,
#         -3.68106969e-01],
#        [ 1.00000000e+00,  5.58235095e-01, -6.86007762e-01,
#         -4.59308016e-01],
#        [ 1.00000000e+00, -5.23148749e-01, -4.42370679e-01,
#         -6.20864157e-01],
#        [ 1.00000000e+00,  8.13598027e-01, -7.98054763e-01,
#         -4.64519505e-01],
#        [ 1.00000000e+00,  1.90801059e+00, -5.51811936e-01,
#         -7.01642227e-01],
#        [ 1.00000000e+00, -6.52133087e-01, -3.02963364e-01,
#          2.92449186e-01],
#        [ 1.00000000e+00, -5.14028645e-01, -8.51472519e-01,
#         -6.02623947e-01],
#        [ 1.00000000e+00,  6.97642410e-01, -5.00999924e-01,
#         -6.87310634e-01],
#        [ 1.00000000e+00, -8.01963379e-01, -4.82759714e-01,
#         -7.49848495e-01],
#        [ 1.00000000e+00,  6.39013165e-01, -7.71997321e-01,
#         -5.71355017e-01],
#        [ 1.00000000e+00,  1.23075813e-01, -5.24451621e-01,
#         -5.81777994e-01],
#        [ 1.00000000e+00,  2.25196883e+00, -8.18900716e-01,
#         -3.91558667e-01],
#        [ 1.00000000e+00,  1.08744220e-01, -6.07835436e-01,
#         -4.48885039e-01],
#        [ 1.00000000e+00,  1.88460449e-02, -2.92540387e-01,
#         -4.08496004e-01],
#        [ 1.00000000e+00,  1.90931346e+00, -3.12083469e-01,
#         -4.31947702e-01],
#        [ 1.00000000e+00,  1.64483043e+00, -6.32590006e-01,
#         -1.63315018e-02],
#        [ 1.00000000e+00,  1.21772941e-01, -5.14028645e-01,
#         -6.63858936e-01],
#        [ 1.00000000e+00,  5.69960944e-01, -3.43352399e-01,
#         -4.89033043e-02],
#        [ 1.00000000e+00,  2.78117593e-01, -5.40086087e-01,
#          8.39896500e-02],
#        [ 1.00000000e+00,  5.58235095e-01, -2.49545608e-01,
#         -2.02642212e-01],
#        [ 1.00000000e+00,  8.77438760e-01, -8.08477740e-01,
#         -7.51151367e-01],
#        [ 1.00000000e+00, -4.99697051e-01, -8.52775391e-01,
#         -4.42370679e-01],
#        [ 1.00000000e+00,  1.96403409e+00, -4.35856318e-01,
#         -1.03623933e-01],
#        [ 1.00000000e+00,  2.39658763e+00, -3.96770155e-01,
#          6.96580569e-02],
#        [ 1.00000000e+00,  5.26966165e-01, -6.89916378e-01,
#         -7.30305413e-01],
#        [ 1.00000000e+00,  1.25527167e+00, -4.60610888e-01,
#         -1.83099131e-01],
#        [ 1.00000000e+00,  1.70215680e+00, -8.26717949e-01,
#         -7.95449018e-01],
#        [ 1.00000000e+00,  1.53669204e+00, -5.98715331e-01,
#         -5.85686610e-01],
#        [ 1.00000000e+00,  2.90210201e+00, -3.21203574e-01,
#         -2.05247957e-01],
#        [ 1.00000000e+00,  8.89164609e-01, -3.29020806e-01,
#         -2.74300178e-01],
#        [ 1.00000000e+00,  2.02526908e+00, -8.16294972e-01,
#         -2.23488166e-01],
#        [ 1.00000000e+00,  2.98939444e+00, -3.99375900e-01,
#          4.42279478e-01],
#        [ 1.00000000e+00,  2.77832916e+00, -7.40728390e-01,
#         -5.93503843e-01],
#        [ 1.00000000e+00,  1.57577821e+00, -6.48224471e-01,
#         -6.39104366e-01],
#        [ 1.00000000e+00,  2.23112287e+00, -4.25433342e-01,
#         -8.03266251e-01],
#        [ 1.00000000e+00,  9.24342155e-01, -2.67785817e-01,
#         -1.03623933e-01],
#        [ 1.00000000e+00, -5.46600447e-01, -7.29002541e-01,
#         -4.85365458e-01],
#        [ 1.00000000e+00,  3.05477907e-01, -8.68409856e-01,
#         -5.70052145e-01],
#        [ 1.00000000e+00, -7.01642227e-01, -8.67106984e-01,
#         -5.38783214e-01],
#        [ 1.00000000e+00,  2.45521687e+00, -5.21845877e-01,
#         -8.00660507e-01],
#        [ 1.00000000e+00,  2.06956673e+00, -7.65482960e-01,
#         -1.36195735e-01],
#        [ 1.00000000e+00,  2.27672340e+00, -3.77227074e-01,
#         -5.70052145e-01],
#        [ 1.00000000e+00,  1.41682781e+00, -6.71676169e-01,
#         -8.41049542e-01],
#        [ 1.00000000e+00,  1.85850145e+00, -6.03926820e-01,
#         -7.32911158e-01],
#        [ 1.00000000e+00,  1.46527511e-01, -2.62574329e-01,
#         -4.22827597e-01],
#        [ 1.00000000e+00,  1.06138476e-01, -4.16313237e-01,
#         -1.85704875e-01],
#        [ 1.00000000e+00,  9.41279493e-01, -6.86007762e-01,
#         -5.38783214e-01],
#        [ 1.00000000e+00,  1.23075813e-01, -8.61895496e-01,
#         -6.79493401e-01],
#        [ 1.00000000e+00,  7.65391759e-01, -3.91558667e-01,
#          1.59556232e-01],
#        [ 1.00000000e+00, -6.19561285e-01, -6.63858936e-01,
#         -5.81777994e-01],
#        [ 1.00000000e+00,  9.68639807e-01, -5.23148749e-01,
#         -2.70391562e-01],
#        [ 1.00000000e+00, -6.27378517e-01, -5.89595226e-01,
#         -2.15670933e-01],
#        [ 1.00000000e+00,  2.04611503e+00, -8.41049542e-01,
#         -6.69070425e-01],
#        [ 1.00000000e+00,  7.31517084e-01, -4.21524725e-01,
#         -7.10762332e-01],
#        [ 1.00000000e+00,  2.11777300e+00, -4.51490784e-01,
#          9.44126268e-02],
#        [ 1.00000000e+00,  2.63786000e-01, -7.18579565e-01,
#         -5.34874598e-01],
#        [ 1.00000000e+00, -7.70694449e-01, -3.65501225e-01,
#         -2.13065189e-01],
#        [ 1.00000000e+00,  1.72584953e-01, -8.72318472e-01,
#         -7.52454239e-01],
#        [ 1.00000000e+00,  1.99790877e+00, -2.33911143e-01,
#         -8.30626565e-01],
#        [ 1.00000000e+00, -9.58067000e-02, -7.15973820e-01,
#         -3.10780597e-01],
#        [ 1.00000000e+00, -8.63198368e-01, -3.56381120e-01,
#         -7.58968600e-01],
#        [ 1.00000000e+00,  2.58289834e+00, -8.34535182e-01,
#         -3.12083469e-01],
#        [ 1.00000000e+00, -7.62877216e-01, -5.17937261e-01,
#         -8.44958158e-01],
#        [ 1.00000000e+00,  1.99139441e+00, -4.35856318e-01,
#         -2.84723155e-01],
#        [ 1.00000000e+00, -3.91558667e-01, -3.69409841e-01,
#         -1.76343739e-02],
#        [ 1.00000000e+00, -2.43031247e-01, -2.59968585e-01,
#         -7.61574344e-01],
#        [ 1.00000000e+00, -5.38783214e-01, -3.64198353e-01,
#         -7.51151367e-01],
#        [ 1.00000000e+00,  2.69364247e+00, -4.95788435e-01,
#         -9.45038279e-02],
#        [ 1.00000000e+00, -3.12083469e-01, -5.34874598e-01,
#         -6.05229692e-01],
#        [ 1.00000000e+00,  1.53669204e+00, -3.00357620e-01,
#         -8.50169647e-01],
#        [ 1.00000000e+00,  8.39896500e-02, -6.50830215e-01,
#         -7.04247971e-01],
#        [ 1.00000000e+00,  1.65134479e+00, -4.11101749e-01,
#          1.12652836e-01],
#        [ 1.00000000e+00,  2.00051451e+00, -4.39764935e-01,
#         -3.78529946e-01],
#        [ 1.00000000e+00,  4.90485746e-01, -7.98054763e-01,
#         -4.24130470e-01],
#        [ 1.00000000e+00,  3.81044489e-01, -6.79493401e-01,
#         -3.65501225e-01],
#        [ 1.00000000e+00,  9.55611086e-01, -8.47563903e-01,
#         -7.55059983e-01],
#        [ 1.00000000e+00,  2.25587744e+00, -7.77208809e-01,
#         -7.58968600e-01],
#        [ 1.00000000e+00,  2.29626648e+00, -2.33911143e-01,
#         -2.95146132e-01],
#        [ 1.00000000e+00, -3.77227074e-01, -3.47261016e-01,
#         -7.17276692e-01],
#        [ 1.00000000e+00, -2.89934643e-01, -5.36177470e-01,
#         -6.03926820e-01],
#        [ 1.00000000e+00,  2.78484352e+00, -6.91219250e-01,
#         -3.90255795e-01],
#        [ 1.00000000e+00,  7.04156770e-01, -7.62877216e-01,
#         -2.37819759e-01],
#        [ 1.00000000e+00,  1.70215680e+00, -5.68749273e-01,
#         -6.87310634e-01],
#        [ 1.00000000e+00,  1.35950144e+00, -3.55078248e-01,
#         -3.81135690e-01],
#        [ 1.00000000e+00,  1.57447533e+00, -5.97412459e-01,
#         -7.48545623e-01],
#        [ 1.00000000e+00, -8.18900716e-01, -7.21185309e-01,
#         -7.98054763e-01],
#        [ 1.00000000e+00,  3.51078431e-01, -3.05569108e-01,
#         -2.14368061e-01],
#        [ 1.00000000e+00,  1.07938394e+00, -8.55381135e-01,
#         -5.55720552e-01],
#        [ 1.00000000e+00, -7.19882437e-01, -3.91558667e-01,
#         -2.83420283e-01],
#        [ 1.00000000e+00,  8.43564085e-01, -6.32590006e-01,
#         -4.21524725e-01],
#        [ 1.00000000e+00,  1.37513590e+00, -6.36498622e-01,
#         -4.72336737e-01],
#        [ 1.00000000e+00,  2.44242919e-01, -4.05890260e-01,
#         -2.30002526e-01],
#        [ 1.00000000e+00,  1.58229257e+00, -6.36498622e-01,
#         -5.38783214e-01],
#        [ 1.00000000e+00,  1.25787741e+00, -3.92861539e-01,
#         -7.75905937e-01],
#        [ 1.00000000e+00,  6.54647630e-01, -6.80796274e-01,
#         -8.01963379e-01],
#        [ 1.00000000e+00,  2.18291661e+00, -8.28020821e-01,
#          2.32517070e-01],
#        [ 1.00000000e+00, -6.39104366e-01, -3.82438562e-01,
#         -5.90898099e-01],
#        [ 1.00000000e+00,  1.82202103e+00, -8.04569123e-01,
#         -6.19561285e-01],
#        [ 1.00000000e+00,  1.93406803e+00, -5.64840657e-01,
#         -1.21864142e-01],
#        [ 1.00000000e+00,  2.83174691e+00, -7.34214030e-01,
#         -7.88934658e-01],
#        [ 1.00000000e+00, -2.20882422e-01, -7.21185309e-01,
#         -6.32590006e-01],
#        [ 1.00000000e+00,  1.27090613e+00, -6.00018203e-01,
#         -2.54757096e-01],
#        [ 1.00000000e+00, -6.16955541e-01, -6.10441180e-01,
#         -6.50830215e-01],
#        [ 1.00000000e+00,  1.32171815e+00, -7.79814553e-01,
#         -7.05550843e-01],
#        [ 1.00000000e+00,  2.02526908e+00, -8.28020821e-01,
#         -7.01642227e-01],
#        [ 1.00000000e+00,  2.73533438e+00, -2.35214015e-01,
#         -3.27717934e-01],
#        [ 1.00000000e+00,  2.36401583e+00, -4.78851098e-01,
#         -6.07835436e-01],
#        [ 1.00000000e+00,  1.34516984e+00, -7.70694449e-01,
#         -4.13707493e-01],
#        [ 1.00000000e+00,  2.73272863e+00, -8.42352414e-01,
#         -5.63537784e-01],
#        [ 1.00000000e+00,  1.28523773e+00, -7.42031262e-01,
#         -6.43012983e-01],
#        [ 1.00000000e+00,  1.16797924e+00, -8.38443798e-01,
#         -7.64180088e-01],
#        [ 1.00000000e+00,  1.97445707e+00, -8.01963379e-01,
#         -5.15331517e-01],
#        [ 1.00000000e+00, -1.40104351e-01, -7.98054763e-01,
#         -4.85365458e-01],
#        [ 1.00000000e+00,  2.87474169e+00, -3.12083469e-01,
#          6.31436964e-02],
#        [ 1.00000000e+00,  2.43437092e+00, -5.94806715e-01,
#         -4.81456842e-01],
#        [ 1.00000000e+00,  1.79856934e+00, -2.84723155e-01,
#         -6.16955541e-01],
#        [ 1.00000000e+00,  9.45188109e-01, -8.44958158e-01,
#         -5.25754493e-01],
#        [ 1.00000000e+00,  1.61747011e+00, -4.98394179e-01,
#         -6.35195750e-01],
#        [ 1.00000000e+00,  2.85389574e+00, -6.91219250e-01,
#         -8.24112205e-01],
#        [ 1.00000000e+00, -6.28681389e-01, -7.14670948e-01,
#         -5.67446401e-01],
#        [ 1.00000000e+00, -3.57683992e-01, -3.36838039e-01,
#         -7.96751891e-01],
#        [ 1.00000000e+00,  1.11349964e-01, -7.31608286e-01,
#         -7.94146146e-01],
#        [ 1.00000000e+00, -6.48224471e-01, -8.18900716e-01,
#         -4.60610888e-01],
#        [ 1.00000000e+00,  1.30087219e+00, -3.25112190e-01,
#         -8.25415077e-01],
#        [ 1.00000000e+00,  1.07808106e+00, -4.08496004e-01,
#         -7.94146146e-01],
#        [ 1.00000000e+00, -3.74621330e-01, -8.24112205e-01,
#         -6.92522122e-01],
#        [ 1.00000000e+00,  3.54987047e-01, -8.08477740e-01,
#         -7.66785832e-01],
#        [ 1.00000000e+00,  1.43376515e+00, -7.51151367e-01,
#         -7.88934658e-01],
#        [ 1.00000000e+00,  2.82262681e+00, -3.25112190e-01,
#         -9.81714128e-03],
#        [ 1.00000000e+00,  2.15164768e+00, -7.60271472e-01,
#         -7.58968600e-01]])

# %%
# we need MSE and its gradient
def MSE(w,x,y):
  return np.mean((y-x@w)**2)

# %%
# we must compute the gradient of MSE
def gradient(w,x,y):
  n = len(x)
  return 2/n*(y-x@w)@(-x)

# %%
w = [1,2,3,4]
# all we need to update the weights in the direction of the negative gradient
lr = 0.02 # in reality this value needs to be guessed or found independently
max_iter = 10000

# %%
for i in range(max_iter):
  w_new = w - lr*gradient(w,x_aug,y)
  if np.mean(abs(w-w_new))<1e-6:
    break
  if (i+1)%50==0:
    print(f"At the iteration {i+1} the Mean Squared Error is {MSE(w_new,x_aug,y)}")
  w = w_new
# Out:
# At the iteration 50 the Mean Squared Error is 13.799467390177933
# At the iteration 100 the Mean Squared Error is 10.756110559324192
# At the iteration 150 the Mean Squared Error is 9.73700342938406
# At the iteration 200 the Mean Squared Error is 8.978058745759949
# At the iteration 250 the Mean Squared Error is 8.320629009864222
# At the iteration 300 the Mean Squared Error is 7.740596101227877
# At the iteration 350 the Mean Squared Error is 7.2267312672216
# At the iteration 400 the Mean Squared Error is 6.7703326324050686
# At the iteration 450 the Mean Squared Error is 6.3641025947593075
# At the iteration 500 the Mean Squared Error is 6.001840915567064
# At the iteration 550 the Mean Squared Error is 5.678247710967425
# At the iteration 600 the Mean Squared Error is 5.388769174015595
# At the iteration 650 the Mean Squared Error is 5.129473442318083
# At the iteration 700 the Mean Squared Error is 4.896950049438605
# At the iteration 750 the Mean Squared Error is 4.688228084396113
# At the iteration 800 the Mean Squared Error is 4.50070925157864
# At the iteration 850 the Mean Squared Error is 4.332112837334165
# At the iteration 900 the Mean Squared Error is 4.180430224188715
# At the iteration 950 the Mean Squared Error is 4.043887090133469
# At the iteration 1000 the Mean Squared Error is 3.9209118192633365
# At the iteration 1050 the Mean Squared Error is 3.8101089549093645
# At the iteration 1100 the Mean Squared Error is 3.7102367657130744
# At the iteration 1150 the Mean Squared Error is 3.6201881831967806
# At the iteration 1200 the Mean Squared Error is 3.538974517475462
# At the iteration 1250 the Mean Squared Error is 3.465711474551332
# At the iteration 1300 the Mean Squared Error is 3.3996070909302007
# At the iteration 1350 the Mean Squared Error is 3.3399512744014372
# At the iteration 1400 the Mean Squared Error is 3.286106697869209
# At the iteration 1450 the Mean Squared Error is 3.2375008393423763
# At the iteration 1500 the Mean Squared Error is 3.1936189981082386
# At the iteration 1550 the Mean Squared Error is 3.1539981467045983
# At the iteration 1600 the Mean Squared Error is 3.1182215021089315
# At the iteration 1650 the Mean Squared Error is 3.0859137187924226
# At the iteration 1700 the Mean Squared Error is 3.0567366218872785
# At the iteration 1750 the Mean Squared Error is 3.0303854114326167
# At the iteration 1800 the Mean Squared Error is 3.0065852790813947
# At the iteration 1850 the Mean Squared Error is 2.9850883872287244
# At the iteration 1900 the Mean Squared Error is 2.965671167623177
# At the iteration 1950 the Mean Squared Error is 2.9481319024339934
# At the iteration 2000 the Mean Squared Error is 2.932288555695426
# At the iteration 2050 the Mean Squared Error is 2.9179768272147895
# At the iteration 2100 the Mean Squared Error is 2.9050484045567817
# At the iteration 2150 the Mean Squared Error is 2.8933693917174255
# At the iteration 2200 the Mean Squared Error is 2.8828188956686005
# At the iteration 2250 the Mean Squared Error is 2.8732877541620723
# At the iteration 2300 the Mean Squared Error is 2.8646773900898292
# At the iteration 2350 the Mean Squared Error is 2.856898779353726
# At the iteration 2400 the Mean Squared Error is 2.84987152064106
# At the iteration 2450 the Mean Squared Error is 2.8435229967661373
# At the iteration 2500 the Mean Squared Error is 2.8377876183475395
# At the iteration 2550 the Mean Squared Error is 2.832606141568535
# At the iteration 2600 the Mean Squared Error is 2.8279250526322186
# At the iteration 2650 the Mean Squared Error is 2.8236960122887083
# At the iteration 2700 the Mean Squared Error is 2.8198753544918302
# At the iteration 2750 the Mean Squared Error is 2.8164236338482596
# At the iteration 2800 the Mean Squared Error is 2.8133052170619273
# At the iteration 2850 the Mean Squared Error is 2.81048791405889
# At the iteration 2900 the Mean Squared Error is 2.807942644909364
# At the iteration 2950 the Mean Squared Error is 2.805643139050133
# At the iteration 3000 the Mean Squared Error is 2.8035656636571917
# At the iteration 3050 the Mean Squared Error is 2.8016887783296296
# At the iteration 3100 the Mean Squared Error is 2.799993113525336
# At the iteration 3150 the Mean Squared Error is 2.798461170440469
# At the iteration 3200 the Mean Squared Error is 2.7970771402507233
# At the iteration 3250 the Mean Squared Error is 2.7958267408361017
# At the iteration 3300 the Mean Squared Error is 2.794697069294135
# At the iteration 3350 the Mean Squared Error is 2.7936764687118028
# At the iteration 3400 the Mean Squared Error is 2.7927544078152255
# At the iteration 3450 the Mean Squared Error is 2.7919213722505436
# At the iteration 3500 the Mean Squared Error is 2.7911687663704163
# At the iteration 3550 the Mean Squared Error is 2.790488824509873
# At the iteration 3600 the Mean Squared Error is 2.7898745308337594
# At the iteration 3650 the Mean Squared Error is 2.789319546927025
# At the iteration 3700 the Mean Squared Error is 2.788818146379335
# At the iteration 3750 the Mean Squared Error is 2.7883651556879916
# At the iteration 3800 the Mean Squared Error is 2.7879559008685804
# At the iteration 3850 the Mean Squared Error is 2.787586159221819
# At the iteration 3900 the Mean Squared Error is 2.787252115758447
# At the iteration 3950 the Mean Squared Error is 2.7869503238321647
# At the iteration 4000 the Mean Squared Error is 2.7866776695741198
# At the iteration 4050 the Mean Squared Error is 2.786431339761775
# At the iteration 4100 the Mean Squared Error is 2.7862087927904056
# At the iteration 4150 the Mean Squared Error is 2.786007732447613
# At the iteration 4200 the Mean Squared Error is 2.785826084220136
# At the iteration 4250 the Mean Squared Error is 2.7856619738883963
# At the iteration 4300 the Mean Squared Error is 2.7855137081878882
# At the iteration 4350 the Mean Squared Error is 2.785379757337795
# At the iteration 4400 the Mean Squared Error is 2.785258739256544
# At the iteration 4450 the Mean Squared Error is 2.7851494053013965
# At the iteration 4500 the Mean Squared Error is 2.785050627384927
# At the iteration 4550 the Mean Squared Error is 2.7849613863354263
# At the iteration 4600 the Mean Squared Error is 2.7848807613811215
# At the iteration 4650 the Mean Squared Error is 2.784807920649722
# At the iteration 4700 the Mean Squared Error is 2.7847421125852234
# At the iteration 4750 the Mean Squared Error is 2.7846826581934363
# At the iteration 4800 the Mean Squared Error is 2.7846289440362044
# At the iteration 4850 the Mean Squared Error is 2.7845804159020338
# At the iteration 4900 the Mean Squared Error is 2.7845365730878138
# At the iteration 4950 the Mean Squared Error is 2.78449696323265
# At the iteration 5000 the Mean Squared Error is 2.78446117765047
# At the iteration 5050 the Mean Squared Error is 2.7844288471132814
# At the iteration 5100 the Mean Squared Error is 2.784399638041531
# At the iteration 5150 the Mean Squared Error is 2.7843732490623063
# At the iteration 5200 the Mean Squared Error is 2.784349407899815
# At the iteration 5250 the Mean Squared Error is 2.784327868566105
# At the iteration 5300 the Mean Squared Error is 2.784308408823006
# At the iteration 5350 the Mean Squared Error is 2.7842908278891185
# At the iteration 5400 the Mean Squared Error is 2.7842749443681964
# At the iteration 5450 the Mean Squared Error is 2.7842605943775367
# At the iteration 5500 the Mean Squared Error is 2.784247629857067
# At the iteration 5550 the Mean Squared Error is 2.7842359170417024
# At the iteration 5600 the Mean Squared Error is 2.7842253350811763
# At the iteration 5650 the Mean Squared Error is 2.7842157747931378
# At the iteration 5700 the Mean Squared Error is 2.7842071375366313
# At the iteration 5750 the Mean Squared Error is 2.784199334194337
# At the iteration 5800 the Mean Squared Error is 2.784192284253082
# At the iteration 5850 the Mean Squared Error is 2.78418591497312
# At the iteration 5900 the Mean Squared Error is 2.7841801606376193
# At the iteration 5950 the Mean Squared Error is 2.7841749618746086
# At the iteration 6000 the Mean Squared Error is 2.7841702650443967
# At the iteration 6050 the Mean Squared Error is 2.78416602168612
# At the iteration 6100 the Mean Squared Error is 2.784162188017739
# At the iteration 6150 the Mean Squared Error is 2.784158724484308
# At the iteration 6200 the Mean Squared Error is 2.784155595349852
# At the iteration 6250 the Mean Squared Error is 2.784152768328647
# At the iteration 6300 the Mean Squared Error is 2.7841502142521137
# At the iteration 6350 the Mean Squared Error is 2.7841479067678496
# At the iteration 6400 the Mean Squared Error is 2.78414582206774
# At the iteration 6450 the Mean Squared Error is 2.7841439386423077
# At the iteration 6500 the Mean Squared Error is 2.784142237058785
# At the iteration 6550 the Mean Squared Error is 2.784140699760606
# At the iteration 6600 the Mean Squared Error is 2.7841393108862666
# At the iteration 6650 the Mean Squared Error is 2.7841380561056686
# At the iteration 6700 the Mean Squared Error is 2.7841369224722583
# At the iteration 6750 the Mean Squared Error is 2.7841358982894597
# At the iteration 6800 the Mean Squared Error is 2.7841349729899787
# At the iteration 6850 the Mean Squared Error is 2.7841341370267783
# At the iteration 6900 the Mean Squared Error is 2.784133381774574
# At the iteration 6950 the Mean Squared Error is 2.7841326994408404
# At the iteration 7000 the Mean Squared Error is 2.7841320829854097
# At the iteration 7050 the Mean Squared Error is 2.7841315260478274
# At the iteration 7100 the Mean Squared Error is 2.784131022881736
# At the iteration 7150 the Mean Squared Error is 2.784130568295578
# At the iteration 7200 the Mean Squared Error is 2.7841301575990336
# At the iteration 7250 the Mean Squared Error is 2.784129786554626
# At the iteration 7300 the Mean Squared Error is 2.7841294513340014
# At the iteration 7350 the Mean Squared Error is 2.784129148478426
# At the iteration 7400 the Mean Squared Error is 2.784128874863104
# At the iteration 7450 the Mean Squared Error is 2.7841286276649324
# At the iteration 7500 the Mean Squared Error is 2.7841284043333734
# At the iteration 7550 the Mean Squared Error is 2.784128202564143
# At the iteration 7600 the Mean Squared Error is 2.7841280202754306
# At the iteration 7650 the Mean Squared Error is 2.7841278555864197
# At the iteration 7700 the Mean Squared Error is 2.7841277067978867
# At the iteration 7750 the Mean Squared Error is 2.7841275723746652
# At the iteration 7800 the Mean Squared Error is 2.7841274509298035
# At the iteration 7850 the Mean Squared Error is 2.784127341210261
# At the iteration 7900 the Mean Squared Error is 2.784127242083977
# At the iteration 7950 the Mean Squared Error is 2.7841271525281877
# At the iteration 8000 the Mean Squared Error is 2.7841270716188764
# At the iteration 8050 the Mean Squared Error is 2.784126998521236
# At the iteration 8100 the Mean Squared Error is 2.784126932481065
# At the iteration 8150 the Mean Squared Error is 2.7841268728169735
# At the iteration 8200 the Mean Squared Error is 2.784126818913361
# At the iteration 8250 the Mean Squared Error is 2.784126770214061
# At the iteration 8300 the Mean Squared Error is 2.784126726216605
# At the iteration 8350 the Mean Squared Error is 2.784126686467039
# At the iteration 8400 the Mean Squared Error is 2.7841266505552347
# At the iteration 8450 the Mean Squared Error is 2.78412661811066
# At the iteration 8500 the Mean Squared Error is 2.7841265887985607
# At the iteration 8550 the Mean Squared Error is 2.784126562316501
# At the iteration 8600 the Mean Squared Error is 2.7841265383912432
# At the iteration 8650 the Mean Squared Error is 2.7841265167759355
# At the iteration 8700 the Mean Squared Error is 2.784126497247552

# %% [markdown]
# ## The Mini-Batch SGD

# %%
np.array_split(np.random.permutation(range(len(x))),15)
# Out:
# [array([ 49,  53, 110, 145,  42,  11,  44, 152, 176, 178,  10, 147,  43,
#         181]),
#  array([ 33,  24, 168,  34,   8, 153,  74, 186,  76,  87,  19, 158,  45,
#          91]),
#  array([  5, 150,  28, 121,  36,  83, 133, 187, 194,  59, 173, 126,  18,
#          81]),
#  array([ 90, 160,  23,  38, 159, 102,  17, 189,   9, 185, 180, 184, 108,
#          99]),
#  array([113,  82, 162,  93,  98,  84,  29, 137, 103,  62, 167,  77, 182,
#          78]),
#  array([130, 190, 129, 170,  30, 142, 163,  96, 107,  40,   4,  65,   6]),
#  array([199,  61,  31, 101,  35,   3, 196,  12, 174, 179, 106, 195,  69]),
#  array([128, 149,  57, 114, 109, 140, 123, 148,  86, 141, 104, 165,  71]),
#  array([ 72, 191, 111, 156, 138, 136,  26,  60, 161,   0,  67, 146,  97]),
#  array([  2,  85, 134,  92, 135,  41, 143, 115, 155,  50, 132,  94, 157]),
#  array([166, 151,  66, 192,  75,  32, 112,  88,  95,  73,  58, 171, 188]),
#  array([100,  39,  20, 131,  56,  22, 193, 125, 139,  21,  52, 175,  68]),
#  array([169, 154, 172,  70,  14,  37,  48,  27, 124,   1,  64, 127, 197]),
#  array([116, 164,  54,  25,  63,   7, 119, 117,  47, 198,  46,  51,  89]),
#  array([183, 120,  55,  80,  13, 118, 122, 105, 177, 144,  16,  79,  15])]

# %%
w = [1,2,3,4]
batch_size = 15
epochs = 10000
lr = 0.03

# %%
for i in range(epochs):
  for batch_ind in np.array_split(np.random.permutation(range(len(x))),batch_size):
    xs = x_aug[batch_ind]
    ys = y[batch_ind]
    w_new = w - lr*gradient(w,xs,ys)
    if np.mean(abs(w-w_new))<1e-6:
      break
    if (i+1)%100==0:
      print(f"At the iteration {i+1} the Mean Squared Error is {MSE(w_new,x_aug,y)}")
    w = w_new
# Out:
# At the iteration 100 the Mean Squared Error is 2.8774967927498163
# At the iteration 100 the Mean Squared Error is 2.87756933200744
# At the iteration 100 the Mean Squared Error is 2.884953966845076
# At the iteration 100 the Mean Squared Error is 2.894686940112473
# At the iteration 100 the Mean Squared Error is 2.874525017850684
# At the iteration 100 the Mean Squared Error is 2.9305551357289867
# At the iteration 100 the Mean Squared Error is 2.883904528883613
# At the iteration 100 the Mean Squared Error is 2.875582346234071
# At the iteration 100 the Mean Squared Error is 2.8753456794044667
# At the iteration 100 the Mean Squared Error is 2.8827475469809722
# At the iteration 100 the Mean Squared Error is 2.9335654451507094
# At the iteration 100 the Mean Squared Error is 2.9141505422545264
# At the iteration 100 the Mean Squared Error is 2.8719814426530017
# At the iteration 100 the Mean Squared Error is 2.875013389461365
# At the iteration 100 the Mean Squared Error is 2.901804869617333
# At the iteration 200 the Mean Squared Error is 2.8001221280508424
# At the iteration 200 the Mean Squared Error is 2.805229567360864
# At the iteration 200 the Mean Squared Error is 2.8331102415055374
# At the iteration 200 the Mean Squared Error is 2.802804483799694
# At the iteration 200 the Mean Squared Error is 2.797628350810337
# At the iteration 200 the Mean Squared Error is 2.7937782476896564
# At the iteration 200 the Mean Squared Error is 2.870350267467799
# At the iteration 200 the Mean Squared Error is 2.8579834358130847
# At the iteration 200 the Mean Squared Error is 2.909453919313138
# At the iteration 200 the Mean Squared Error is 2.830584760186383
# At the iteration 200 the Mean Squared Error is 2.815727780664009
# At the iteration 200 the Mean Squared Error is 2.7860589360839834
# At the iteration 200 the Mean Squared Error is 2.8030938466630375
# At the iteration 200 the Mean Squared Error is 2.8098936063169764
# At the iteration 200 the Mean Squared Error is 2.7976916832646883
# At the iteration 300 the Mean Squared Error is 2.791839809237633
# At the iteration 300 the Mean Squared Error is 2.787327812580819
# At the iteration 300 the Mean Squared Error is 2.824540575355193
# At the iteration 300 the Mean Squared Error is 2.7915920520318025
# At the iteration 300 the Mean Squared Error is 2.793717560345778
# At the iteration 300 the Mean Squared Error is 2.787167420565475
# At the iteration 300 the Mean Squared Error is 2.787726628515484
# At the iteration 300 the Mean Squared Error is 2.7896447353836935
# At the iteration 300 the Mean Squared Error is 2.7890023973795
# At the iteration 300 the Mean Squared Error is 2.830329358610482
# At the iteration 300 the Mean Squared Error is 2.8166254130507253
# At the iteration 300 the Mean Squared Error is 2.7873592714803386
# At the iteration 300 the Mean Squared Error is 2.7847691187434473
# At the iteration 300 the Mean Squared Error is 2.7845947868872263
# At the iteration 300 the Mean Squared Error is 2.785673896513462
# At the iteration 400 the Mean Squared Error is 2.7982076598419736
# At the iteration 400 the Mean Squared Error is 2.7885679146433926
# At the iteration 400 the Mean Squared Error is 2.7856116854534205
# At the iteration 400 the Mean Squared Error is 2.8099115050775594
# At the iteration 400 the Mean Squared Error is 2.807832814422078
# At the iteration 400 the Mean Squared Error is 2.805039170499073
# At the iteration 400 the Mean Squared Error is 2.788997683722295
# At the iteration 400 the Mean Squared Error is 2.7888839042200244
# At the iteration 400 the Mean Squared Error is 2.7855605262992005
# At the iteration 400 the Mean Squared Error is 2.7857552520845865
# At the iteration 400 the Mean Squared Error is 2.794558403582272
# At the iteration 400 the Mean Squared Error is 2.7858069854505754
# At the iteration 400 the Mean Squared Error is 2.797632894364465
# At the iteration 400 the Mean Squared Error is 2.784443409564592
# At the iteration 400 the Mean Squared Error is 2.784158962161458
# At the iteration 500 the Mean Squared Error is 2.821085914362255
# At the iteration 500 the Mean Squared Error is 2.825339179813403
# At the iteration 500 the Mean Squared Error is 2.809775790094626
# At the iteration 500 the Mean Squared Error is 2.809024535993369
# At the iteration 500 the Mean Squared Error is 2.8248829139247893
# At the iteration 500 the Mean Squared Error is 2.7941240641942797
# At the iteration 500 the Mean Squared Error is 2.785310945981129
# At the iteration 500 the Mean Squared Error is 2.7945282817115706
# At the iteration 500 the Mean Squared Error is 2.789601864080782
# At the iteration 500 the Mean Squared Error is 2.7958778351902636
# At the iteration 500 the Mean Squared Error is 2.804978697845844
# At the iteration 500 the Mean Squared Error is 2.786613336537066
# At the iteration 500 the Mean Squared Error is 2.8028939020161654
# At the iteration 500 the Mean Squared Error is 2.794278273104231
# At the iteration 500 the Mean Squared Error is 2.786098680304522
# At the iteration 600 the Mean Squared Error is 2.7898893493932633
# At the iteration 600 the Mean Squared Error is 2.797601682411281
# At the iteration 600 the Mean Squared Error is 2.8822007767145603
# At the iteration 600 the Mean Squared Error is 2.862911227650585
# At the iteration 600 the Mean Squared Error is 2.8296812785713064
# At the iteration 600 the Mean Squared Error is 2.796880227676526
# At the iteration 600 the Mean Squared Error is 2.785372838636975
# At the iteration 600 the Mean Squared Error is 2.797434587458821
# At the iteration 600 the Mean Squared Error is 2.794861308419421
# At the iteration 600 the Mean Squared Error is 2.7906086154735834
# At the iteration 600 the Mean Squared Error is 2.7870579318659376
# At the iteration 600 the Mean Squared Error is 2.7880854569251348
# At the iteration 600 the Mean Squared Error is 2.7851192903284696
# At the iteration 600 the Mean Squared Error is 2.786821219826719
# At the iteration 600 the Mean Squared Error is 2.7852785400199616
# At the iteration 700 the Mean Squared Error is 2.866959161479956
# At the iteration 700 the Mean Squared Error is 2.819777267899324
# At the iteration 700 the Mean Squared Error is 2.8068059685258957
# At the iteration 700 the Mean Squared Error is 2.818471984136048
# At the iteration 700 the Mean Squared Error is 2.784554144600512
# At the iteration 700 the Mean Squared Error is 2.784726575518945
# At the iteration 700 the Mean Squared Error is 2.8416043133621662
# At the iteration 700 the Mean Squared Error is 2.7915615844599677
# At the iteration 700 the Mean Squared Error is 2.7975565505962527
# At the iteration 700 the Mean Squared Error is 2.7858399482559095
# At the iteration 700 the Mean Squared Error is 2.7849087016639573
# At the iteration 700 the Mean Squared Error is 2.785569133312594
# At the iteration 700 the Mean Squared Error is 2.8072444240126577
# At the iteration 700 the Mean Squared Error is 2.7857911436846297
# At the iteration 700 the Mean Squared Error is 2.7859498815674733
# At the iteration 800 the Mean Squared Error is 2.791813592703576
# At the iteration 800 the Mean Squared Error is 2.7863059068364713
# At the iteration 800 the Mean Squared Error is 2.788583248715413
# At the iteration 800 the Mean Squared Error is 2.7931455699176144
# At the iteration 800 the Mean Squared Error is 2.789488137124615
# At the iteration 800 the Mean Squared Error is 2.809087116026276
# At the iteration 800 the Mean Squared Error is 2.789588909708546
# At the iteration 800 the Mean Squared Error is 2.787427930698575
# At the iteration 800 the Mean Squared Error is 2.794903745064512
# At the iteration 800 the Mean Squared Error is 2.790469093935767
# At the iteration 800 the Mean Squared Error is 2.7871688776598087
# At the iteration 800 the Mean Squared Error is 2.7855084608320486
# At the iteration 800 the Mean Squared Error is 2.78990669371187
# At the iteration 800 the Mean Squared Error is 2.7858155419869353
# At the iteration 800 the Mean Squared Error is 2.7912883473968213
# At the iteration 900 the Mean Squared Error is 2.789244596431003
# At the iteration 900 the Mean Squared Error is 2.7873041537061316
# At the iteration 900 the Mean Squared Error is 2.7876560849049627
# At the iteration 900 the Mean Squared Error is 2.8054505188755625
# At the iteration 900 the Mean Squared Error is 2.7868755456391234
# At the iteration 900 the Mean Squared Error is 2.785389682158187
# At the iteration 900 the Mean Squared Error is 2.7849142449237103
# At the iteration 900 the Mean Squared Error is 2.7910616909978647
# At the iteration 900 the Mean Squared Error is 2.788967122824467
# At the iteration 900 the Mean Squared Error is 2.7889091206917014
# At the iteration 900 the Mean Squared Error is 2.803949183437741
# At the iteration 900 the Mean Squared Error is 2.787106449477578
# At the iteration 900 the Mean Squared Error is 2.7909592508953036
# At the iteration 900 the Mean Squared Error is 2.7841401270536337
# At the iteration 900 the Mean Squared Error is 2.7849250790540565
# At the iteration 1000 the Mean Squared Error is 2.788164718568095
# At the iteration 1000 the Mean Squared Error is 2.7853913504246304
# At the iteration 1000 the Mean Squared Error is 2.7920910704817827
# At the iteration 1000 the Mean Squared Error is 2.7844689089985297
# At the iteration 1000 the Mean Squared Error is 2.7868105546792368
# At the iteration 1000 the Mean Squared Error is 2.7848245742156115
# At the iteration 1000 the Mean Squared Error is 2.786194750170094
# At the iteration 1000 the Mean Squared Error is 2.798937723618567
# At the iteration 1000 the Mean Squared Error is 2.786448582691936
# At the iteration 1000 the Mean Squared Error is 2.7898669426153986
# At the iteration 1000 the Mean Squared Error is 2.7896381269174073
# At the iteration 1000 the Mean Squared Error is 2.801643353187329
# At the iteration 1000 the Mean Squared Error is 2.7904593921957
# At the iteration 1000 the Mean Squared Error is 2.7939102251014543
# At the iteration 1000 the Mean Squared Error is 2.784714097032017
# At the iteration 1100 the Mean Squared Error is 2.7919414859213685
# At the iteration 1100 the Mean Squared Error is 2.7862315004063305
# At the iteration 1100 the Mean Squared Error is 2.785367752901949
# At the iteration 1100 the Mean Squared Error is 2.7872169838360987
# At the iteration 1100 the Mean Squared Error is 2.785907074957515
# At the iteration 1100 the Mean Squared Error is 2.7852089567053198
# At the iteration 1100 the Mean Squared Error is 2.7846314272542276
# At the iteration 1100 the Mean Squared Error is 2.789001316830199
# At the iteration 1100 the Mean Squared Error is 2.818903335268915
# At the iteration 1100 the Mean Squared Error is 2.7903617556980715
# At the iteration 1100 the Mean Squared Error is 2.7849858194759283
# At the iteration 1100 the Mean Squared Error is 2.795933403093695
# At the iteration 1100 the Mean Squared Error is 2.787718880207302
# At the iteration 1100 the Mean Squared Error is 2.8291660898781608
# At the iteration 1100 the Mean Squared Error is 2.7843287475640035
# At the iteration 1200 the Mean Squared Error is 2.7871047043498898
# At the iteration 1200 the Mean Squared Error is 2.79554702368388
# At the iteration 1200 the Mean Squared Error is 2.8047823413932336
# At the iteration 1200 the Mean Squared Error is 2.80496928465748
# At the iteration 1200 the Mean Squared Error is 2.8027299468823568
# At the iteration 1200 the Mean Squared Error is 2.8084713049768
# At the iteration 1200 the Mean Squared Error is 2.8176194717787904
# At the iteration 1200 the Mean Squared Error is 2.7992095511748305
# At the iteration 1200 the Mean Squared Error is 2.788816258844266
# At the iteration 1200 the Mean Squared Error is 2.7899632548487836
# At the iteration 1200 the Mean Squared Error is 2.7881397637897654
# At the iteration 1200 the Mean Squared Error is 2.8324676685888783
# At the iteration 1200 the Mean Squared Error is 2.8335190032701987
# At the iteration 1200 the Mean Squared Error is 2.8682189202866346
# At the iteration 1200 the Mean Squared Error is 2.79410110232982
# At the iteration 1300 the Mean Squared Error is 2.7895944860830975
# At the iteration 1300 the Mean Squared Error is 2.797315306634573
# At the iteration 1300 the Mean Squared Error is 2.7929635402439525
# At the iteration 1300 the Mean Squared Error is 2.7920389092667364
# At the iteration 1300 the Mean Squared Error is 2.786921790606879
# At the iteration 1300 the Mean Squared Error is 2.786327259330325
# At the iteration 1300 the Mean Squared Error is 2.78767720989039
# At the iteration 1300 the Mean Squared Error is 2.8051798533707073
# At the iteration 1300 the Mean Squared Error is 2.8121082206554284
# At the iteration 1300 the Mean Squared Error is 2.8131651322134883
# At the iteration 1300 the Mean Squared Error is 2.836694296470213
# At the iteration 1300 the Mean Squared Error is 2.863573346859248
# At the iteration 1300 the Mean Squared Error is 2.809392481027294
# At the iteration 1300 the Mean Squared Error is 2.789538470455822
# At the iteration 1300 the Mean Squared Error is 2.810951009498384
# At the iteration 1400 the Mean Squared Error is 2.7873026876774514
# At the iteration 1400 the Mean Squared Error is 2.785067657413579
# At the iteration 1400 the Mean Squared Error is 2.7854359970895373
# At the iteration 1400 the Mean Squared Error is 2.795785283833343
# At the iteration 1400 the Mean Squared Error is 2.7875255915884747
# At the iteration 1400 the Mean Squared Error is 2.787547648913562
# At the iteration 1400 the Mean Squared Error is 2.806475321144061
# At the iteration 1400 the Mean Squared Error is 2.8066851303493534
# At the iteration 1400 the Mean Squared Error is 2.7872410952575204
# At the iteration 1400 the Mean Squared Error is 2.7954055389972154
# At the iteration 1400 the Mean Squared Error is 2.8069949233491456
# At the iteration 1400 the Mean Squared Error is 2.78643429001734
# At the iteration 1400 the Mean Squared Error is 2.7842650155247166
# At the iteration 1400 the Mean Squared Error is 2.787130280571409
# At the iteration 1400 the Mean Squared Error is 2.7933832464850137
# At the iteration 1500 the Mean Squared Error is 2.7843251264380084
# At the iteration 1500 the Mean Squared Error is 2.7923883847096636
# At the iteration 1500 the Mean Squared Error is 2.784230069994577
# At the iteration 1500 the Mean Squared Error is 2.8201257962088255
# At the iteration 1500 the Mean Squared Error is 2.860663615530598
# At the iteration 1500 the Mean Squared Error is 2.8600096244600026
# At the iteration 1500 the Mean Squared Error is 2.8544643674997157
# At the iteration 1500 the Mean Squared Error is 2.788032667182936
# At the iteration 1500 the Mean Squared Error is 2.785623410738884
# At the iteration 1500 the Mean Squared Error is 2.7851558412089723
# At the iteration 1500 the Mean Squared Error is 2.851217719526753
# At the iteration 1500 the Mean Squared Error is 2.845466648216198
# At the iteration 1500 the Mean Squared Error is 2.827463726958562
# At the iteration 1500 the Mean Squared Error is 2.8319725882010376
# At the iteration 1500 the Mean Squared Error is 2.792570622687438
# At the iteration 1600 the Mean Squared Error is 2.797313315736759
# At the iteration 1600 the Mean Squared Error is 2.7843921052270195
# At the iteration 1600 the Mean Squared Error is 2.8006732520118907
# At the iteration 1600 the Mean Squared Error is 2.8059784413271065
# At the iteration 1600 the Mean Squared Error is 2.796522442719631
# At the iteration 1600 the Mean Squared Error is 2.825123737480676
# At the iteration 1600 the Mean Squared Error is 2.8101651382621835
# At the iteration 1600 the Mean Squared Error is 2.790884193146277
# At the iteration 1600 the Mean Squared Error is 2.7879293105994987
# At the iteration 1600 the Mean Squared Error is 2.7880111506427907
# At the iteration 1600 the Mean Squared Error is 2.7886350312926016
# At the iteration 1600 the Mean Squared Error is 2.7885706137048647
# At the iteration 1600 the Mean Squared Error is 2.7863371921541353
# At the iteration 1600 the Mean Squared Error is 2.785236203201843
# At the iteration 1600 the Mean Squared Error is 2.801418710780979
# At the iteration 1700 the Mean Squared Error is 2.7851792627962157
# At the iteration 1700 the Mean Squared Error is 2.786934019479298
# At the iteration 1700 the Mean Squared Error is 2.7957971314405143
# At the iteration 1700 the Mean Squared Error is 2.7975004013310945
# At the iteration 1700 the Mean Squared Error is 2.814147494025549
# At the iteration 1700 the Mean Squared Error is 2.8359309131401913
# At the iteration 1700 the Mean Squared Error is 2.8435464128199417
# At the iteration 1700 the Mean Squared Error is 2.833065106549212
# At the iteration 1700 the Mean Squared Error is 2.821306011288128
# At the iteration 1700 the Mean Squared Error is 2.800608448176509
# At the iteration 1700 the Mean Squared Error is 2.7893804544179175
# At the iteration 1700 the Mean Squared Error is 2.7911349109676293
# At the iteration 1700 the Mean Squared Error is 2.799471656017208
# At the iteration 1700 the Mean Squared Error is 2.8386563992648735
# At the iteration 1700 the Mean Squared Error is 2.811189444848941
# At the iteration 1800 the Mean Squared Error is 2.79380086463599
# At the iteration 1800 the Mean Squared Error is 2.7851227110530283
# At the iteration 1800 the Mean Squared Error is 2.80141708475825
# At the iteration 1800 the Mean Squared Error is 2.79246251347831
# At the iteration 1800 the Mean Squared Error is 2.7862727169682695
# At the iteration 1800 the Mean Squared Error is 2.792194517386849
# At the iteration 1800 the Mean Squared Error is 2.785263384379002
# At the iteration 1800 the Mean Squared Error is 2.789385892190349
# At the iteration 1800 the Mean Squared Error is 2.7843678342176856
# At the iteration 1800 the Mean Squared Error is 2.7841431703650157
# At the iteration 1800 the Mean Squared Error is 2.795130292122451
# At the iteration 1800 the Mean Squared Error is 2.7922704368639564
# At the iteration 1800 the Mean Squared Error is 2.794704890698407
# At the iteration 1800 the Mean Squared Error is 2.784134562934744
# At the iteration 1800 the Mean Squared Error is 2.786477448308491
# At the iteration 1900 the Mean Squared Error is 2.7843703611783615
# At the iteration 1900 the Mean Squared Error is 2.8026867652196654
# At the iteration 1900 the Mean Squared Error is 2.7869324102688733
# At the iteration 1900 the Mean Squared Error is 2.805216627480419
# At the iteration 1900 the Mean Squared Error is 2.7851826744928894
# At the iteration 1900 the Mean Squared Error is 2.785984282457256
# At the iteration 1900 the Mean Squared Error is 2.794032931335254
# At the iteration 1900 the Mean Squared Error is 2.8048907887599603
# At the iteration 1900 the Mean Squared Error is 2.7859996530843385
# At the iteration 1900 the Mean Squared Error is 2.790637176479339
# At the iteration 1900 the Mean Squared Error is 2.787318509735554
# At the iteration 1900 the Mean Squared Error is 2.7888152130131107
# At the iteration 1900 the Mean Squared Error is 2.785311025790288
# At the iteration 1900 the Mean Squared Error is 2.78473987328533
# At the iteration 1900 the Mean Squared Error is 2.7887812545943285
# At the iteration 2000 the Mean Squared Error is 2.793941191384537
# At the iteration 2000 the Mean Squared Error is 2.7857223067049914
# At the iteration 2000 the Mean Squared Error is 2.7978479565400267
# At the iteration 2000 the Mean Squared Error is 2.815691365736528
# At the iteration 2000 the Mean Squared Error is 2.8212331970377225
# At the iteration 2000 the Mean Squared Error is 2.7936427637459893
# At the iteration 2000 the Mean Squared Error is 2.794760951495582
# At the iteration 2000 the Mean Squared Error is 2.7859293909826666
# At the iteration 2000 the Mean Squared Error is 2.786700740653259
# At the iteration 2000 the Mean Squared Error is 2.800033964627703
# At the iteration 2000 the Mean Squared Error is 2.8119135019561434
# At the iteration 2000 the Mean Squared Error is 2.787438835583351
# At the iteration 2000 the Mean Squared Error is 2.806866321620595
# At the iteration 2000 the Mean Squared Error is 2.8312282402349007
# At the iteration 2000 the Mean Squared Error is 2.803413105778732
# At the iteration 2100 the Mean Squared Error is 2.8655848959268195
# At the iteration 2100 the Mean Squared Error is 2.854466396337595
# At the iteration 2100 the Mean Squared Error is 2.868094172315723
# At the iteration 2100 the Mean Squared Error is 2.866809154872965
# At the iteration 2100 the Mean Squared Error is 2.8687732593656587
# At the iteration 2100 the Mean Squared Error is 2.8440582489463724
# At the iteration 2100 the Mean Squared Error is 2.812026326889638
# At the iteration 2100 the Mean Squared Error is 2.792198063427927
# At the iteration 2100 the Mean Squared Error is 2.784939236369
# At the iteration 2100 the Mean Squared Error is 2.7903513097608137
# At the iteration 2100 the Mean Squared Error is 2.785771702011875
# At the iteration 2100 the Mean Squared Error is 2.789215890915277
# At the iteration 2100 the Mean Squared Error is 2.8526463951129637
# At the iteration 2100 the Mean Squared Error is 2.827302167995295
# At the iteration 2100 the Mean Squared Error is 2.8157825501392812
# At the iteration 2200 the Mean Squared Error is 2.7928633827456872
# At the iteration 2200 the Mean Squared Error is 2.784327517170936
# At the iteration 2200 the Mean Squared Error is 2.7915735448833483
# At the iteration 2200 the Mean Squared Error is 2.78597199301156
# At the iteration 2200 the Mean Squared Error is 2.792067284535068
# At the iteration 2200 the Mean Squared Error is 2.78971335855358
# At the iteration 2200 the Mean Squared Error is 2.7858636160697996
# At the iteration 2200 the Mean Squared Error is 2.791757764329765
# At the iteration 2200 the Mean Squared Error is 2.786388209423864
# At the iteration 2200 the Mean Squared Error is 2.7862294457401435
# At the iteration 2200 the Mean Squared Error is 2.791439512853623
# At the iteration 2200 the Mean Squared Error is 2.797159557800414
# At the iteration 2200 the Mean Squared Error is 2.7991856460537736
# At the iteration 2200 the Mean Squared Error is 2.7880044558858468
# At the iteration 2200 the Mean Squared Error is 2.7862451079361956
# At the iteration 2300 the Mean Squared Error is 2.785860799293315
# At the iteration 2300 the Mean Squared Error is 2.7873379127168176
# At the iteration 2300 the Mean Squared Error is 2.784781047722047
# At the iteration 2300 the Mean Squared Error is 2.787222995925132
# At the iteration 2300 the Mean Squared Error is 2.786670385337031
# At the iteration 2300 the Mean Squared Error is 2.8239580909051716
# At the iteration 2300 the Mean Squared Error is 2.8174803758079463
# At the iteration 2300 the Mean Squared Error is 2.810241631083002
# At the iteration 2300 the Mean Squared Error is 2.8075738749766366
# At the iteration 2300 the Mean Squared Error is 2.7922888529939405
# At the iteration 2300 the Mean Squared Error is 2.845128550219078
# At the iteration 2300 the Mean Squared Error is 2.8465981451087727
# At the iteration 2300 the Mean Squared Error is 2.836019794501178
# At the iteration 2300 the Mean Squared Error is 2.805720239218106
# At the iteration 2300 the Mean Squared Error is 2.792950997964425
# At the iteration 2400 the Mean Squared Error is 2.786427306581112
# At the iteration 2400 the Mean Squared Error is 2.785300752753199
# At the iteration 2400 the Mean Squared Error is 2.8075342223431052
# At the iteration 2400 the Mean Squared Error is 2.786546160002855
# At the iteration 2400 the Mean Squared Error is 2.7901609680596606
# At the iteration 2400 the Mean Squared Error is 2.82128034992462
# At the iteration 2400 the Mean Squared Error is 2.882056310042072
# At the iteration 2400 the Mean Squared Error is 2.823058724292456
# At the iteration 2400 the Mean Squared Error is 2.8113607790321327
# At the iteration 2400 the Mean Squared Error is 2.7996104669395017
# At the iteration 2400 the Mean Squared Error is 2.7852445312654366
# At the iteration 2400 the Mean Squared Error is 2.7887694726650376
# At the iteration 2400 the Mean Squared Error is 2.7867116408879777
# At the iteration 2400 the Mean Squared Error is 2.791687891518677
# At the iteration 2400 the Mean Squared Error is 2.798382012115292
# At the iteration 2500 the Mean Squared Error is 2.7856857722316293
# At the iteration 2500 the Mean Squared Error is 2.7884704136710576
# At the iteration 2500 the Mean Squared Error is 2.8034900412905337
# At the iteration 2500 the Mean Squared Error is 2.7858918562080963
# At the iteration 2500 the Mean Squared Error is 2.789823302324942
# At the iteration 2500 the Mean Squared Error is 2.8092735391498014
# At the iteration 2500 the Mean Squared Error is 2.790393741440399
# At the iteration 2500 the Mean Squared Error is 2.78908528733042
# At the iteration 2500 the Mean Squared Error is 2.8959396988074335
# At the iteration 2500 the Mean Squared Error is 2.822760327637324
# At the iteration 2500 the Mean Squared Error is 2.792785153664172
# At the iteration 2500 the Mean Squared Error is 2.7894065026722603
# At the iteration 2500 the Mean Squared Error is 2.7863120253217124
# At the iteration 2500 the Mean Squared Error is 2.7858117801918967
# At the iteration 2500 the Mean Squared Error is 2.785581801642623
# At the iteration 2600 the Mean Squared Error is 2.786069834899814
# At the iteration 2600 the Mean Squared Error is 2.790092414564508
# At the iteration 2600 the Mean Squared Error is 2.7893578464499194
# At the iteration 2600 the Mean Squared Error is 2.7905371213668837
# At the iteration 2600 the Mean Squared Error is 2.79159733042323
# At the iteration 2600 the Mean Squared Error is 2.7880281323447274
# At the iteration 2600 the Mean Squared Error is 2.7924514881279983
# At the iteration 2600 the Mean Squared Error is 2.7862006707903832
# At the iteration 2600 the Mean Squared Error is 2.7862062360974833
# At the iteration 2600 the Mean Squared Error is 2.7962211259297307
# At the iteration 2600 the Mean Squared Error is 2.8152423489352008
# At the iteration 2600 the Mean Squared Error is 2.7885116503813094
# At the iteration 2600 the Mean Squared Error is 2.7971435866904786
# At the iteration 2600 the Mean Squared Error is 2.786439590321509
# At the iteration 2600 the Mean Squared Error is 2.79096456347519
# At the iteration 2700 the Mean Squared Error is 2.7860548820233073
# At the iteration 2700 the Mean Squared Error is 2.7968013899158257
# At the iteration 2700 the Mean Squared Error is 2.805439498198888
# At the iteration 2700 the Mean Squared Error is 2.7988238024015044
# At the iteration 2700 the Mean Squared Error is 2.792371640509899
# At the iteration 2700 the Mean Squared Error is 2.7867765043544908
# At the iteration 2700 the Mean Squared Error is 2.7864881674217306
# At the iteration 2700 the Mean Squared Error is 2.7871223711845854
# At the iteration 2700 the Mean Squared Error is 2.7936212290938793
# At the iteration 2700 the Mean Squared Error is 2.785281110221066
# At the iteration 2700 the Mean Squared Error is 2.784590809285395
# At the iteration 2700 the Mean Squared Error is 2.7842234009062254
# At the iteration 2700 the Mean Squared Error is 2.786034906364124
# At the iteration 2700 the Mean Squared Error is 2.7854870261315137
# At the iteration 2700 the Mean Squared Error is 2.7935125000538403
# At the iteration 2800 the Mean Squared Error is 2.7895944938383814
# At the iteration 2800 the Mean Squared Error is 2.7926930201675497
# At the iteration 2800 the Mean Squared Error is 2.813536919192909
# At the iteration 2800 the Mean Squared Error is 2.8431716642378775
# At the iteration 2800 the Mean Squared Error is 2.8018759004266642
# At the iteration 2800 the Mean Squared Error is 2.8037458028783737
# At the iteration 2800 the Mean Squared Error is 2.789574012549814
# At the iteration 2800 the Mean Squared Error is 2.793198261771941
# At the iteration 2800 the Mean Squared Error is 2.7869435358517864
# At the iteration 2800 the Mean Squared Error is 2.788186066704069
# At the iteration 2800 the Mean Squared Error is 2.790952943508255
# At the iteration 2800 the Mean Squared Error is 2.7887740647803736
# At the iteration 2800 the Mean Squared Error is 2.7842126467195594
# At the iteration 2800 the Mean Squared Error is 2.785673800115963
# At the iteration 2800 the Mean Squared Error is 2.7847745367225345
# At the iteration 2900 the Mean Squared Error is 2.7952073789753307
# At the iteration 2900 the Mean Squared Error is 2.7863917252041155
# At the iteration 2900 the Mean Squared Error is 2.832426200423918
# At the iteration 2900 the Mean Squared Error is 2.8228443449665908
# At the iteration 2900 the Mean Squared Error is 2.785274221867102
# At the iteration 2900 the Mean Squared Error is 2.784547527361857
# At the iteration 2900 the Mean Squared Error is 2.785825247244146
# At the iteration 2900 the Mean Squared Error is 2.8035476846020675
# At the iteration 2900 the Mean Squared Error is 2.8250715076579
# At the iteration 2900 the Mean Squared Error is 2.786575185323118
# At the iteration 2900 the Mean Squared Error is 2.813121142438667
# At the iteration 2900 the Mean Squared Error is 2.7975294960807844
# At the iteration 2900 the Mean Squared Error is 2.7917502873735884
# At the iteration 2900 the Mean Squared Error is 2.784986529007098
# At the iteration 2900 the Mean Squared Error is 2.8111913423925636
# At the iteration 3000 the Mean Squared Error is 2.7933789831235334
# At the iteration 3000 the Mean Squared Error is 2.78606193948469
# At the iteration 3000 the Mean Squared Error is 2.803640469339374
# At the iteration 3000 the Mean Squared Error is 2.7895017167734206
# At the iteration 3000 the Mean Squared Error is 2.7864258998006197
# At the iteration 3000 the Mean Squared Error is 2.7900973250257186
# At the iteration 3000 the Mean Squared Error is 2.7902869198766513
# At the iteration 3000 the Mean Squared Error is 2.7893793072329887
# At the iteration 3000 the Mean Squared Error is 2.798897872940778
# At the iteration 3000 the Mean Squared Error is 2.795554317661988
# At the iteration 3000 the Mean Squared Error is 2.794224052583623
# At the iteration 3000 the Mean Squared Error is 2.791559769977407
# At the iteration 3000 the Mean Squared Error is 2.7844172370660063
# At the iteration 3000 the Mean Squared Error is 2.785846394855298
# At the iteration 3000 the Mean Squared Error is 2.7842203525824236
# At the iteration 3100 the Mean Squared Error is 2.7880079451092015
# At the iteration 3100 the Mean Squared Error is 2.790138833221472
# At the iteration 3100 the Mean Squared Error is 2.806323057513658
# At the iteration 3100 the Mean Squared Error is 2.7978957328702307
# At the iteration 3100 the Mean Squared Error is 2.805076894397349
# At the iteration 3100 the Mean Squared Error is 2.7940396742502975
# At the iteration 3100 the Mean Squared Error is 2.821765106823226
# At the iteration 3100 the Mean Squared Error is 2.7937661675155647
# At the iteration 3100 the Mean Squared Error is 2.8136750897717606
# At the iteration 3100 the Mean Squared Error is 2.8206708257007502
# At the iteration 3100 the Mean Squared Error is 2.7930049210795755
# At the iteration 3100 the Mean Squared Error is 2.7924130238469087
# At the iteration 3100 the Mean Squared Error is 2.7874748097012825
# At the iteration 3100 the Mean Squared Error is 2.7864625240728684
# At the iteration 3100 the Mean Squared Error is 2.7906820422817993
# At the iteration 3200 the Mean Squared Error is 2.7853340185780953
# At the iteration 3200 the Mean Squared Error is 2.8078515797243546
# At the iteration 3200 the Mean Squared Error is 2.785838785501078
# At the iteration 3200 the Mean Squared Error is 2.804840596341774
# At the iteration 3200 the Mean Squared Error is 2.7875000203781446
# At the iteration 3200 the Mean Squared Error is 2.784990179602296
# At the iteration 3200 the Mean Squared Error is 2.7847340093198927
# At the iteration 3200 the Mean Squared Error is 2.7876917111398565
# At the iteration 3200 the Mean Squared Error is 2.7898232376341277
# At the iteration 3200 the Mean Squared Error is 2.8065796839321577
# At the iteration 3200 the Mean Squared Error is 2.7905716761774575
# At the iteration 3200 the Mean Squared Error is 2.8035806607114786
# At the iteration 3200 the Mean Squared Error is 2.79542953161827
# At the iteration 3200 the Mean Squared Error is 2.785035664305539
# At the iteration 3200 the Mean Squared Error is 2.8009034522445764
# At the iteration 3300 the Mean Squared Error is 2.784249191509937
# At the iteration 3300 the Mean Squared Error is 2.787139826892733
# At the iteration 3300 the Mean Squared Error is 2.8227697131138605
# At the iteration 3300 the Mean Squared Error is 2.8394820441669775
# At the iteration 3300 the Mean Squared Error is 2.790777597847949
# At the iteration 3300 the Mean Squared Error is 2.82522567804333
# At the iteration 3300 the Mean Squared Error is 2.8067824065161004
# At the iteration 3300 the Mean Squared Error is 2.78464345554705
# At the iteration 3300 the Mean Squared Error is 2.8080548915311385
# At the iteration 3300 the Mean Squared Error is 2.7995526498858054
# At the iteration 3300 the Mean Squared Error is 2.790913173698714
# At the iteration 3300 the Mean Squared Error is 2.7971611000142524
# At the iteration 3300 the Mean Squared Error is 2.7946867639919954
# At the iteration 3300 the Mean Squared Error is 2.802660867601369
# At the iteration 3300 the Mean Squared Error is 2.78946284832237
# At the iteration 3400 the Mean Squared Error is 2.806655760208254
# At the iteration 3400 the Mean Squared Error is 2.799093575091331
# At the iteration 3400 the Mean Squared Error is 2.8371796531595526
# At the iteration 3400 the Mean Squared Error is 2.7862202872971102
# At the iteration 3400 the Mean Squared Error is 2.7934140184249916
# At the iteration 3400 the Mean Squared Error is 2.7872410118666937
# At the iteration 3400 the Mean Squared Error is 2.7874328163655258
# At the iteration 3400 the Mean Squared Error is 2.784502044322402
# At the iteration 3400 the Mean Squared Error is 2.8050879784399463
# At the iteration 3400 the Mean Squared Error is 2.8200249635111914
# At the iteration 3400 the Mean Squared Error is 2.7931623144131184
# At the iteration 3400 the Mean Squared Error is 2.7933022034911024
# At the iteration 3400 the Mean Squared Error is 2.7957249596689575
# At the iteration 3400 the Mean Squared Error is 2.7869161389469728
# At the iteration 3400 the Mean Squared Error is 2.7913455970025427
# At the iteration 3500 the Mean Squared Error is 2.8015912397269056
# At the iteration 3500 the Mean Squared Error is 2.8084793005614856
# At the iteration 3500 the Mean Squared Error is 2.8244297915295284
# At the iteration 3500 the Mean Squared Error is 2.7920857886045134
# At the iteration 3500 the Mean Squared Error is 2.7878000170301624
# At the iteration 3500 the Mean Squared Error is 2.793825410984431
# At the iteration 3500 the Mean Squared Error is 2.807708620498241
# At the iteration 3500 the Mean Squared Error is 2.787179776339028
# At the iteration 3500 the Mean Squared Error is 2.7990723384268654
# At the iteration 3500 the Mean Squared Error is 2.7969505013293703
# At the iteration 3500 the Mean Squared Error is 2.8168076794108674
# At the iteration 3500 the Mean Squared Error is 2.803949471979994
# At the iteration 3500 the Mean Squared Error is 2.7850668716397586
# At the iteration 3500 the Mean Squared Error is 2.7857623254789825
# At the iteration 3500 the Mean Squared Error is 2.784541196486282
# At the iteration 3600 the Mean Squared Error is 2.7981816441631615
# At the iteration 3600 the Mean Squared Error is 2.786132592080228
# At the iteration 3600 the Mean Squared Error is 2.785607094553898
# At the iteration 3600 the Mean Squared Error is 2.7845926276664787
# At the iteration 3600 the Mean Squared Error is 2.791937340158455
# At the iteration 3600 the Mean Squared Error is 2.798055776716885
# At the iteration 3600 the Mean Squared Error is 2.815900210838245
# At the iteration 3600 the Mean Squared Error is 2.8063319338019848
# At the iteration 3600 the Mean Squared Error is 2.8071967307168793
# At the iteration 3600 the Mean Squared Error is 2.787408247105231
# At the iteration 3600 the Mean Squared Error is 2.787908847114716
# At the iteration 3600 the Mean Squared Error is 2.7867387006180326
# At the iteration 3600 the Mean Squared Error is 2.792230425908564
# At the iteration 3600 the Mean Squared Error is 2.7883597661930115
# At the iteration 3600 the Mean Squared Error is 2.789691357164529
# At the iteration 3700 the Mean Squared Error is 2.9287759191545866
# At the iteration 3700 the Mean Squared Error is 2.820266775116538
# At the iteration 3700 the Mean Squared Error is 2.793188687311862
# At the iteration 3700 the Mean Squared Error is 2.788649170058352
# At the iteration 3700 the Mean Squared Error is 2.827283517566231
# At the iteration 3700 the Mean Squared Error is 2.785724819256519
# At the iteration 3700 the Mean Squared Error is 2.785014350027621
# At the iteration 3700 the Mean Squared Error is 2.787195542706803
# At the iteration 3700 the Mean Squared Error is 2.7893397381003933
# At the iteration 3700 the Mean Squared Error is 2.787923137708781
# At the iteration 3700 the Mean Squared Error is 2.7871981092063116
# At the iteration 3700 the Mean Squared Error is 2.7886014763955043
# At the iteration 3700 the Mean Squared Error is 2.7925942418279623
# At the iteration 3700 the Mean Squared Error is 2.7930781481790983
# At the iteration 3700 the Mean Squared Error is 2.8034285132472743
# At the iteration 3800 the Mean Squared Error is 2.8023113907803663
# At the iteration 3800 the Mean Squared Error is 2.8475301127232613
# At the iteration 3800 the Mean Squared Error is 2.796811425218248
# At the iteration 3800 the Mean Squared Error is 2.7903036051530496
# At the iteration 3800 the Mean Squared Error is 2.7906792358985753
# At the iteration 3800 the Mean Squared Error is 2.7907000549745864
# At the iteration 3800 the Mean Squared Error is 2.8423349015732913
# At the iteration 3800 the Mean Squared Error is 2.796396284216849
# At the iteration 3800 the Mean Squared Error is 2.7901951029301153
# At the iteration 3800 the Mean Squared Error is 2.7926179587582203
# At the iteration 3800 the Mean Squared Error is 2.7867889694452503
# At the iteration 3800 the Mean Squared Error is 2.7846668508567656
# At the iteration 3800 the Mean Squared Error is 2.792928656874285
# At the iteration 3800 the Mean Squared Error is 2.80113143909296
# At the iteration 3800 the Mean Squared Error is 2.8117502860180004
# At the iteration 3900 the Mean Squared Error is 2.785045442019373
# At the iteration 3900 the Mean Squared Error is 2.78996211727891
# At the iteration 3900 the Mean Squared Error is 2.7867518463714727
# At the iteration 3900 the Mean Squared Error is 2.791479458786463
# At the iteration 3900 the Mean Squared Error is 2.806564128516357
# At the iteration 3900 the Mean Squared Error is 2.7886565842546753
# At the iteration 3900 the Mean Squared Error is 2.797193735832613
# At the iteration 3900 the Mean Squared Error is 2.837960045665204
# At the iteration 3900 the Mean Squared Error is 2.7942521077939677
# At the iteration 3900 the Mean Squared Error is 2.7870898640393422
# At the iteration 3900 the Mean Squared Error is 2.7854303403734617
# At the iteration 3900 the Mean Squared Error is 2.795678456555481
# At the iteration 3900 the Mean Squared Error is 2.7850192772276525
# At the iteration 3900 the Mean Squared Error is 2.7914818016493497
# At the iteration 3900 the Mean Squared Error is 2.8286379238963235
# At the iteration 4000 the Mean Squared Error is 2.7872214370088404
# At the iteration 4000 the Mean Squared Error is 2.7870176707266263
# At the iteration 4000 the Mean Squared Error is 2.8295810058731132
# At the iteration 4000 the Mean Squared Error is 2.7926637521448465
# At the iteration 4000 the Mean Squared Error is 2.785747488901627
# At the iteration 4000 the Mean Squared Error is 2.7851449778674042
# At the iteration 4000 the Mean Squared Error is 2.787781558227058
# At the iteration 4000 the Mean Squared Error is 2.8123829789988997
# At the iteration 4000 the Mean Squared Error is 2.796306449311187
# At the iteration 4000 the Mean Squared Error is 2.7892123350354363
# At the iteration 4000 the Mean Squared Error is 2.8019280823852224
# At the iteration 4000 the Mean Squared Error is 2.793725002303904
# At the iteration 4000 the Mean Squared Error is 2.78723137015565
# At the iteration 4000 the Mean Squared Error is 2.788620023949467
# At the iteration 4000 the Mean Squared Error is 2.78517564471358
# At the iteration 4100 the Mean Squared Error is 2.786149131587712
# At the iteration 4100 the Mean Squared Error is 2.7888152303444764
# At the iteration 4100 the Mean Squared Error is 2.7988691016177256
# At the iteration 4100 the Mean Squared Error is 2.8008079195134394
# At the iteration 4100 the Mean Squared Error is 2.7962941902363387
# At the iteration 4100 the Mean Squared Error is 2.785652622718778
# At the iteration 4100 the Mean Squared Error is 2.7938016916301747
# At the iteration 4100 the Mean Squared Error is 2.7997959783676003
# At the iteration 4100 the Mean Squared Error is 2.795534231922167
# At the iteration 4100 the Mean Squared Error is 2.790370607351035
# At the iteration 4100 the Mean Squared Error is 2.7913774090600953
# At the iteration 4100 the Mean Squared Error is 2.792198837325409
# At the iteration 4100 the Mean Squared Error is 2.7894864757892344
# At the iteration 4100 the Mean Squared Error is 2.7868826375903866
# At the iteration 4100 the Mean Squared Error is 2.797980751674797
# At the iteration 4200 the Mean Squared Error is 2.7852831183877176
# At the iteration 4200 the Mean Squared Error is 2.784979142077928
# At the iteration 4200 the Mean Squared Error is 2.785127088369992
# At the iteration 4200 the Mean Squared Error is 2.802395030330325
# At the iteration 4200 the Mean Squared Error is 2.8047190169707688
# At the iteration 4200 the Mean Squared Error is 2.8032353804080388
# At the iteration 4200 the Mean Squared Error is 2.787897297934425
# At the iteration 4200 the Mean Squared Error is 2.7883620383004897
# At the iteration 4200 the Mean Squared Error is 2.8033747189382954
# At the iteration 4200 the Mean Squared Error is 2.7917633850403996
# At the iteration 4200 the Mean Squared Error is 2.79829364590021
# At the iteration 4200 the Mean Squared Error is 2.791660821791753
# At the iteration 4200 the Mean Squared Error is 2.791748079689488
# At the iteration 4200 the Mean Squared Error is 2.802471872739754
# At the iteration 4200 the Mean Squared Error is 2.7876460256467395
# At the iteration 4300 the Mean Squared Error is 2.78747430590439
# At the iteration 4300 the Mean Squared Error is 2.7887385658096893
# At the iteration 4300 the Mean Squared Error is 2.789524120987414
# At the iteration 4300 the Mean Squared Error is 2.823813991592262
# At the iteration 4300 the Mean Squared Error is 2.8469596680789824
# At the iteration 4300 the Mean Squared Error is 2.824607009746491
# At the iteration 4300 the Mean Squared Error is 2.789673939821867
# At the iteration 4300 the Mean Squared Error is 2.813892200586522
# At the iteration 4300 the Mean Squared Error is 2.7893663258701893
# At the iteration 4300 the Mean Squared Error is 2.7912804172483408
# At the iteration 4300 the Mean Squared Error is 2.799251439039525
# At the iteration 4300 the Mean Squared Error is 2.7880707666814293
# At the iteration 4300 the Mean Squared Error is 2.7866672694100116
# At the iteration 4300 the Mean Squared Error is 2.789609989424851
# At the iteration 4300 the Mean Squared Error is 2.7929224494482527
# At the iteration 4400 the Mean Squared Error is 2.7947082056956485
# At the iteration 4400 the Mean Squared Error is 2.798866598375342
# At the iteration 4400 the Mean Squared Error is 2.788949930645415
# At the iteration 4400 the Mean Squared Error is 2.7912800568926905
# At the iteration 4400 the Mean Squared Error is 2.785056910350765
# At the iteration 4400 the Mean Squared Error is 2.7953944212886754
# At the iteration 4400 the Mean Squared Error is 2.8008566335091523
# At the iteration 4400 the Mean Squared Error is 2.7950413983453757
# At the iteration 4400 the Mean Squared Error is 2.8015417448011353
# At the iteration 4400 the Mean Squared Error is 2.7873707758442405
# At the iteration 4400 the Mean Squared Error is 2.785841357400805
# At the iteration 4400 the Mean Squared Error is 2.7901948875230227
# At the iteration 4400 the Mean Squared Error is 2.792721044345328
# At the iteration 4400 the Mean Squared Error is 2.7850399664759546
# At the iteration 4400 the Mean Squared Error is 2.7857789267593653
# At the iteration 4500 the Mean Squared Error is 2.798436188065484
# At the iteration 4500 the Mean Squared Error is 2.806908154891559
# At the iteration 4500 the Mean Squared Error is 2.7900668529104293
# At the iteration 4500 the Mean Squared Error is 2.7934340884177584
# At the iteration 4500 the Mean Squared Error is 2.787915092619313
# At the iteration 4500 the Mean Squared Error is 2.8071225626431606
# At the iteration 4500 the Mean Squared Error is 2.7853489000384677
# At the iteration 4500 the Mean Squared Error is 2.7896846706109146
# At the iteration 4500 the Mean Squared Error is 2.803874604038539
# At the iteration 4500 the Mean Squared Error is 2.792941975332991
# At the iteration 4500 the Mean Squared Error is 2.7846880487641954
# At the iteration 4500 the Mean Squared Error is 2.787079269930764
# At the iteration 4500 the Mean Squared Error is 2.7847376179600634
# At the iteration 4500 the Mean Squared Error is 2.7869753063620637
# At the iteration 4500 the Mean Squared Error is 2.7860042373876017
# At the iteration 4600 the Mean Squared Error is 2.7925727577433146
# At the iteration 4600 the Mean Squared Error is 2.8053822838702676
# At the iteration 4600 the Mean Squared Error is 2.8356994760562473
# At the iteration 4600 the Mean Squared Error is 2.8171753361521503
# At the iteration 4600 the Mean Squared Error is 2.7902241798345653
# At the iteration 4600 the Mean Squared Error is 2.7849745411850164
# At the iteration 4600 the Mean Squared Error is 2.819145962065381
# At the iteration 4600 the Mean Squared Error is 2.848796002826883
# At the iteration 4600 the Mean Squared Error is 2.856055094723097
# At the iteration 4600 the Mean Squared Error is 2.795931171531888
# At the iteration 4600 the Mean Squared Error is 2.7990010084735157
# At the iteration 4600 the Mean Squared Error is 2.793733504491399
# At the iteration 4600 the Mean Squared Error is 2.785510766016929
# At the iteration 4600 the Mean Squared Error is 2.7870565585943603
# At the iteration 4600 the Mean Squared Error is 2.7850718869857043
# At the iteration 4700 the Mean Squared Error is 2.7854660556101796
# At the iteration 4700 the Mean Squared Error is 2.7906129447555723
# At the iteration 4700 the Mean Squared Error is 2.785096806186244
# At the iteration 4700 the Mean Squared Error is 2.795207695850369
# At the iteration 4700 the Mean Squared Error is 2.806684304306151
# At the iteration 4700 the Mean Squared Error is 2.7945145225540897
# At the iteration 4700 the Mean Squared Error is 2.784702975298143
# At the iteration 4700 the Mean Squared Error is 2.785176485990346
# At the iteration 4700 the Mean Squared Error is 2.7885898808631286
# At the iteration 4700 the Mean Squared Error is 2.784993175092329
# At the iteration 4700 the Mean Squared Error is 2.7864535885804855
# At the iteration 4700 the Mean Squared Error is 2.79909856923001
# At the iteration 4700 the Mean Squared Error is 2.7930947962354207
# At the iteration 4700 the Mean Squared Error is 2.802091213473176
# At the iteration 4700 the Mean Squared Error is 2.824927990786047
# At the iteration 4800 the Mean Squared Error is 2.7871536293721726
# At the iteration 4800 the Mean Squared Error is 2.7854096714150516
# At the iteration 4800 the Mean Squared Error is 2.7854558830627583
# At the iteration 4800 the Mean Squared Error is 2.8051545635412367
# At the iteration 4800 the Mean Squared Error is 2.7908001021176636
# At the iteration 4800 the Mean Squared Error is 2.810775462959766
# At the iteration 4800 the Mean Squared Error is 2.78776908917721
# At the iteration 4800 the Mean Squared Error is 2.7980589309650825
# At the iteration 4800 the Mean Squared Error is 2.8103733121809595
# At the iteration 4800 the Mean Squared Error is 2.8005390242884847
# At the iteration 4800 the Mean Squared Error is 2.824590687225229
# At the iteration 4800 the Mean Squared Error is 2.7861371315123593
# At the iteration 4800 the Mean Squared Error is 2.78626824676944
# At the iteration 4800 the Mean Squared Error is 2.7865602935415152
# At the iteration 4800 the Mean Squared Error is 2.784499670906937
# At the iteration 4900 the Mean Squared Error is 2.7881841142127928
# At the iteration 4900 the Mean Squared Error is 2.8050569710621214
# At the iteration 4900 the Mean Squared Error is 2.7946085889322085
# At the iteration 4900 the Mean Squared Error is 2.792441168610395
# ...
# At the iteration 8500 the Mean Squared Error is 2.8683480166557103
# At the iteration 8500 the Mean Squared Error is 2.8508732179845873
# At the iteration 8500 the Mean Squared Error is 2.796723500208642
# At the iteration 8500 the Mean Squared Error is 2.7867970030732785
# At the iteration 8500 the Mean Squared Error is 2.7884429506367723
# At the iteration 8500 the Mean Squared Error is 2.787250129567358
# At the iteration 8500 the Mean Squared Error is 2.7883589234424253
# At the iteration 8500 the Mean Squared Error is 2.7895519206273893
# At the iteration 8500 the Mean Squared Error is 2.7881118770462785
# At the iteration 8500 the Mean Squared Error is 2.7880485154566377
# At the iteration 8500 the Mean Squared Error is 2.7864463324459483
# At the iteration 8500 the Mean Squared Error is 2.789019455918259
# At the iteration 8500 the Mean Squared Error is 2.784248509620686
# At the iteration 8500 the Mean Squared Error is 2.7854690881040973
# At the iteration 8500 the Mean Squared Error is 2.784782310517096
# At the iteration 8600 the Mean Squared Error is 2.8257422065092146
# At the iteration 8600 the Mean Squared Error is 2.8288226893703547
# At the iteration 8600 the Mean Squared Error is 2.8354534806906964
# At the iteration 8600 the Mean Squared Error is 2.784521257136163
# At the iteration 8600 the Mean Squared Error is 2.7943861272462005
# At the iteration 8600 the Mean Squared Error is 2.801522184744666
# At the iteration 8600 the Mean Squared Error is 2.811699382632792
# At the iteration 8600 the Mean Squared Error is 2.848338477859203
# At the iteration 8600 the Mean Squared Error is 2.8403783637976368
# At the iteration 8600 the Mean Squared Error is 2.8389621881813643
# At the iteration 8600 the Mean Squared Error is 2.7871382294557225
# At the iteration 8600 the Mean Squared Error is 2.7856225218711224
# At the iteration 8600 the Mean Squared Error is 2.78474331876371
# At the iteration 8600 the Mean Squared Error is 2.8053308342251837
# At the iteration 8600 the Mean Squared Error is 2.8015831561176325
# At the iteration 8700 the Mean Squared Error is 2.788756810112177
# At the iteration 8700 the Mean Squared Error is 2.786495354787464
# At the iteration 8700 the Mean Squared Error is 2.7863978144356993
# At the iteration 8700 the Mean Squared Error is 2.7860151752199274
# At the iteration 8700 the Mean Squared Error is 2.7859779977810266
# At the iteration 8700 the Mean Squared Error is 2.787503048703472
# At the iteration 8700 the Mean Squared Error is 2.7860459346436057
# At the iteration 8700 the Mean Squared Error is 2.7843633526906104
# At the iteration 8700 the Mean Squared Error is 2.7921022319147037
# At the iteration 8700 the Mean Squared Error is 2.8010244824905306
# At the iteration 8700 the Mean Squared Error is 2.7852464751449033
# At the iteration 8700 the Mean Squared Error is 2.784836586159559
# At the iteration 8700 the Mean Squared Error is 2.791272480928865
# At the iteration 8700 the Mean Squared Error is 2.7841672299735274
# At the iteration 8700 the Mean Squared Error is 2.790715089056722
# At the iteration 8800 the Mean Squared Error is 2.7938783798766305
# At the iteration 8800 the Mean Squared Error is 2.813321992509917
# At the iteration 8800 the Mean Squared Error is 2.7879772357555272
# At the iteration 8800 the Mean Squared Error is 2.7869314144400037
# At the iteration 8800 the Mean Squared Error is 2.786483088851506
# At the iteration 8800 the Mean Squared Error is 2.7886242064581896
# At the iteration 8800 the Mean Squared Error is 2.789331893539577
# At the iteration 8800 the Mean Squared Error is 2.786325164031266
# At the iteration 8800 the Mean Squared Error is 2.7971153157246333
# At the iteration 8800 the Mean Squared Error is 2.7843832472116183
# At the iteration 8800 the Mean Squared Error is 2.798403034423673
# At the iteration 8800 the Mean Squared Error is 2.7923824256433165
# At the iteration 8800 the Mean Squared Error is 2.8146291598073043
# At the iteration 8800 the Mean Squared Error is 2.822870088279652
# At the iteration 8800 the Mean Squared Error is 2.7910235162447146
# At the iteration 8900 the Mean Squared Error is 2.784791277681627
# At the iteration 8900 the Mean Squared Error is 2.8128006616825165
# At the iteration 8900 the Mean Squared Error is 2.8086583144550303
# At the iteration 8900 the Mean Squared Error is 2.798137505023799
# At the iteration 8900 the Mean Squared Error is 2.817836452318108
# At the iteration 8900 the Mean Squared Error is 2.8272694284573476
# At the iteration 8900 the Mean Squared Error is 2.7927128671344543
# At the iteration 8900 the Mean Squared Error is 2.7870960963560396
# At the iteration 8900 the Mean Squared Error is 2.7920706296019464
# At the iteration 8900 the Mean Squared Error is 2.7891739672155724
# At the iteration 8900 the Mean Squared Error is 2.793291421671833
# At the iteration 8900 the Mean Squared Error is 2.8003847521698004
# At the iteration 8900 the Mean Squared Error is 2.7890914829272537
# At the iteration 8900 the Mean Squared Error is 2.809140252089118
# At the iteration 8900 the Mean Squared Error is 2.7913143354875363
# At the iteration 9000 the Mean Squared Error is 2.786697697910414
# At the iteration 9000 the Mean Squared Error is 2.7844602303300303
# At the iteration 9000 the Mean Squared Error is 2.8042446866033806
# At the iteration 9000 the Mean Squared Error is 2.7964462014515687
# At the iteration 9000 the Mean Squared Error is 2.796377254723926
# At the iteration 9000 the Mean Squared Error is 2.7856890753211103
# At the iteration 9000 the Mean Squared Error is 2.819146265686615
# At the iteration 9000 the Mean Squared Error is 2.7872072342236254
# At the iteration 9000 the Mean Squared Error is 2.788671305882245
# At the iteration 9000 the Mean Squared Error is 2.7855000613314638
# At the iteration 9000 the Mean Squared Error is 2.7894219182078275
# At the iteration 9000 the Mean Squared Error is 2.7871591756464293
# At the iteration 9000 the Mean Squared Error is 2.7853493541793135
# At the iteration 9000 the Mean Squared Error is 2.7868479887633377
# At the iteration 9000 the Mean Squared Error is 2.7846051473257645
# At the iteration 9100 the Mean Squared Error is 2.8003582081599516
# At the iteration 9100 the Mean Squared Error is 2.7961860402814795
# At the iteration 9100 the Mean Squared Error is 2.829173106509831
# At the iteration 9100 the Mean Squared Error is 2.805608199958676
# At the iteration 9100 the Mean Squared Error is 2.800364402345234
# At the iteration 9100 the Mean Squared Error is 2.8031337549002022
# At the iteration 9100 the Mean Squared Error is 2.7851346152068506
# At the iteration 9100 the Mean Squared Error is 2.7842366656612594
# At the iteration 9100 the Mean Squared Error is 2.811985706742679
# At the iteration 9100 the Mean Squared Error is 2.7891023930230165
# At the iteration 9100 the Mean Squared Error is 2.797101360524961
# At the iteration 9100 the Mean Squared Error is 2.835363188982981
# At the iteration 9100 the Mean Squared Error is 2.787706670545756
# At the iteration 9100 the Mean Squared Error is 2.7848674052245195
# At the iteration 9100 the Mean Squared Error is 2.7844599811452415
# At the iteration 9200 the Mean Squared Error is 2.7878120655592977
# At the iteration 9200 the Mean Squared Error is 2.7924682931353892
# At the iteration 9200 the Mean Squared Error is 2.8191748392082956
# At the iteration 9200 the Mean Squared Error is 2.7868513754931414
# At the iteration 9200 the Mean Squared Error is 2.787132216087378
# At the iteration 9200 the Mean Squared Error is 2.801625033736649
# At the iteration 9200 the Mean Squared Error is 2.7923973398871516
# At the iteration 9200 the Mean Squared Error is 2.787386370749301
# At the iteration 9200 the Mean Squared Error is 2.7903116377222896
# At the iteration 9200 the Mean Squared Error is 2.7861665081831166
# At the iteration 9200 the Mean Squared Error is 2.78986400307031
# At the iteration 9200 the Mean Squared Error is 2.7940050203756015
# At the iteration 9200 the Mean Squared Error is 2.8054395159868863
# At the iteration 9200 the Mean Squared Error is 2.7916837493786257
# At the iteration 9200 the Mean Squared Error is 2.7849696377401756
# At the iteration 9300 the Mean Squared Error is 2.8017006095304815
# At the iteration 9300 the Mean Squared Error is 2.8204903511037593
# At the iteration 9300 the Mean Squared Error is 2.7963639788605157
# At the iteration 9300 the Mean Squared Error is 2.8005349130238697
# At the iteration 9300 the Mean Squared Error is 2.7871335061147238
# At the iteration 9300 the Mean Squared Error is 2.8009190603802563
# At the iteration 9300 the Mean Squared Error is 2.7852314505725655
# At the iteration 9300 the Mean Squared Error is 2.792177984980901
# At the iteration 9300 the Mean Squared Error is 2.85436296428781
# At the iteration 9300 the Mean Squared Error is 2.806927770669604
# At the iteration 9300 the Mean Squared Error is 2.8162076602678474
# At the iteration 9300 the Mean Squared Error is 2.786570660776623
# At the iteration 9300 the Mean Squared Error is 2.802081546965971
# At the iteration 9300 the Mean Squared Error is 2.8055549476242243
# At the iteration 9300 the Mean Squared Error is 2.7857611791410557
# At the iteration 9400 the Mean Squared Error is 2.822030810520579
# At the iteration 9400 the Mean Squared Error is 2.8923139496041816
# At the iteration 9400 the Mean Squared Error is 2.829001192182426
# At the iteration 9400 the Mean Squared Error is 2.8015051846664063
# At the iteration 9400 the Mean Squared Error is 2.8081438950781203
# At the iteration 9400 the Mean Squared Error is 2.797261224410089
# At the iteration 9400 the Mean Squared Error is 2.7878882170903414
# At the iteration 9400 the Mean Squared Error is 2.801883042340577
# At the iteration 9400 the Mean Squared Error is 2.7990136915103654
# At the iteration 9400 the Mean Squared Error is 2.796742052770047
# At the iteration 9400 the Mean Squared Error is 2.8190635368204005
# At the iteration 9400 the Mean Squared Error is 2.841497630325905
# At the iteration 9400 the Mean Squared Error is 2.8250866054640404
# At the iteration 9400 the Mean Squared Error is 2.791846229664311
# At the iteration 9400 the Mean Squared Error is 2.788266938734546
# At the iteration 9500 the Mean Squared Error is 2.7913417061280654
# At the iteration 9500 the Mean Squared Error is 2.784303641737277
# At the iteration 9500 the Mean Squared Error is 2.785354837958816
# At the iteration 9500 the Mean Squared Error is 2.7880358617087233
# At the iteration 9500 the Mean Squared Error is 2.789799157278046
# At the iteration 9500 the Mean Squared Error is 2.7861378857926926
# At the iteration 9500 the Mean Squared Error is 2.7897928187976206
# At the iteration 9500 the Mean Squared Error is 2.7899968875323795
# At the iteration 9500 the Mean Squared Error is 2.796150325026442
# At the iteration 9500 the Mean Squared Error is 2.7877865170758334
# At the iteration 9500 the Mean Squared Error is 2.793030002113495
# At the iteration 9500 the Mean Squared Error is 2.8032171009853806
# At the iteration 9500 the Mean Squared Error is 2.799407654962764
# At the iteration 9500 the Mean Squared Error is 2.7888683711593867
# At the iteration 9500 the Mean Squared Error is 2.7851813397853595
# At the iteration 9600 the Mean Squared Error is 2.7911105679507187
# At the iteration 9600 the Mean Squared Error is 2.787309581825622
# At the iteration 9600 the Mean Squared Error is 2.7867509335986176
# At the iteration 9600 the Mean Squared Error is 2.785301716729052
# At the iteration 9600 the Mean Squared Error is 2.7872804958659323
# At the iteration 9600 the Mean Squared Error is 2.785058662868828
# At the iteration 9600 the Mean Squared Error is 2.805247197973693
# At the iteration 9600 the Mean Squared Error is 2.7871215919176415
# At the iteration 9600 the Mean Squared Error is 2.8013731535891817
# At the iteration 9600 the Mean Squared Error is 2.840216298232465
# At the iteration 9600 the Mean Squared Error is 2.7924621290206404
# At the iteration 9600 the Mean Squared Error is 2.8319846590153825
# At the iteration 9600 the Mean Squared Error is 2.793315981121815
# At the iteration 9600 the Mean Squared Error is 2.787001287388175
# At the iteration 9600 the Mean Squared Error is 2.8323171146838617
# At the iteration 9700 the Mean Squared Error is 2.787185758659682
# At the iteration 9700 the Mean Squared Error is 2.7851037031553267
# At the iteration 9700 the Mean Squared Error is 2.784626297175313
# At the iteration 9700 the Mean Squared Error is 2.797454734486593
# At the iteration 9700 the Mean Squared Error is 2.784491704485595
# At the iteration 9700 the Mean Squared Error is 2.785032570144616
# At the iteration 9700 the Mean Squared Error is 2.7846540979254826
# At the iteration 9700 the Mean Squared Error is 2.7843583130581133
# At the iteration 9700 the Mean Squared Error is 2.7842727000303373
# At the iteration 9700 the Mean Squared Error is 2.7864744749104786
# At the iteration 9700 the Mean Squared Error is 2.7848281396333756
# At the iteration 9700 the Mean Squared Error is 2.7860076322510405
# At the iteration 9700 the Mean Squared Error is 2.7862040923455846
# At the iteration 9700 the Mean Squared Error is 2.7848962323824935
# At the iteration 9700 the Mean Squared Error is 2.78422948788261
# At the iteration 9800 the Mean Squared Error is 2.7874421904675866
# At the iteration 9800 the Mean Squared Error is 2.787811392902084
# At the iteration 9800 the Mean Squared Error is 2.7895767632931916
# At the iteration 9800 the Mean Squared Error is 2.7872237996095865
# At the iteration 9800 the Mean Squared Error is 2.7933873921512133
# At the iteration 9800 the Mean Squared Error is 2.7918532246838943
# At the iteration 9800 the Mean Squared Error is 2.7946125699398014
# At the iteration 9800 the Mean Squared Error is 2.7940285343756157
# At the iteration 9800 the Mean Squared Error is 2.7889690801897813
# At the iteration 9800 the Mean Squared Error is 2.78930188388135
# At the iteration 9800 the Mean Squared Error is 2.7883113861338735
# At the iteration 9800 the Mean Squared Error is 2.787572139276991
# At the iteration 9800 the Mean Squared Error is 2.798933299098834
# At the iteration 9800 the Mean Squared Error is 2.7857602983637544
# At the iteration 9800 the Mean Squared Error is 2.796413047011033
# At the iteration 9900 the Mean Squared Error is 2.7972586781543796
# At the iteration 9900 the Mean Squared Error is 2.787621053975837
# At the iteration 9900 the Mean Squared Error is 2.786532204201967
# At the iteration 9900 the Mean Squared Error is 2.7883133528097157
# At the iteration 9900 the Mean Squared Error is 2.7860826926221343
# At the iteration 9900 the Mean Squared Error is 2.7863127642334002
# At the iteration 9900 the Mean Squared Error is 2.805525528314011
# At the iteration 9900 the Mean Squared Error is 2.8537918785065046
# At the iteration 9900 the Mean Squared Error is 2.832176763134455
# At the iteration 9900 the Mean Squared Error is 2.7955722064664803
# At the iteration 9900 the Mean Squared Error is 2.7993820519995953
# At the iteration 9900 the Mean Squared Error is 2.8022183824904032
# At the iteration 9900 the Mean Squared Error is 2.787390626337486
# At the iteration 9900 the Mean Squared Error is 2.7865455182695062
# At the iteration 9900 the Mean Squared Error is 2.7972704663483365
# At the iteration 10000 the Mean Squared Error is 2.789437629985558
# At the iteration 10000 the Mean Squared Error is 2.784386582699256
# At the iteration 10000 the Mean Squared Error is 2.793662445556795
# At the iteration 10000 the Mean Squared Error is 2.81279568023888
# At the iteration 10000 the Mean Squared Error is 2.7923940874863167
# At the iteration 10000 the Mean Squared Error is 2.8011323061802553
# At the iteration 10000 the Mean Squared Error is 2.787271198499701
# At the iteration 10000 the Mean Squared Error is 2.7904029576266454
# At the iteration 10000 the Mean Squared Error is 2.8353982120140713
# At the iteration 10000 the Mean Squared Error is 2.8228140140564006
# At the iteration 10000 the Mean Squared Error is 2.7872670978109797
# At the iteration 10000 the Mean Squared Error is 2.785984424920965
# At the iteration 10000 the Mean Squared Error is 2.7920501325935807
# At the iteration 10000 the Mean Squared Error is 2.7854938566996905
# At the iteration 10000 the Mean Squared Error is 2.784724522594477

# %% [markdown]
# ## RMSPROP

# %%
w = [1,2,3,4]
batch_size = 15
epochs = 10000
eta = 0.1
gama = 0.5
epsilon = 0.01
s = 0
path = [w]

# %%
for i in range(epochs):
  for batch_ind in np.array_split(np.random.permutation(range(len(x))),batch_size):
    xs = x_aug[batch_ind]
    ys = y[batch_ind]
    lr = eta/np.sqrt(s+epsilon)
    g = gradient(w,xs,ys)
    w_new = w - lr*g
    path.append(w_new)
    s = gama*s + (1-gama)*sum(g**2)
    if np.mean(abs(w-w_new))<1e-6:
      break
    if (i+1)%100==0:
      print(f"At the iteration {i+1} the Mean Squared Error is {MSE(w_new,x_aug,y)}")
    w = w_new
# Out:
# At the iteration 100 the Mean Squared Error is 2.8718451300203918
# At the iteration 100 the Mean Squared Error is 2.8841286703068683
# At the iteration 100 the Mean Squared Error is 2.86027264805761
# At the iteration 100 the Mean Squared Error is 2.8808031214452607
# At the iteration 100 the Mean Squared Error is 2.941582957164295
# At the iteration 100 the Mean Squared Error is 3.089227259174954
# At the iteration 100 the Mean Squared Error is 3.0443763238604715
# At the iteration 100 the Mean Squared Error is 3.0221085398670753
# At the iteration 100 the Mean Squared Error is 3.08663704347918
# At the iteration 100 the Mean Squared Error is 2.881490486954906
# At the iteration 100 the Mean Squared Error is 2.866968764199846
# At the iteration 100 the Mean Squared Error is 2.8701878585748215
# At the iteration 100 the Mean Squared Error is 2.8612236887786664
# At the iteration 100 the Mean Squared Error is 2.9907319358736206
# At the iteration 100 the Mean Squared Error is 2.938113715682832
# At the iteration 200 the Mean Squared Error is 2.809631364097055
# At the iteration 200 the Mean Squared Error is 2.808960228219755
# At the iteration 200 the Mean Squared Error is 2.788929512072747
# At the iteration 200 the Mean Squared Error is 2.795830907116574
# At the iteration 200 the Mean Squared Error is 2.7949237438754557
# At the iteration 200 the Mean Squared Error is 2.8729234093527567
# At the iteration 200 the Mean Squared Error is 2.8122481915644655
# At the iteration 200 the Mean Squared Error is 2.79061673387444
# At the iteration 200 the Mean Squared Error is 2.897214174474337
# At the iteration 200 the Mean Squared Error is 2.800152072565838
# At the iteration 200 the Mean Squared Error is 2.8472016225441785
# At the iteration 200 the Mean Squared Error is 2.8649328543245827
# At the iteration 200 the Mean Squared Error is 2.7905010945456454
# At the iteration 200 the Mean Squared Error is 2.7941501375172733
# At the iteration 200 the Mean Squared Error is 2.8037130772179113
# At the iteration 300 the Mean Squared Error is 2.856681686732535
# At the iteration 300 the Mean Squared Error is 2.7926254738295753
# At the iteration 300 the Mean Squared Error is 2.8016432953550314
# At the iteration 300 the Mean Squared Error is 2.8067907458099977
# At the iteration 300 the Mean Squared Error is 2.796694931544754
# At the iteration 300 the Mean Squared Error is 2.841172200278757
# At the iteration 300 the Mean Squared Error is 2.8256973573043234
# At the iteration 300 the Mean Squared Error is 2.813194722891345
# At the iteration 300 the Mean Squared Error is 2.8451348905092018
# At the iteration 300 the Mean Squared Error is 2.805367155460408
# At the iteration 300 the Mean Squared Error is 2.8739599241089815
# At the iteration 300 the Mean Squared Error is 2.9169653881138307
# At the iteration 300 the Mean Squared Error is 2.858977352970348
# At the iteration 300 the Mean Squared Error is 2.836836367749385
# At the iteration 300 the Mean Squared Error is 2.785965093785221
# At the iteration 400 the Mean Squared Error is 2.7959521449792635
# At the iteration 400 the Mean Squared Error is 2.819558218586676
# At the iteration 400 the Mean Squared Error is 2.8129937281830086
# At the iteration 400 the Mean Squared Error is 2.9896300623360537
# At the iteration 400 the Mean Squared Error is 2.840537104184116
# At the iteration 400 the Mean Squared Error is 2.8022449629099166
# At the iteration 400 the Mean Squared Error is 2.791732213217711
# At the iteration 400 the Mean Squared Error is 2.7904255680979393
# At the iteration 400 the Mean Squared Error is 2.7964154318853605
# At the iteration 400 the Mean Squared Error is 2.7978811388735974
# At the iteration 400 the Mean Squared Error is 2.7872020285455608
# At the iteration 400 the Mean Squared Error is 2.796420877868875
# At the iteration 400 the Mean Squared Error is 2.8665126417961218
# At the iteration 400 the Mean Squared Error is 2.787753904765283
# At the iteration 400 the Mean Squared Error is 2.799457609142735
# At the iteration 500 the Mean Squared Error is 2.7844789380022816
# At the iteration 500 the Mean Squared Error is 2.8350758696151503
# At the iteration 500 the Mean Squared Error is 2.8124194998388474
# At the iteration 500 the Mean Squared Error is 2.7899990887721247
# At the iteration 500 the Mean Squared Error is 2.8962154990972566
# At the iteration 500 the Mean Squared Error is 2.789725348752266
# At the iteration 500 the Mean Squared Error is 2.7940456961930926
# At the iteration 500 the Mean Squared Error is 2.8063531874202967
# At the iteration 500 the Mean Squared Error is 2.8499696462380144
# At the iteration 500 the Mean Squared Error is 2.793888265101705
# At the iteration 500 the Mean Squared Error is 2.8170925816452326
# At the iteration 500 the Mean Squared Error is 2.8313690942032643
# At the iteration 500 the Mean Squared Error is 2.823119907811102
# At the iteration 500 the Mean Squared Error is 2.7909475252370832
# At the iteration 500 the Mean Squared Error is 2.7870771257083953
# At the iteration 600 the Mean Squared Error is 2.791904524164208
# At the iteration 600 the Mean Squared Error is 2.84910682821648
# At the iteration 600 the Mean Squared Error is 2.922146974429942
# At the iteration 600 the Mean Squared Error is 2.9813207791474756
# At the iteration 600 the Mean Squared Error is 2.788734878598749
# At the iteration 600 the Mean Squared Error is 2.790484469700776
# At the iteration 600 the Mean Squared Error is 2.814956156543327
# At the iteration 600 the Mean Squared Error is 2.815503883729493
# At the iteration 600 the Mean Squared Error is 2.7919474396829504
# At the iteration 600 the Mean Squared Error is 3.079174990528578
# At the iteration 600 the Mean Squared Error is 2.9594282319368275
# At the iteration 600 the Mean Squared Error is 2.961010144042301
# At the iteration 600 the Mean Squared Error is 2.8756507742694284
# At the iteration 600 the Mean Squared Error is 2.814499720985881
# At the iteration 600 the Mean Squared Error is 2.799191533255587
# At the iteration 700 the Mean Squared Error is 2.786418544799683
# At the iteration 700 the Mean Squared Error is 2.840538978281529
# At the iteration 700 the Mean Squared Error is 3.0486818583219497
# At the iteration 700 the Mean Squared Error is 2.9130290387351203
# At the iteration 700 the Mean Squared Error is 2.84709377502795
# At the iteration 700 the Mean Squared Error is 2.903075979363133
# At the iteration 700 the Mean Squared Error is 2.8262617340513208
# At the iteration 700 the Mean Squared Error is 2.8138783511775523
# At the iteration 700 the Mean Squared Error is 2.797334161118294
# At the iteration 700 the Mean Squared Error is 2.799436766585006
# At the iteration 700 the Mean Squared Error is 2.8977446015906048
# At the iteration 700 the Mean Squared Error is 3.132063782230921
# At the iteration 700 the Mean Squared Error is 2.828457825423973
# At the iteration 700 the Mean Squared Error is 2.795748017537828
# At the iteration 700 the Mean Squared Error is 2.7996048507313454
# At the iteration 800 the Mean Squared Error is 2.8175006493076533
# At the iteration 800 the Mean Squared Error is 2.787715407365796
# At the iteration 800 the Mean Squared Error is 2.786889880164888
# At the iteration 800 the Mean Squared Error is 2.7863882924015075
# At the iteration 800 the Mean Squared Error is 2.8009504589131757
# At the iteration 800 the Mean Squared Error is 2.7860520433912153
# At the iteration 800 the Mean Squared Error is 2.8229003927699416
# At the iteration 800 the Mean Squared Error is 2.786244467818367
# At the iteration 800 the Mean Squared Error is 2.8099797348185485
# At the iteration 800 the Mean Squared Error is 3.0269832100606275
# At the iteration 800 the Mean Squared Error is 2.8795846837814167
# At the iteration 800 the Mean Squared Error is 2.8346859627123346
# At the iteration 800 the Mean Squared Error is 3.123689071532059
# At the iteration 800 the Mean Squared Error is 2.9438364519058404
# At the iteration 800 the Mean Squared Error is 2.9270421275722924
# At the iteration 900 the Mean Squared Error is 2.8077803558593475
# At the iteration 900 the Mean Squared Error is 2.815334719877315
# At the iteration 900 the Mean Squared Error is 2.802659724481557
# At the iteration 900 the Mean Squared Error is 2.7874985385194226
# At the iteration 900 the Mean Squared Error is 2.8066906098698188
# At the iteration 900 the Mean Squared Error is 2.9415731880738862
# At the iteration 900 the Mean Squared Error is 2.8339739916500646
# At the iteration 900 the Mean Squared Error is 2.794103966970904
# At the iteration 900 the Mean Squared Error is 2.8155954993570322
# At the iteration 900 the Mean Squared Error is 2.7885557645318175
# At the iteration 900 the Mean Squared Error is 2.7867805079406263
# At the iteration 900 the Mean Squared Error is 2.816598555329365
# At the iteration 900 the Mean Squared Error is 2.8596417944095958
# At the iteration 900 the Mean Squared Error is 2.805913738306409
# At the iteration 900 the Mean Squared Error is 2.841918135475364
# At the iteration 1000 the Mean Squared Error is 2.827466424503187
# At the iteration 1000 the Mean Squared Error is 2.8032783893622533
# At the iteration 1000 the Mean Squared Error is 2.8026766477198923
# At the iteration 1000 the Mean Squared Error is 2.826614630947276
# At the iteration 1000 the Mean Squared Error is 2.931108334187527
# At the iteration 1000 the Mean Squared Error is 2.793605401953462
# At the iteration 1000 the Mean Squared Error is 2.806304701538304
# At the iteration 1000 the Mean Squared Error is 2.7873568137625786
# At the iteration 1000 the Mean Squared Error is 2.793283208300488
# At the iteration 1000 the Mean Squared Error is 2.7934215186980733
# At the iteration 1000 the Mean Squared Error is 2.9150742323633314
# At the iteration 1000 the Mean Squared Error is 2.7927107543229557
# At the iteration 1000 the Mean Squared Error is 2.790321631976054
# At the iteration 1000 the Mean Squared Error is 2.871805130721605
# At the iteration 1000 the Mean Squared Error is 2.838867086636302
# At the iteration 1100 the Mean Squared Error is 2.8585816593088067
# At the iteration 1100 the Mean Squared Error is 2.800840030784986
# At the iteration 1100 the Mean Squared Error is 2.8081780551365836
# At the iteration 1100 the Mean Squared Error is 2.855827173345805
# At the iteration 1100 the Mean Squared Error is 2.8243780597252215
# At the iteration 1100 the Mean Squared Error is 2.8081097211201187
# At the iteration 1100 the Mean Squared Error is 2.922224889400005
# At the iteration 1100 the Mean Squared Error is 2.884028230037409
# At the iteration 1100 the Mean Squared Error is 2.8029881129974172
# At the iteration 1100 the Mean Squared Error is 2.7985032720976593
# At the iteration 1100 the Mean Squared Error is 2.800856807172048
# At the iteration 1100 the Mean Squared Error is 2.7983657856206587
# At the iteration 1100 the Mean Squared Error is 2.8644923410137015
# At the iteration 1100 the Mean Squared Error is 2.7847989777441917
# At the iteration 1100 the Mean Squared Error is 2.7974554159768776
# At the iteration 1200 the Mean Squared Error is 2.836404227482782
# At the iteration 1200 the Mean Squared Error is 2.812101147687471
# At the iteration 1200 the Mean Squared Error is 2.893858313306189
# At the iteration 1200 the Mean Squared Error is 2.884425588825286
# At the iteration 1200 the Mean Squared Error is 2.895893381193125
# At the iteration 1200 the Mean Squared Error is 2.8539133336190856
# At the iteration 1200 the Mean Squared Error is 2.8163690735442226
# At the iteration 1200 the Mean Squared Error is 2.814981113218947
# At the iteration 1200 the Mean Squared Error is 2.806687821530115
# At the iteration 1200 the Mean Squared Error is 3.1054479907293073
# At the iteration 1200 the Mean Squared Error is 2.928912322053913
# At the iteration 1200 the Mean Squared Error is 2.8859137115415052
# At the iteration 1200 the Mean Squared Error is 2.7982888884896577
# At the iteration 1200 the Mean Squared Error is 2.790414165882552
# At the iteration 1200 the Mean Squared Error is 2.80453438147821
# At the iteration 1300 the Mean Squared Error is 2.80059031295922
# At the iteration 1300 the Mean Squared Error is 2.797935787929565
# At the iteration 1300 the Mean Squared Error is 2.7883041071747026
# At the iteration 1300 the Mean Squared Error is 2.788079139564383
# At the iteration 1300 the Mean Squared Error is 2.933992435680795
# At the iteration 1300 the Mean Squared Error is 2.938912089420104
# At the iteration 1300 the Mean Squared Error is 2.8776966050762183
# At the iteration 1300 the Mean Squared Error is 2.8971826305215647
# At the iteration 1300 the Mean Squared Error is 2.7989409131333844
# At the iteration 1300 the Mean Squared Error is 2.7909522668033304
# At the iteration 1300 the Mean Squared Error is 2.8179210179067127
# At the iteration 1300 the Mean Squared Error is 2.7911374706702206
# At the iteration 1300 the Mean Squared Error is 2.8517666142774782
# At the iteration 1300 the Mean Squared Error is 2.794589348473399
# At the iteration 1300 the Mean Squared Error is 2.8070584059295047
# At the iteration 1400 the Mean Squared Error is 3.02465912913348
# At the iteration 1400 the Mean Squared Error is 2.924376841845839
# At the iteration 1400 the Mean Squared Error is 2.8557201160948384
# At the iteration 1400 the Mean Squared Error is 2.7846895635782913
# At the iteration 1400 the Mean Squared Error is 2.786233092218654
# At the iteration 1400 the Mean Squared Error is 2.804206805622304
# At the iteration 1400 the Mean Squared Error is 2.8972452446580403
# At the iteration 1400 the Mean Squared Error is 2.8250665880055714
# At the iteration 1400 the Mean Squared Error is 2.8092077862697384
# At the iteration 1400 the Mean Squared Error is 2.7876161387427034
# At the iteration 1400 the Mean Squared Error is 2.7861747365547456
# At the iteration 1400 the Mean Squared Error is 2.79346769924213
# At the iteration 1400 the Mean Squared Error is 2.880949621308653
# At the iteration 1400 the Mean Squared Error is 2.8416782750144254
# At the iteration 1400 the Mean Squared Error is 2.7962254148961576
# At the iteration 1500 the Mean Squared Error is 2.7866688155612316
# At the iteration 1500 the Mean Squared Error is 2.7865423678292376
# At the iteration 1500 the Mean Squared Error is 2.824321736954736
# At the iteration 1500 the Mean Squared Error is 2.830363584832205
# At the iteration 1500 the Mean Squared Error is 2.8834954147166822
# At the iteration 1500 the Mean Squared Error is 2.7995457190905824
# At the iteration 1500 the Mean Squared Error is 2.813952678559863
# At the iteration 1500 the Mean Squared Error is 2.796291415674349
# At the iteration 1500 the Mean Squared Error is 2.86419105567871
# At the iteration 1500 the Mean Squared Error is 2.815713806783943
# At the iteration 1500 the Mean Squared Error is 2.8038561290381376
# At the iteration 1500 the Mean Squared Error is 2.894492875514148
# At the iteration 1500 the Mean Squared Error is 2.813881627950538
# At the iteration 1500 the Mean Squared Error is 2.786123603904094
# At the iteration 1500 the Mean Squared Error is 2.79135312810272
# At the iteration 1600 the Mean Squared Error is 2.8254944090053935
# At the iteration 1600 the Mean Squared Error is 2.8344795996642707
# At the iteration 1600 the Mean Squared Error is 2.833241410255374
# At the iteration 1600 the Mean Squared Error is 2.8604280568919984
# At the iteration 1600 the Mean Squared Error is 2.804827580071375
# At the iteration 1600 the Mean Squared Error is 2.7900876602535107
# At the iteration 1600 the Mean Squared Error is 2.790973196542509
# At the iteration 1600 the Mean Squared Error is 2.8159904604613484
# At the iteration 1600 the Mean Squared Error is 2.812373297322196
# At the iteration 1600 the Mean Squared Error is 2.8432617245678404
# At the iteration 1600 the Mean Squared Error is 2.81420612293173
# At the iteration 1600 the Mean Squared Error is 2.8081631758252907
# At the iteration 1600 the Mean Squared Error is 2.836674843705597
# At the iteration 1600 the Mean Squared Error is 2.8488204365562217
# At the iteration 1600 the Mean Squared Error is 2.8730595033517643
# At the iteration 1700 the Mean Squared Error is 2.940906040365519
# At the iteration 1700 the Mean Squared Error is 2.9429686549800844
# At the iteration 1700 the Mean Squared Error is 2.792191146528552
# At the iteration 1700 the Mean Squared Error is 2.818713438033521
# At the iteration 1700 the Mean Squared Error is 2.7934512339290136
# At the iteration 1700 the Mean Squared Error is 2.8461729117053767
# At the iteration 1700 the Mean Squared Error is 2.7934225354085847
# At the iteration 1700 the Mean Squared Error is 2.816071373780332
# At the iteration 1700 the Mean Squared Error is 2.7933420187022864
# At the iteration 1700 the Mean Squared Error is 2.791095500977518
# At the iteration 1700 the Mean Squared Error is 2.8111849534420004
# At the iteration 1700 the Mean Squared Error is 2.8321853793548337
# At the iteration 1700 the Mean Squared Error is 2.7854692279434956
# At the iteration 1700 the Mean Squared Error is 2.796083050310991
# At the iteration 1700 the Mean Squared Error is 2.790665554607567
# At the iteration 1800 the Mean Squared Error is 2.798929604986631
# At the iteration 1800 the Mean Squared Error is 2.789041770938874
# At the iteration 1800 the Mean Squared Error is 2.856878864710711
# At the iteration 1800 the Mean Squared Error is 2.7898529240945287
# At the iteration 1800 the Mean Squared Error is 2.788361746551285
# At the iteration 1800 the Mean Squared Error is 2.786262462616356
# At the iteration 1800 the Mean Squared Error is 2.7956816648794107
# At the iteration 1800 the Mean Squared Error is 2.7975165816086847
# At the iteration 1800 the Mean Squared Error is 2.789734090467594
# At the iteration 1800 the Mean Squared Error is 2.7873281787672024
# At the iteration 1800 the Mean Squared Error is 2.9543391391869243
# At the iteration 1800 the Mean Squared Error is 2.850640387301596
# At the iteration 1800 the Mean Squared Error is 2.8118822631996143
# At the iteration 1800 the Mean Squared Error is 2.808054212782793
# At the iteration 1800 the Mean Squared Error is 2.784488430243332
# At the iteration 1900 the Mean Squared Error is 2.8463883964673062
# At the iteration 1900 the Mean Squared Error is 2.8021429632213186
# At the iteration 1900 the Mean Squared Error is 2.797565801450764
# At the iteration 1900 the Mean Squared Error is 2.8406131867582287
# At the iteration 1900 the Mean Squared Error is 2.8022421986179005
# At the iteration 1900 the Mean Squared Error is 2.8300695958900604
# At the iteration 1900 the Mean Squared Error is 2.863150917300631
# At the iteration 1900 the Mean Squared Error is 2.8354088871457894
# At the iteration 1900 the Mean Squared Error is 2.790974702825589
# At the iteration 1900 the Mean Squared Error is 2.831583452606801
# At the iteration 1900 the Mean Squared Error is 2.852055471906573
# At the iteration 1900 the Mean Squared Error is 2.9229738104179455
# At the iteration 1900 the Mean Squared Error is 2.8066077711528727
# At the iteration 1900 the Mean Squared Error is 2.84845060134236
# At the iteration 1900 the Mean Squared Error is 3.03841168582653
# At the iteration 2000 the Mean Squared Error is 2.7851141247795805
# At the iteration 2000 the Mean Squared Error is 2.785083381579051
# At the iteration 2000 the Mean Squared Error is 2.8182614011101714
# At the iteration 2000 the Mean Squared Error is 2.8073633160856533
# At the iteration 2000 the Mean Squared Error is 2.7946206802389297
# At the iteration 2000 the Mean Squared Error is 2.804233760973619
# At the iteration 2000 the Mean Squared Error is 2.8028959895147163
# At the iteration 2000 the Mean Squared Error is 2.8081821980121804
# At the iteration 2000 the Mean Squared Error is 3.0753681695705746
# At the iteration 2000 the Mean Squared Error is 3.0842174816934245
# At the iteration 2000 the Mean Squared Error is 2.8041782009901577
# At the iteration 2000 the Mean Squared Error is 2.821078130953805
# At the iteration 2000 the Mean Squared Error is 2.8224967258694282
# At the iteration 2000 the Mean Squared Error is 2.8711760961423622
# At the iteration 2000 the Mean Squared Error is 2.831030266919163
# At the iteration 2100 the Mean Squared Error is 2.812718749717927
# At the iteration 2100 the Mean Squared Error is 2.896697140158855
# At the iteration 2100 the Mean Squared Error is 2.8232793319272367
# At the iteration 2100 the Mean Squared Error is 2.825068658180584
# At the iteration 2100 the Mean Squared Error is 2.8215655035322476
# At the iteration 2100 the Mean Squared Error is 2.838215050435866
# At the iteration 2100 the Mean Squared Error is 2.9301863910911354
# At the iteration 2100 the Mean Squared Error is 2.917569347101735
# At the iteration 2100 the Mean Squared Error is 2.8150523973374897
# At the iteration 2100 the Mean Squared Error is 2.7976356961305777
# At the iteration 2100 the Mean Squared Error is 2.791003237938554
# At the iteration 2100 the Mean Squared Error is 2.8394074828495492
# At the iteration 2100 the Mean Squared Error is 2.790197687829014
# At the iteration 2100 the Mean Squared Error is 2.8128839630553837
# At the iteration 2100 the Mean Squared Error is 2.8066260682288715
# At the iteration 2200 the Mean Squared Error is 2.7883169031810957
# At the iteration 2200 the Mean Squared Error is 2.7904780650078522
# At the iteration 2200 the Mean Squared Error is 2.7846173394423026
# At the iteration 2200 the Mean Squared Error is 2.806294676908536
# At the iteration 2200 the Mean Squared Error is 2.854623588006748
# At the iteration 2200 the Mean Squared Error is 2.7932542455825673
# At the iteration 2200 the Mean Squared Error is 2.7936651056161543
# At the iteration 2200 the Mean Squared Error is 2.8063686850928438
# At the iteration 2200 the Mean Squared Error is 2.848339459447716
# At the iteration 2200 the Mean Squared Error is 2.784408114089908
# At the iteration 2200 the Mean Squared Error is 2.789031702076413
# At the iteration 2200 the Mean Squared Error is 2.790450914931908
# At the iteration 2200 the Mean Squared Error is 2.79478073275764
# At the iteration 2200 the Mean Squared Error is 2.798240592602972
# At the iteration 2200 the Mean Squared Error is 2.7962191788540407
# At the iteration 2300 the Mean Squared Error is 2.827723912632205
# At the iteration 2300 the Mean Squared Error is 2.7969908229378326
# At the iteration 2300 the Mean Squared Error is 2.8170971436573904
# At the iteration 2300 the Mean Squared Error is 2.799788090917225
# At the iteration 2300 the Mean Squared Error is 2.8493964810946535
# At the iteration 2300 the Mean Squared Error is 2.870123100913527
# At the iteration 2300 the Mean Squared Error is 2.847509113971893
# At the iteration 2300 the Mean Squared Error is 2.8542608112881624
# At the iteration 2300 the Mean Squared Error is 2.890285215998389
# At the iteration 2300 the Mean Squared Error is 2.8269399670922577
# At the iteration 2300 the Mean Squared Error is 2.8412144897259806
# At the iteration 2300 the Mean Squared Error is 2.8263521812781773
# At the iteration 2300 the Mean Squared Error is 2.853622142643809
# At the iteration 2300 the Mean Squared Error is 2.797519574040002
# At the iteration 2300 the Mean Squared Error is 2.8503669727123393
# At the iteration 2400 the Mean Squared Error is 2.7921421207484194
# At the iteration 2400 the Mean Squared Error is 2.7914464065422977
# At the iteration 2400 the Mean Squared Error is 2.792916445984965
# At the iteration 2400 the Mean Squared Error is 2.8149196481186163
# At the iteration 2400 the Mean Squared Error is 2.801681460225426
# At the iteration 2400 the Mean Squared Error is 2.8112564773222384
# At the iteration 2400 the Mean Squared Error is 2.8045387605326346
# At the iteration 2400 the Mean Squared Error is 2.80729631301574
# At the iteration 2400 the Mean Squared Error is 2.787007341869503
# At the iteration 2400 the Mean Squared Error is 2.793541297678705
# At the iteration 2400 the Mean Squared Error is 2.816990266174202
# At the iteration 2400 the Mean Squared Error is 2.8241539459652008
# At the iteration 2400 the Mean Squared Error is 2.796121373362031
# At the iteration 2400 the Mean Squared Error is 2.7900608037230734
# At the iteration 2400 the Mean Squared Error is 2.7862492341480736
# At the iteration 2500 the Mean Squared Error is 2.791677900338203
# At the iteration 2500 the Mean Squared Error is 2.7913963135480215
# At the iteration 2500 the Mean Squared Error is 2.807405634062866
# At the iteration 2500 the Mean Squared Error is 2.8129221847429644
# At the iteration 2500 the Mean Squared Error is 2.789458350569461
# At the iteration 2500 the Mean Squared Error is 2.813175450557054
# At the iteration 2500 the Mean Squared Error is 2.7947317296654695
# At the iteration 2500 the Mean Squared Error is 2.8179382055334457
# At the iteration 2500 the Mean Squared Error is 2.7898392093426305
# At the iteration 2500 the Mean Squared Error is 2.805569682580997
# At the iteration 2500 the Mean Squared Error is 2.8281726794607405
# At the iteration 2500 the Mean Squared Error is 2.7859279881004677
# At the iteration 2500 the Mean Squared Error is 2.7875944031912177
# At the iteration 2500 the Mean Squared Error is 2.8455592123200675
# At the iteration 2500 the Mean Squared Error is 2.799667353047978
# At the iteration 2600 the Mean Squared Error is 2.869651972476644
# At the iteration 2600 the Mean Squared Error is 2.7979876049255914
# At the iteration 2600 the Mean Squared Error is 2.8057956302011537
# At the iteration 2600 the Mean Squared Error is 2.840647623725582
# At the iteration 2600 the Mean Squared Error is 2.7965168937903973
# At the iteration 2600 the Mean Squared Error is 2.7911680852787866
# At the iteration 2600 the Mean Squared Error is 2.7910757760443206
# At the iteration 2600 the Mean Squared Error is 2.788152002370997
# At the iteration 2600 the Mean Squared Error is 2.8950156972610994
# At the iteration 2600 the Mean Squared Error is 2.7908191725327582
# At the iteration 2600 the Mean Squared Error is 2.798854909149504
# At the iteration 2600 the Mean Squared Error is 2.8051917946867038
# At the iteration 2600 the Mean Squared Error is 2.8599302346502804
# At the iteration 2600 the Mean Squared Error is 2.784326054269719
# At the iteration 2600 the Mean Squared Error is 2.8222565846422207
# At the iteration 2700 the Mean Squared Error is 2.907348059151787
# At the iteration 2700 the Mean Squared Error is 2.785700475123358
# At the iteration 2700 the Mean Squared Error is 2.7880768520647545
# At the iteration 2700 the Mean Squared Error is 2.8390523389419506
# At the iteration 2700 the Mean Squared Error is 2.784514098389626
# At the iteration 2700 the Mean Squared Error is 2.8158953818295913
# At the iteration 2700 the Mean Squared Error is 2.794405664229177
# At the iteration 2700 the Mean Squared Error is 2.821843301083916
# At the iteration 2700 the Mean Squared Error is 2.816400341236918
# At the iteration 2700 the Mean Squared Error is 2.8268727299859404
# At the iteration 2700 the Mean Squared Error is 2.8021175622061008
# At the iteration 2700 the Mean Squared Error is 2.817182571265948
# At the iteration 2700 the Mean Squared Error is 2.7865484932276967
# At the iteration 2700 the Mean Squared Error is 2.826550274520664
# At the iteration 2700 the Mean Squared Error is 3.061744338890122
# At the iteration 2800 the Mean Squared Error is 2.7871724777233196
# At the iteration 2800 the Mean Squared Error is 2.784656514705611
# At the iteration 2800 the Mean Squared Error is 2.858249657189197
# At the iteration 2800 the Mean Squared Error is 2.78731896842257
# At the iteration 2800 the Mean Squared Error is 2.7912866947008173
# At the iteration 2800 the Mean Squared Error is 2.7885592262826764
# At the iteration 2800 the Mean Squared Error is 2.7852595353479184
# At the iteration 2800 the Mean Squared Error is 2.7928859270709103
# At the iteration 2800 the Mean Squared Error is 2.799034554278058
# At the iteration 2800 the Mean Squared Error is 2.863535296332085
# At the iteration 2800 the Mean Squared Error is 2.785405278036712
# At the iteration 2800 the Mean Squared Error is 2.8053858295313217
# At the iteration 2800 the Mean Squared Error is 2.7936533033786928
# At the iteration 2800 the Mean Squared Error is 2.795147215964603
# At the iteration 2800 the Mean Squared Error is 2.802154126367214
# At the iteration 2900 the Mean Squared Error is 2.793097718219343
# At the iteration 2900 the Mean Squared Error is 2.802145283036312
# At the iteration 2900 the Mean Squared Error is 2.8276862440773085
# At the iteration 2900 the Mean Squared Error is 2.799098407037146
# At the iteration 2900 the Mean Squared Error is 2.8006053337365167
# At the iteration 2900 the Mean Squared Error is 2.83552605122766
# At the iteration 2900 the Mean Squared Error is 2.812214514453808
# At the iteration 2900 the Mean Squared Error is 2.7866744296232615
# At the iteration 2900 the Mean Squared Error is 2.7925431097148827
# At the iteration 2900 the Mean Squared Error is 2.811264455017603
# At the iteration 2900 the Mean Squared Error is 2.7885255500395583
# At the iteration 2900 the Mean Squared Error is 2.786228141841663
# At the iteration 2900 the Mean Squared Error is 2.78522430378177
# At the iteration 2900 the Mean Squared Error is 2.8028010071521505
# At the iteration 2900 the Mean Squared Error is 2.79769353002942
# At the iteration 3000 the Mean Squared Error is 2.804232172307976
# At the iteration 3000 the Mean Squared Error is 2.7846500429062964
# At the iteration 3000 the Mean Squared Error is 2.7959839786511687
# At the iteration 3000 the Mean Squared Error is 2.7964172849147446
# At the iteration 3000 the Mean Squared Error is 2.940511626845884
# At the iteration 3000 the Mean Squared Error is 2.800086821060861
# At the iteration 3000 the Mean Squared Error is 2.8645844202550257
# At the iteration 3000 the Mean Squared Error is 2.8374253821995294
# At the iteration 3000 the Mean Squared Error is 2.8406004980392265
# At the iteration 3000 the Mean Squared Error is 2.8016672001887817
# At the iteration 3000 the Mean Squared Error is 2.793313176626457
# At the iteration 3000 the Mean Squared Error is 2.8014785531230815
# At the iteration 3000 the Mean Squared Error is 2.786050510843704
# At the iteration 3000 the Mean Squared Error is 2.7969529617940845
# At the iteration 3000 the Mean Squared Error is 2.8660608643480545
# At the iteration 3100 the Mean Squared Error is 2.8468749784392937
# At the iteration 3100 the Mean Squared Error is 2.793933301013277
# At the iteration 3100 the Mean Squared Error is 2.7918688345934792
# At the iteration 3100 the Mean Squared Error is 2.807224291686649
# At the iteration 3100 the Mean Squared Error is 2.8071359403139895
# At the iteration 3100 the Mean Squared Error is 2.8269170296043287
# At the iteration 3100 the Mean Squared Error is 2.8102873841874456
# At the iteration 3100 the Mean Squared Error is 2.8471268391099596
# At the iteration 3100 the Mean Squared Error is 2.8279699057426573
# At the iteration 3100 the Mean Squared Error is 2.809681467671474
# At the iteration 3100 the Mean Squared Error is 2.8281974183943066
# At the iteration 3100 the Mean Squared Error is 2.785720350867748
# At the iteration 3100 the Mean Squared Error is 2.786383226388565
# At the iteration 3100 the Mean Squared Error is 2.7991243233361707
# At the iteration 3100 the Mean Squared Error is 2.8072363902522968
# At the iteration 3200 the Mean Squared Error is 2.8224164916385575
# At the iteration 3200 the Mean Squared Error is 2.9638999433094875
# At the iteration 3200 the Mean Squared Error is 2.796977857222396
# At the iteration 3200 the Mean Squared Error is 2.8123816821070364
# At the iteration 3200 the Mean Squared Error is 2.7960518306150117
# At the iteration 3200 the Mean Squared Error is 2.7903682410707606
# At the iteration 3200 the Mean Squared Error is 2.828546478482059
# At the iteration 3200 the Mean Squared Error is 2.8636338429777526
# At the iteration 3200 the Mean Squared Error is 2.809217252213031
# At the iteration 3200 the Mean Squared Error is 2.795596191635549
# At the iteration 3200 the Mean Squared Error is 2.7940542870835516
# At the iteration 3200 the Mean Squared Error is 2.7849350274387854
# At the iteration 3200 the Mean Squared Error is 2.807768447453469
# At the iteration 3200 the Mean Squared Error is 2.786121467693282
# At the iteration 3200 the Mean Squared Error is 2.796067223191396
# At the iteration 3300 the Mean Squared Error is 2.826743956394596
# At the iteration 3300 the Mean Squared Error is 2.8093776336641976
# At the iteration 3300 the Mean Squared Error is 2.7901869123336303
# At the iteration 3300 the Mean Squared Error is 2.787294941311611
# At the iteration 3300 the Mean Squared Error is 2.809686098405708
# At the iteration 3300 the Mean Squared Error is 2.786811566094199
# At the iteration 3300 the Mean Squared Error is 2.7984506803686617
# At the iteration 3300 the Mean Squared Error is 2.7981223799692794
# At the iteration 3300 the Mean Squared Error is 2.7913575085269566
# At the iteration 3300 the Mean Squared Error is 2.920711296760654
# At the iteration 3300 the Mean Squared Error is 2.81302863767828
# At the iteration 3300 the Mean Squared Error is 2.8943692068999205
# At the iteration 3300 the Mean Squared Error is 2.803256640577355
# At the iteration 3300 the Mean Squared Error is 2.7856273095305086
# At the iteration 3300 the Mean Squared Error is 2.784433922260309
# At the iteration 3400 the Mean Squared Error is 2.7957104959631396
# At the iteration 3400 the Mean Squared Error is 2.810990211914296
# At the iteration 3400 the Mean Squared Error is 2.831112288254445
# At the iteration 3400 the Mean Squared Error is 2.788274922400008
# At the iteration 3400 the Mean Squared Error is 2.8280596766146457
# At the iteration 3400 the Mean Squared Error is 2.794500295409812
# At the iteration 3400 the Mean Squared Error is 2.8143588949893026
# At the iteration 3400 the Mean Squared Error is 2.8020534833181268
# At the iteration 3400 the Mean Squared Error is 2.8129994840396297
# At the iteration 3400 the Mean Squared Error is 2.7874027857953547
# At the iteration 3400 the Mean Squared Error is 2.880180018312789
# At the iteration 3400 the Mean Squared Error is 2.7893920979578417
# At the iteration 3400 the Mean Squared Error is 2.792273970429269
# At the iteration 3400 the Mean Squared Error is 2.7945154875911897
# At the iteration 3400 the Mean Squared Error is 2.796282578980081
# At the iteration 3500 the Mean Squared Error is 2.7852717852325033
# At the iteration 3500 the Mean Squared Error is 2.7892637003038736
# At the iteration 3500 the Mean Squared Error is 2.7856162628866876
# At the iteration 3500 the Mean Squared Error is 2.8089475918939537
# At the iteration 3500 the Mean Squared Error is 2.8056415514532493
# At the iteration 3500 the Mean Squared Error is 2.942861607032626
# At the iteration 3500 the Mean Squared Error is 2.788950818315349
# At the iteration 3500 the Mean Squared Error is 2.7924738020109685
# At the iteration 3500 the Mean Squared Error is 2.784309881247599
# At the iteration 3500 the Mean Squared Error is 2.7944451056117545
# At the iteration 3500 the Mean Squared Error is 2.915018819092867
# At the iteration 3500 the Mean Squared Error is 2.8121780527068565
# At the iteration 3500 the Mean Squared Error is 2.788853453747484
# At the iteration 3500 the Mean Squared Error is 2.8446296727244134
# At the iteration 3500 the Mean Squared Error is 2.8621928672682166
# At the iteration 3600 the Mean Squared Error is 2.8128728453942027
# At the iteration 3600 the Mean Squared Error is 2.790456411161616
# At the iteration 3600 the Mean Squared Error is 2.8463401327478413
# At the iteration 3600 the Mean Squared Error is 2.8016919152312254
# At the iteration 3600 the Mean Squared Error is 2.8023809817448364
# At the iteration 3600 the Mean Squared Error is 2.7879259675731567
# At the iteration 3600 the Mean Squared Error is 2.9201752592910806
# At the iteration 3600 the Mean Squared Error is 2.8640495774524055
# At the iteration 3600 the Mean Squared Error is 2.8001420340991565
# At the iteration 3600 the Mean Squared Error is 2.7871647905121093
# At the iteration 3600 the Mean Squared Error is 2.7853067653307892
# At the iteration 3600 the Mean Squared Error is 2.796744223448025
# At the iteration 3600 the Mean Squared Error is 2.891062590567547
# At the iteration 3600 the Mean Squared Error is 2.8505818383270674
# At the iteration 3600 the Mean Squared Error is 2.815132073843057
# At the iteration 3700 the Mean Squared Error is 2.7960910078070835
# At the iteration 3700 the Mean Squared Error is 2.785458119045267
# At the iteration 3700 the Mean Squared Error is 2.793809985347071
# At the iteration 3700 the Mean Squared Error is 2.7876593506691996
# At the iteration 3700 the Mean Squared Error is 2.810102781741947
# At the iteration 3700 the Mean Squared Error is 2.82214271962077
# At the iteration 3700 the Mean Squared Error is 2.8840511074154596
# At the iteration 3700 the Mean Squared Error is 2.991322939010114
# At the iteration 3700 the Mean Squared Error is 2.8638575254825467
# At the iteration 3700 the Mean Squared Error is 2.838579439122567
# At the iteration 3700 the Mean Squared Error is 2.7988889729482094
# At the iteration 3700 the Mean Squared Error is 2.801363849502942
# At the iteration 3700 the Mean Squared Error is 2.823806963181939
# At the iteration 3700 the Mean Squared Error is 2.8108366713195965
# At the iteration 3700 the Mean Squared Error is 2.7923489301942483
# At the iteration 3800 the Mean Squared Error is 2.845117042138313
# At the iteration 3800 the Mean Squared Error is 2.7861077094550075
# At the iteration 3800 the Mean Squared Error is 2.806396015052327
# At the iteration 3800 the Mean Squared Error is 2.799611903842642
# At the iteration 3800 the Mean Squared Error is 2.8528640907582106
# At the iteration 3800 the Mean Squared Error is 2.7965389241964216
# At the iteration 3800 the Mean Squared Error is 2.816270130335963
# At the iteration 3800 the Mean Squared Error is 2.876507284649794
# At the iteration 3800 the Mean Squared Error is 2.8395975431457816
# At the iteration 3800 the Mean Squared Error is 2.803177898366513
# At the iteration 3800 the Mean Squared Error is 2.7916971108419917
# At the iteration 3800 the Mean Squared Error is 2.830088013623859
# At the iteration 3800 the Mean Squared Error is 2.8288291990505376
# At the iteration 3800 the Mean Squared Error is 2.892269596963959
# At the iteration 3800 the Mean Squared Error is 2.8012317790426176
# At the iteration 3900 the Mean Squared Error is 2.9183052600241313
# At the iteration 3900 the Mean Squared Error is 2.8559280564592258
# At the iteration 3900 the Mean Squared Error is 2.804173388898899
# At the iteration 3900 the Mean Squared Error is 2.7902654382065126
# At the iteration 3900 the Mean Squared Error is 2.7922987137996507
# At the iteration 3900 the Mean Squared Error is 2.8226815269532572
# At the iteration 3900 the Mean Squared Error is 2.8206188393709066
# At the iteration 3900 the Mean Squared Error is 2.7971183278473575
# At the iteration 3900 the Mean Squared Error is 2.828053076081216
# At the iteration 3900 the Mean Squared Error is 2.81671734356196
# At the iteration 3900 the Mean Squared Error is 2.835422993585164
# At the iteration 3900 the Mean Squared Error is 2.8118715655686377
# At the iteration 3900 the Mean Squared Error is 2.813124453686944
# At the iteration 3900 the Mean Squared Error is 2.7923601838434435
# At the iteration 3900 the Mean Squared Error is 2.8005348214392614
# At the iteration 4000 the Mean Squared Error is 2.791425113891397
# At the iteration 4000 the Mean Squared Error is 2.7877568113988946
# At the iteration 4000 the Mean Squared Error is 2.8976996326748643
# At the iteration 4000 the Mean Squared Error is 2.845545903981283
# At the iteration 4000 the Mean Squared Error is 2.7870957335624498
# At the iteration 4000 the Mean Squared Error is 2.7916684262055895
# At the iteration 4000 the Mean Squared Error is 2.787917822190559
# At the iteration 4000 the Mean Squared Error is 2.800056471402351
# At the iteration 4000 the Mean Squared Error is 2.788578176016687
# At the iteration 4000 the Mean Squared Error is 2.949858666491467
# At the iteration 4000 the Mean Squared Error is 2.9573835018432213
# At the iteration 4000 the Mean Squared Error is 2.978132381341793
# At the iteration 4000 the Mean Squared Error is 2.8062630051294004
# At the iteration 4000 the Mean Squared Error is 2.795942733561052
# At the iteration 4000 the Mean Squared Error is 3.0232185588327645
# At the iteration 4100 the Mean Squared Error is 2.8275063642764615
# At the iteration 4100 the Mean Squared Error is 2.824931013112784
# At the iteration 4100 the Mean Squared Error is 2.8008007118672538
# At the iteration 4100 the Mean Squared Error is 2.888809121629913
# At the iteration 4100 the Mean Squared Error is 2.9059659743553112
# At the iteration 4100 the Mean Squared Error is 2.950917614429816
# At the iteration 4100 the Mean Squared Error is 3.1239439719542825
# At the iteration 4100 the Mean Squared Error is 2.8424974432868204
# At the iteration 4100 the Mean Squared Error is 2.807900003561908
# At the iteration 4100 the Mean Squared Error is 2.7860746681128967
# At the iteration 4100 the Mean Squared Error is 2.7945491480609643
# At the iteration 4100 the Mean Squared Error is 2.789814017463716
# At the iteration 4100 the Mean Squared Error is 3.017684602093167
# At the iteration 4100 the Mean Squared Error is 3.0494138109158415
# At the iteration 4100 the Mean Squared Error is 2.998244236162701
# At the iteration 4200 the Mean Squared Error is 2.792566574531827
# At the iteration 4200 the Mean Squared Error is 2.8010994616777283
# At the iteration 4200 the Mean Squared Error is 2.791098929586502
# At the iteration 4200 the Mean Squared Error is 2.7883884881756806
# At the iteration 4200 the Mean Squared Error is 2.8118097178457715
# At the iteration 4200 the Mean Squared Error is 2.7933652762613095
# At the iteration 4200 the Mean Squared Error is 2.806761798990493
# At the iteration 4200 the Mean Squared Error is 3.0308772322245563
# At the iteration 4200 the Mean Squared Error is 2.838064030921292
# At the iteration 4200 the Mean Squared Error is 2.865167194519981
# At the iteration 4200 the Mean Squared Error is 2.798234229402675
# At the iteration 4200 the Mean Squared Error is 2.792247304698595
# At the iteration 4200 the Mean Squared Error is 2.7870485395820452
# At the iteration 4200 the Mean Squared Error is 2.7965616835406295
# At the iteration 4200 the Mean Squared Error is 2.8994781433569217
# At the iteration 4300 the Mean Squared Error is 2.788689162576475
# At the iteration 4300 the Mean Squared Error is 2.8156492032138103
# At the iteration 4300 the Mean Squared Error is 2.8406048583319006
# At the iteration 4300 the Mean Squared Error is 2.9104978622723103
# At the iteration 4300 the Mean Squared Error is 3.022234353410083
# At the iteration 4300 the Mean Squared Error is 3.0334669770923743
# At the iteration 4300 the Mean Squared Error is 2.8233447090741124
# At the iteration 4300 the Mean Squared Error is 2.8739352628864054
# At the iteration 4300 the Mean Squared Error is 2.8745344999829023
# At the iteration 4300 the Mean Squared Error is 2.8327704148340684
# At the iteration 4300 the Mean Squared Error is 2.796309714037916
# At the iteration 4300 the Mean Squared Error is 2.7984827878262424
# At the iteration 4300 the Mean Squared Error is 2.7884402700384747
# At the iteration 4300 the Mean Squared Error is 2.809610971815582
# At the iteration 4300 the Mean Squared Error is 2.897806689452371
# At the iteration 4400 the Mean Squared Error is 2.868023372308767
# At the iteration 4400 the Mean Squared Error is 2.976787018904398
# At the iteration 4400 the Mean Squared Error is 2.796438886973235
# At the iteration 4400 the Mean Squared Error is 2.7899168766334532
# At the iteration 4400 the Mean Squared Error is 2.7971577494584388
# At the iteration 4400 the Mean Squared Error is 2.78644175266133
# At the iteration 4400 the Mean Squared Error is 2.8005237713992
# At the iteration 4400 the Mean Squared Error is 2.855221271545646
# At the iteration 4400 the Mean Squared Error is 2.8291961410914075
# At the iteration 4400 the Mean Squared Error is 2.7938334626122474
# At the iteration 4400 the Mean Squared Error is 2.8126058188394993
# At the iteration 4400 the Mean Squared Error is 2.7873773322084476
# At the iteration 4400 the Mean Squared Error is 2.784629938371686
# At the iteration 4400 the Mean Squared Error is 2.868155263576332
# At the iteration 4400 the Mean Squared Error is 2.8391095581455583
# At the iteration 4500 the Mean Squared Error is 2.795234755555549
# At the iteration 4500 the Mean Squared Error is 2.784559500206763
# At the iteration 4500 the Mean Squared Error is 2.8252821761880518
# At the iteration 4500 the Mean Squared Error is 2.7978317320418515
# At the iteration 4500 the Mean Squared Error is 2.8702415170713156
# At the iteration 4500 the Mean Squared Error is 2.920799759245324
# At the iteration 4500 the Mean Squared Error is 2.802283969116254
# At the iteration 4500 the Mean Squared Error is 2.8070115207499198
# At the iteration 4500 the Mean Squared Error is 2.7929170137709867
# At the iteration 4500 the Mean Squared Error is 2.7973188545709604
# At the iteration 4500 the Mean Squared Error is 2.7922334877892583
# At the iteration 4500 the Mean Squared Error is 2.7858172542482307
# At the iteration 4500 the Mean Squared Error is 2.8520092066812914
# At the iteration 4500 the Mean Squared Error is 2.8066330570140976
# At the iteration 4500 the Mean Squared Error is 2.857065805990695
# At the iteration 4600 the Mean Squared Error is 2.788435930669977
# At the iteration 4600 the Mean Squared Error is 2.7873437271335684
# At the iteration 4600 the Mean Squared Error is 2.790857811411878
# At the iteration 4600 the Mean Squared Error is 2.805426379159664
# At the iteration 4600 the Mean Squared Error is 2.7923610903848357
# At the iteration 4600 the Mean Squared Error is 2.8216647894139872
# At the iteration 4600 the Mean Squared Error is 2.7857487412142063
# At the iteration 4600 the Mean Squared Error is 2.788364989364751
# At the iteration 4600 the Mean Squared Error is 2.7889956470277197
# At the iteration 4600 the Mean Squared Error is 2.8117743074216355
# At the iteration 4600 the Mean Squared Error is 2.7913017258445905
# At the iteration 4600 the Mean Squared Error is 2.8966625516488556
# At the iteration 4600 the Mean Squared Error is 2.7937180271950366
# At the iteration 4600 the Mean Squared Error is 2.830054455295261
# At the iteration 4600 the Mean Squared Error is 2.801160091007046
# At the iteration 4700 the Mean Squared Error is 2.806318026251355
# At the iteration 4700 the Mean Squared Error is 2.8373070768122295
# At the iteration 4700 the Mean Squared Error is 2.8093856605955354
# At the iteration 4700 the Mean Squared Error is 2.7851997339129957
# At the iteration 4700 the Mean Squared Error is 2.789335308837698
# At the iteration 4700 the Mean Squared Error is 2.8189025025953662
# At the iteration 4700 the Mean Squared Error is 2.8349665570863323
# At the iteration 4700 the Mean Squared Error is 2.7894823898267807
# At the iteration 4700 the Mean Squared Error is 2.8841448997312273
# At the iteration 4700 the Mean Squared Error is 3.0180456302898024
# At the iteration 4700 the Mean Squared Error is 2.9153248611931786
# At the iteration 4700 the Mean Squared Error is 2.8284300450224857
# At the iteration 4700 the Mean Squared Error is 2.8149446119686288
# At the iteration 4700 the Mean Squared Error is 2.846561660628605
# At the iteration 4700 the Mean Squared Error is 2.842148819110498
# At the iteration 4800 the Mean Squared Error is 2.890973144082076
# At the iteration 4800 the Mean Squared Error is 2.894445903613268
# At the iteration 4800 the Mean Squared Error is 2.8104582130516733
# At the iteration 4800 the Mean Squared Error is 2.8201000043006035
# At the iteration 4800 the Mean Squared Error is 2.809003166253524
# At the iteration 4800 the Mean Squared Error is 2.9336591367742573
# At the iteration 4800 the Mean Squared Error is 2.8366626954364063
# At the iteration 4800 the Mean Squared Error is 2.8736757519991523
# At the iteration 4800 the Mean Squared Error is 2.8513143301078525
# At the iteration 4800 the Mean Squared Error is 2.8541437057547303
# At the iteration 4800 the Mean Squared Error is 2.824009065627622
# At the iteration 4800 the Mean Squared Error is 2.877118518637175
# At the iteration 4800 the Mean Squared Error is 2.810496904957284
# At the iteration 4800 the Mean Squared Error is 2.8263507876641745
# At the iteration 4800 the Mean Squared Error is 2.794169040787219
# At the iteration 4900 the Mean Squared Error is 2.7905828049578623
# At the iteration 4900 the Mean Squared Error is 2.813916250059387
# At the iteration 4900 the Mean Squared Error is 2.7847684773392944
# ...
# At the iteration 8500 the Mean Squared Error is 2.7899025766921453
# At the iteration 8500 the Mean Squared Error is 2.7866611065713625
# At the iteration 8500 the Mean Squared Error is 2.791321296602492
# At the iteration 8500 the Mean Squared Error is 2.7918292972805228
# At the iteration 8500 the Mean Squared Error is 2.8811932221643906
# At the iteration 8500 the Mean Squared Error is 2.9063368027624032
# At the iteration 8500 the Mean Squared Error is 2.786098175111383
# At the iteration 8500 the Mean Squared Error is 2.7946738099746518
# At the iteration 8500 the Mean Squared Error is 2.791186948441746
# At the iteration 8500 the Mean Squared Error is 2.8345444105547024
# At the iteration 8500 the Mean Squared Error is 2.7974354691651895
# At the iteration 8500 the Mean Squared Error is 2.792345506807832
# At the iteration 8500 the Mean Squared Error is 2.873200964335963
# At the iteration 8500 the Mean Squared Error is 2.8181630327270795
# At the iteration 8600 the Mean Squared Error is 2.843041800654697
# At the iteration 8600 the Mean Squared Error is 2.8427851594006426
# At the iteration 8600 the Mean Squared Error is 2.9032416740827744
# At the iteration 8600 the Mean Squared Error is 2.7992056607201756
# At the iteration 8600 the Mean Squared Error is 2.794380507983968
# At the iteration 8600 the Mean Squared Error is 2.7867506737778767
# At the iteration 8600 the Mean Squared Error is 2.786635824879569
# At the iteration 8600 the Mean Squared Error is 2.795162077473749
# At the iteration 8600 the Mean Squared Error is 2.8106780263734055
# At the iteration 8600 the Mean Squared Error is 2.7884676498077554
# At the iteration 8600 the Mean Squared Error is 2.8525144884636813
# At the iteration 8600 the Mean Squared Error is 2.8275906016332697
# At the iteration 8600 the Mean Squared Error is 2.815596428448278
# At the iteration 8600 the Mean Squared Error is 2.790645790603112
# At the iteration 8600 the Mean Squared Error is 2.9128132395788406
# At the iteration 8700 the Mean Squared Error is 2.7963565120647336
# At the iteration 8700 the Mean Squared Error is 2.8423813273049827
# At the iteration 8700 the Mean Squared Error is 2.7854378038727576
# At the iteration 8700 the Mean Squared Error is 2.7948164124360666
# At the iteration 8700 the Mean Squared Error is 2.7965502225696084
# At the iteration 8700 the Mean Squared Error is 2.7934775328647037
# At the iteration 8700 the Mean Squared Error is 2.825485198696354
# At the iteration 8700 the Mean Squared Error is 2.8463927379283804
# At the iteration 8700 the Mean Squared Error is 2.8154724744877746
# At the iteration 8700 the Mean Squared Error is 2.8368736722718744
# At the iteration 8700 the Mean Squared Error is 2.839876377318151
# At the iteration 8700 the Mean Squared Error is 2.939246330797406
# At the iteration 8700 the Mean Squared Error is 2.893865511460201
# At the iteration 8700 the Mean Squared Error is 2.8990684344209616
# At the iteration 8700 the Mean Squared Error is 2.8771027104970868
# At the iteration 8800 the Mean Squared Error is 2.8389690241392964
# At the iteration 8800 the Mean Squared Error is 2.8873683358991933
# At the iteration 8800 the Mean Squared Error is 2.8849068710014802
# At the iteration 8800 the Mean Squared Error is 2.8590991648845385
# At the iteration 8800 the Mean Squared Error is 2.817571530982511
# At the iteration 8800 the Mean Squared Error is 2.8014214024371
# At the iteration 8800 the Mean Squared Error is 2.7956081464462725
# At the iteration 8800 the Mean Squared Error is 2.997710515566815
# At the iteration 8800 the Mean Squared Error is 2.874889606051338
# At the iteration 8800 the Mean Squared Error is 2.7851331995781576
# At the iteration 8800 the Mean Squared Error is 2.7866126942493277
# At the iteration 8800 the Mean Squared Error is 2.8146511956212414
# At the iteration 8800 the Mean Squared Error is 2.8466776233226803
# At the iteration 8800 the Mean Squared Error is 2.7887666093730172
# At the iteration 8800 the Mean Squared Error is 2.8071722396645584
# At the iteration 8900 the Mean Squared Error is 2.788841591944738
# At the iteration 8900 the Mean Squared Error is 2.7890492741977915
# At the iteration 8900 the Mean Squared Error is 2.787140490559014
# At the iteration 8900 the Mean Squared Error is 2.8744478865373395
# At the iteration 8900 the Mean Squared Error is 2.8202414744956603
# At the iteration 8900 the Mean Squared Error is 2.834990218724266
# At the iteration 8900 the Mean Squared Error is 2.838280283871592
# At the iteration 8900 the Mean Squared Error is 2.872450775065749
# At the iteration 8900 the Mean Squared Error is 2.8214171618101442
# At the iteration 8900 the Mean Squared Error is 2.7893123645211757
# At the iteration 8900 the Mean Squared Error is 2.796476447471486
# At the iteration 8900 the Mean Squared Error is 2.892132700037992
# At the iteration 8900 the Mean Squared Error is 2.816321691219082
# At the iteration 8900 the Mean Squared Error is 2.7974685937086408
# At the iteration 8900 the Mean Squared Error is 2.7866774620059402
# At the iteration 9000 the Mean Squared Error is 3.2057903706885065
# At the iteration 9000 the Mean Squared Error is 3.059606787065312
# At the iteration 9000 the Mean Squared Error is 2.9466832282438817
# At the iteration 9000 the Mean Squared Error is 2.851309409540279
# At the iteration 9000 the Mean Squared Error is 2.9914351442469034
# At the iteration 9000 the Mean Squared Error is 2.8283581277791554
# At the iteration 9000 the Mean Squared Error is 2.8072486276686224
# At the iteration 9000 the Mean Squared Error is 2.805294486799588
# At the iteration 9000 the Mean Squared Error is 2.7950683065889415
# At the iteration 9000 the Mean Squared Error is 2.8045080358678165
# At the iteration 9000 the Mean Squared Error is 2.8395896045515325
# At the iteration 9000 the Mean Squared Error is 2.7913467017924387
# At the iteration 9000 the Mean Squared Error is 2.794985054337709
# At the iteration 9000 the Mean Squared Error is 2.784310830711653
# At the iteration 9000 the Mean Squared Error is 2.8617646673780497
# At the iteration 9100 the Mean Squared Error is 2.831781514674723
# At the iteration 9100 the Mean Squared Error is 2.788944279166623
# At the iteration 9100 the Mean Squared Error is 2.8168182639975328
# At the iteration 9100 the Mean Squared Error is 2.7965166169628977
# At the iteration 9100 the Mean Squared Error is 2.8504391727432505
# At the iteration 9100 the Mean Squared Error is 2.8780235043866087
# At the iteration 9100 the Mean Squared Error is 2.8126937160697163
# At the iteration 9100 the Mean Squared Error is 2.8230281962810158
# At the iteration 9100 the Mean Squared Error is 2.7920993275004617
# At the iteration 9100 the Mean Squared Error is 2.8560946209313327
# At the iteration 9100 the Mean Squared Error is 2.9348694341285624
# At the iteration 9100 the Mean Squared Error is 2.792261740430458
# At the iteration 9100 the Mean Squared Error is 2.7875846837352163
# At the iteration 9100 the Mean Squared Error is 2.847392404344471
# At the iteration 9100 the Mean Squared Error is 2.79659775587575
# At the iteration 9200 the Mean Squared Error is 2.7862203650448434
# At the iteration 9200 the Mean Squared Error is 2.8005770626823523
# At the iteration 9200 the Mean Squared Error is 2.8930366372089305
# At the iteration 9200 the Mean Squared Error is 2.842387455601537
# At the iteration 9200 the Mean Squared Error is 2.9247176634124075
# At the iteration 9200 the Mean Squared Error is 2.8253509167813977
# At the iteration 9200 the Mean Squared Error is 2.8878517743488596
# At the iteration 9200 the Mean Squared Error is 2.859266399257873
# At the iteration 9200 the Mean Squared Error is 2.842601828615941
# At the iteration 9200 the Mean Squared Error is 2.816786063548767
# At the iteration 9200 the Mean Squared Error is 2.9203814578751017
# At the iteration 9200 the Mean Squared Error is 2.801370896654268
# At the iteration 9200 the Mean Squared Error is 2.8042444866128324
# At the iteration 9200 the Mean Squared Error is 2.9205995274274996
# At the iteration 9200 the Mean Squared Error is 2.837925548633473
# At the iteration 9300 the Mean Squared Error is 2.7896547449353006
# At the iteration 9300 the Mean Squared Error is 2.8164039374745435
# At the iteration 9300 the Mean Squared Error is 2.7899491492710378
# At the iteration 9300 the Mean Squared Error is 2.934159307238407
# At the iteration 9300 the Mean Squared Error is 2.9099984212227468
# At the iteration 9300 the Mean Squared Error is 2.7898956567636457
# At the iteration 9300 the Mean Squared Error is 2.82387077973709
# At the iteration 9300 the Mean Squared Error is 2.8002944859839625
# At the iteration 9300 the Mean Squared Error is 2.787871441130372
# At the iteration 9300 the Mean Squared Error is 2.9003917029873167
# At the iteration 9300 the Mean Squared Error is 2.8716441959022654
# At the iteration 9300 the Mean Squared Error is 2.787387491410902
# At the iteration 9300 the Mean Squared Error is 2.8174187554512993
# At the iteration 9300 the Mean Squared Error is 2.8262698104654884
# At the iteration 9300 the Mean Squared Error is 2.8345432430012876
# At the iteration 9400 the Mean Squared Error is 2.7888879582223547
# At the iteration 9400 the Mean Squared Error is 2.8291133944316345
# At the iteration 9400 the Mean Squared Error is 2.8372365574024845
# At the iteration 9400 the Mean Squared Error is 2.839488304843256
# At the iteration 9400 the Mean Squared Error is 2.8479731334654548
# At the iteration 9400 the Mean Squared Error is 2.8057204773763726
# At the iteration 9400 the Mean Squared Error is 2.7866717858578953
# At the iteration 9400 the Mean Squared Error is 2.864018254635633
# At the iteration 9400 the Mean Squared Error is 2.7882439370550007
# At the iteration 9400 the Mean Squared Error is 2.7923432652027422
# At the iteration 9400 the Mean Squared Error is 2.8353379189636656
# At the iteration 9400 the Mean Squared Error is 2.879553091626012
# At the iteration 9400 the Mean Squared Error is 2.811754582537923
# At the iteration 9400 the Mean Squared Error is 2.8014404614529065
# At the iteration 9400 the Mean Squared Error is 2.837510897310992
# At the iteration 9500 the Mean Squared Error is 3.077819521189972
# At the iteration 9500 the Mean Squared Error is 2.8510928461648586
# At the iteration 9500 the Mean Squared Error is 2.8155210107685447
# At the iteration 9500 the Mean Squared Error is 2.8072075193745705
# At the iteration 9500 the Mean Squared Error is 2.8271948367569646
# At the iteration 9500 the Mean Squared Error is 2.859347315258214
# At the iteration 9500 the Mean Squared Error is 2.837877937162291
# At the iteration 9500 the Mean Squared Error is 2.853433126635432
# At the iteration 9500 the Mean Squared Error is 2.938099197369547
# At the iteration 9500 the Mean Squared Error is 2.8651962428591093
# At the iteration 9500 the Mean Squared Error is 2.8110129902027383
# At the iteration 9500 the Mean Squared Error is 2.8467723019569955
# At the iteration 9500 the Mean Squared Error is 2.7995421940534824
# At the iteration 9500 the Mean Squared Error is 2.7866926886758687
# At the iteration 9500 the Mean Squared Error is 2.7942822058439987
# At the iteration 9600 the Mean Squared Error is 3.0203238698546135
# At the iteration 9600 the Mean Squared Error is 2.8863132067319794
# At the iteration 9600 the Mean Squared Error is 2.8086933730272063
# At the iteration 9600 the Mean Squared Error is 2.7915703522462603
# At the iteration 9600 the Mean Squared Error is 2.804796624615179
# At the iteration 9600 the Mean Squared Error is 2.785152729581702
# At the iteration 9600 the Mean Squared Error is 2.7853795217819153
# At the iteration 9600 the Mean Squared Error is 2.8295240942786086
# At the iteration 9600 the Mean Squared Error is 2.8036602979467293
# At the iteration 9600 the Mean Squared Error is 2.811841351427938
# At the iteration 9600 the Mean Squared Error is 2.815480508734458
# At the iteration 9600 the Mean Squared Error is 2.810892334032983
# At the iteration 9600 the Mean Squared Error is 2.788111923578731
# At the iteration 9600 the Mean Squared Error is 2.8357457150332186
# At the iteration 9600 the Mean Squared Error is 2.786543081991256
# At the iteration 9700 the Mean Squared Error is 2.8410318241942183
# At the iteration 9700 the Mean Squared Error is 2.8171357749962804
# At the iteration 9700 the Mean Squared Error is 2.8055375570430545
# At the iteration 9700 the Mean Squared Error is 2.999283434855783
# At the iteration 9700 the Mean Squared Error is 2.875076916202571
# At the iteration 9700 the Mean Squared Error is 2.9528847933655467
# At the iteration 9700 the Mean Squared Error is 2.8704337962002398
# At the iteration 9700 the Mean Squared Error is 2.8955724951799784
# At the iteration 9700 the Mean Squared Error is 2.7922222675956356
# At the iteration 9700 the Mean Squared Error is 2.8140647987678715
# At the iteration 9700 the Mean Squared Error is 2.793894625661581
# At the iteration 9700 the Mean Squared Error is 2.790085385286082
# At the iteration 9700 the Mean Squared Error is 2.784624585800633
# At the iteration 9700 the Mean Squared Error is 2.8700878710380864
# At the iteration 9700 the Mean Squared Error is 2.7934915655980297
# At the iteration 9800 the Mean Squared Error is 2.7910121921115665
# At the iteration 9800 the Mean Squared Error is 2.7976119536685995
# At the iteration 9800 the Mean Squared Error is 2.9172333316726404
# At the iteration 9800 the Mean Squared Error is 2.849152044673576
# At the iteration 9800 the Mean Squared Error is 2.7863570339750674
# At the iteration 9800 the Mean Squared Error is 2.7895492630442518
# At the iteration 9800 the Mean Squared Error is 2.789937234828096
# At the iteration 9800 the Mean Squared Error is 2.8803215180410042
# At the iteration 9800 the Mean Squared Error is 2.831802780174933
# At the iteration 9800 the Mean Squared Error is 2.8676037998775787
# At the iteration 9800 the Mean Squared Error is 2.8298507441777856
# At the iteration 9800 the Mean Squared Error is 2.7863771383277203
# At the iteration 9800 the Mean Squared Error is 2.7925166523229463
# At the iteration 9800 the Mean Squared Error is 2.8004725677936677
# At the iteration 9800 the Mean Squared Error is 2.786121124283314
# At the iteration 9900 the Mean Squared Error is 2.929835976692072
# At the iteration 9900 the Mean Squared Error is 2.8254617037290086
# At the iteration 9900 the Mean Squared Error is 2.7926509458907756
# At the iteration 9900 the Mean Squared Error is 2.7969419311166437
# At the iteration 9900 the Mean Squared Error is 2.833165356865753
# At the iteration 9900 the Mean Squared Error is 2.7865757478370825
# At the iteration 9900 the Mean Squared Error is 2.7855854529207478
# At the iteration 9900 the Mean Squared Error is 2.786816414975673
# At the iteration 9900 the Mean Squared Error is 2.784865670845359
# At the iteration 9900 the Mean Squared Error is 2.7947028809618253
# At the iteration 9900 the Mean Squared Error is 2.800395493234963
# At the iteration 9900 the Mean Squared Error is 2.7850909539471673
# At the iteration 9900 the Mean Squared Error is 2.793809820369045
# At the iteration 9900 the Mean Squared Error is 2.8171201095908254
# At the iteration 9900 the Mean Squared Error is 2.784793830976323
# At the iteration 10000 the Mean Squared Error is 2.804540209934448
# At the iteration 10000 the Mean Squared Error is 2.80850876893742
# At the iteration 10000 the Mean Squared Error is 2.892023185508522
# At the iteration 10000 the Mean Squared Error is 2.8550503611305356
# At the iteration 10000 the Mean Squared Error is 2.877989231007551
# At the iteration 10000 the Mean Squared Error is 2.9083688579872544
# At the iteration 10000 the Mean Squared Error is 2.8092370240646303
# At the iteration 10000 the Mean Squared Error is 2.79858041910783
# At the iteration 10000 the Mean Squared Error is 2.7902634141008362
# At the iteration 10000 the Mean Squared Error is 2.7869560769221056
# At the iteration 10000 the Mean Squared Error is 2.7916765287474767
# At the iteration 10000 the Mean Squared Error is 2.7940026263545095
# At the iteration 10000 the Mean Squared Error is 2.7908027373943503
# At the iteration 10000 the Mean Squared Error is 2.8027491287110022
# At the iteration 10000 the Mean Squared Error is 2.9622992454755694

# %%
path_MSE = []
for i in range(len(path)):
  path_MSE.append(MSE(path[i],x_aug,y))

# %%
# the best MSE
np.min(path_MSE)
# Out:
# np.float64(2.784132776043914)

# %%
# the best set of weights
path[np.argmin(path_MSE)]
# Out:
# array([18.54841262,  3.51356361, 14.46361537, -0.08289718])
